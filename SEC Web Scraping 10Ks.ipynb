# %% [markdown]
# # Scraping SEC Website for Financials

# %%
import edgar
import requests
import pandas as pd
import re
from bs4 import BeautifulSoup

# %%
#assuming we already have this information
#edgar.download_index("C:\\Users\\605089\\Desktop\\Personal Projects\\Financial", 2011, "your_name your@email.address", skip_all_present_except_last=False)

# %% [markdown]
# ## Functions

# %%
def find_10k_quarter(selected_company, selected_report, year):
    quarters = ['QTR1', 'QTR2', 'QTR3', 'QTR4']
    
    master_index_file = ''
        
    for quarter in quarters:
        
        master_index_file = str(year) + '-' + quarter + '.tsv'
        
        master_index = pd.read_csv(master_index_file, sep='\t', lineterminator='\n', names=None)
        
        master_index.columns.values[0] = 'Item'
    
        filing_index = master_index[(master_index['Item'].str.contains(selected_company, case=False)) & (master_index['Item'].str.contains(selected_report, case=False))]
        
        if not filing_index.empty:
            return quarter
    
    return ''

# %%
def get_index_info_on_company(selectedcompany, selectedreport, master_index_file):
    #read master index info into a pandas dataframe
    master_index = pd.read_csv(master_index_file, sep='\t', lineterminator='\n', names=None)

    #rename column for convenience
    master_index.columns.values[0] = 'Item'

    #select the row in which the company and document you are interested in is located
    filing_index = master_index[(master_index['Item'].str.contains(selectedcompany, case = False)) & (master_index['Item'].str.contains(selectedreport, case=False))]

    filing_index = filing_index['Item'].str.split('|').to_list()

    for elem in filing_index:
        if selectedreport in elem:
            filing_index_clean = elem
            
    print(filing_index_clean)
            
    return filing_index_clean

# %% [markdown]
# The below functions gets the xml file of a specific filing using Edgar index files downloaded from the edgar python library. Then parses through the xml summary of the filing to obtain the specific urls of various sections of the filing.

# %%
def get_xml_summary_of_file(selectedcompany, selectedreport, master_index_file, user_agent):
    #read master index info into a pandas dataframe
    master_index = pd.read_csv(master_index_file, sep='\t', lineterminator='\n', names=None)

    #rename column for convenience
    master_index.columns.values[0] = 'Item'

    #select the row in which the company and document you are interested in is located
    filing_index = master_index[(master_index['Item'].str.contains(selectedcompany, case=False)) & (master_index['Item'].str.contains(selectedreport, case=False))]

    filing_index = filing_index['Item'].str.split('|').to_list()

    for elem in filing_index:
        if selectedreport in elem:
            filing_index = elem

    for item in filing_index:
        if '.txt' in item:
             txt_url = item
                
    #define base url
    base_url = r"https://www.sec.gov"

    #convert the txt_url to a json url for the document landing page
    documents_url = base_url + "/Archives/" + txt_url.replace('-','').replace('.txt', '/index.json')

    content = requests.get(documents_url, headers=user_agent).json()


    #for each file in the document landing page
    for file in content['directory']['item']:
    
        #if the filing's name is FilingSummary.xml
        if file['name'] == 'FilingSummary.xml':
        
            #create the url for the xml file
            xml_summary = base_url + content['directory']['name'] + "/" + file['name']
        
            print('-' * 100)
            print('File Name: ' + file['name'])
            print('File Path: ' + xml_summary)
        
    return xml_summary

# %%
def parse_xml_summary_of_file(xml_summary, user_agent):
    #define a new base url that represents the filing folder. This will come in handy when we need to download the reports
    base_url = xml_summary.replace('FilingSummary.xml', '')

    #request and parse the content (use .content because this is an xml file not json)
    content = requests.get(xml_summary, headers=user_agent).content

    #create a soup object to parse the content using BeautifulSoup
    soup = BeautifulSoup(content, 'lxml')

    #find the 'myreports' tag because this contains all the individual reports submitted
    reports = soup.find('myreports')

    #want a list ot store all theindividual components of the report, so create the master list
    master_reports = []

    # loop through each report in the 'myreports' tag but avoid the last one as this will cause an error
    # (last one has differnent formatting).
    for index, report in enumerate(reports.find_all('report')[:-1]):
    
        #create a dictionary to store all the differnet parts we need
        report_dict = {}
        report_dict['name_short'] = report.shortname.text
        report_dict['name_long'] = report.longname.text
        report_dict['position'] = index+1
        #report_dict['category'] = report.menucategory.text
        report_dict['url'] = base_url + report.htmlfilename.text
    
        #append the dictionary to the master list.
        master_reports.append(report_dict)
    
        #print the info to the user.
        print('-'*100)
        print(base_url + report.htmlfilename.text)
        print(report.longname.text)
        print(report.shortname.text)
        #print(report.menucategory.text)
        print(index+1)
        
    return master_reports

# %% [markdown]
# Below tries to take a list of urls linking towards the tables in a financial filing, select which urls we want to request content from, and then parse the html text to get specific table information from those urls.

# %%
##################### REVIST LATER #########################################################

def grab_financial_statements(master_reports):
    #create the list to hold the statement urls
    statements_url = []

    for report_dict in master_reports:
    
    # define the statements we want to look for.   
    #######################################################################################
    # MAY WANT TO REVISIT THIS
    #######################################################################################
        item1 = r"CONSOLIDATED"
        item2 = r"PARENTHETICAL"
        item3 = r"EQUITY"
    
        if item1 in report_dict['name_short'].upper() and item2 not in report_dict['name_short'].upper() and item3 not in report_dict['name_short'].upper() and report_dict['position'] < 12:
            statements_url.append(report_dict['url'])
        
        
    # NOW WE HAVE THE URLS OF THE STATEMENTS WE WANT TO SCRAPE
        
        
    #assuming we want all the statements in a single data set
    statements_data = []

    #loop through each statement url
    for statement in statements_url:
    
        #define a dictionary that will store the different parts of the statement
        statement_data = {}
        statement_data['headers'] = []
        statement_data['sections'] = []
        statement_data['data'] = []
    
        #request the statement file content
        content = requests.get(statement, headers=user_agent).content
        report_soup = BeautifulSoup(content, 'html')
    
        #find all the rows, figure out what type of row it is, parse the elements, and store in teh statement file list.
        #tr = table row
        for index, row in enumerate(report_soup.table.find_all('tr')):
        
            #first let's get all the elements (td = standard data cell)
            # cols represents elements in the row
            cols = row.find_all('td')
            
           # if it's a regular row and not a section or a table header (th = header, strong = important)
            if (len(row.find_all('th')) == 0 and len(row.find_all('table')) == 0): # and len(row.find_all('strong')) == 0:
                reg_row = []
                for ele in cols:
                
                    if len(row.find_all('strong')) != 0:
                        reg_row.append(ele.text.strip().upper())
                    else:
                        reg_row.append(ele.text.strip())
                        
                #reg_row = [ele.text.strip() for ele in cols]
                statement_data['data'].append(reg_row)
                        
                #check if it is a section label and store that it in sec_row
                if len(row.find_all('strong')) != 0:
                    sec_row = cols[0].text.strip().upper()
                    statement_data['sections'].append(sec_row)
                    
            
            #finally if it's not any of those it must be a header
            elif (len(row.find_all('th')) != 0):
                hed_row = []
                for ele in row.find_all('th'):
                    if (len(ele.find_all('sup'))) == 0:
                        hed_row.append(ele.text.strip())
                statement_data['headers'].append(hed_row)
            
            else:
                print("We encountered an error")
    
        statements_data.append(statement_data)
    
    return statements_data

# %% [markdown]
# Below are functions that deal with converting data into a pandas dataframe

# %%
## Purpose: Checks if a character can be converted into a float

def char_is_float(char):
    try:
        float(char)
        return True
    except:
        return False
    

## Purpose: Changes a (assumed) string into a float, getting rid of any non-number values in the string in the process.
## Assumptions: We are only interested in strings, so anything else will get a NaN value. In other words, we expect a string
##              but if otherwise then we ignore/erase the passed value as it was not expected and could cause further problems
##              if kept as is.
## Example: Converts '900f' to 900.0

def change_to_float(string):
    
    #if already a float, no need to continue
    if type(string) == float:
        return float(string)
    
    #check if the value is a string (since we want to strip the string and that doesn't work for other types)
    elif type(string) == str:
        
        #get rid of spaces
        string = string.strip()
        
        #just checking ... again
        if string == 'None':
            return 'NaN'
    
        #string to append float characters to
        string_to_convert = ""
        
        #iterate through each element of the string
        for i, char in enumerate(string):
            
            #check the first element of the string, as that can be a minus sign, otherwise only append chars that are numbers
            if i == 0:
                if char_is_float(char) or char == '-':
                    string_to_convert = string_to_convert + char
                
                #if the first character is not a number, why bother
                else:
                    return None
            else:
                if char_is_float(char):
                    string_to_convert = string_to_convert + char
            
        return float(string_to_convert)
    
    #if not a float or a string, I'm assuming its a Nonetype. Return NaN because that is float terminology
    else:
        return 'NaN'

# %%
## Purpose: Gets rid of any columns in a pandas datframe that do not contain any information (i.e. irrelevant)
def get_rid_of_null_columns(df):

    #store the column index of columns we want to drop in a list
    column_index_to_drop = []

    #for each column in the dataframe
    for i in range(df.shape[1]):
        
        #if all values within that column are NaN, assign that column to be dropped
        if df[df.columns[i]].isnull().all():
            column_index_to_drop.append(i)
        
    df.drop(df.columns[column_index_to_drop], axis = 1, inplace=True)

    return df

# %%
## Parameters: Takes in a dictionary called statements data that holds 'headers' and 'data' from the html that describes
##             the financial statements scraped from the SEC website. The 'headers' describe the columns, while the 'data'
##             are the elements below the 'headers' in the table. Statements data contains multiple documents, but this funciton
##             only works with one statement, so a number describing what statement from statements data is given as a 
##             parameter.
##
## Purpose:    Converts a dictionary describing financial data into a pandas dataframe. There are many steps to cleaning
##             the data so that it can be machine readable (e.g. cleaning the data, dealing with edge cases such as multiple
##             levels of headers)

def convert_statements_data_to_pandas(statements_data, statements_num):
    
    #take the raw table data (without the headers)
    balance_data = statements_data[statements_num]['data']
    
    df = pd.DataFrame(balance_data)
    
    #Define the Index column as the first column
    df.index = df[0]
    
    #since the index makes up the first column, we can get rid of the first column
    df = df.drop(0, axis = 1)
    
    # Get rid of the '$', '(', ')', and convert the '' to NaNs.
    df = df.replace('[\$,)]','', regex=True )\
                     .replace( '[(]','-', regex=True)\
                     .replace( '', 'NaN', regex=True)
    
    #convert each element in the table portion into a float (excluding indexes or headers) 
    for i in range(df.shape[1]):
        
        #apply change_to_float which cleans the element to be prepared to turn into a float
        df[df.columns[i]] = df[df.columns[i]].apply(change_to_float) 
    
    #change_to_float should already accomplish this, but this is to double check if any values were not converted into floats
    df = df.astype(float)
    
    df = get_rid_of_null_columns(df)
    
    
    # Now we need the headers for the document (as well as the document's name) 
    # This is also stored in the statements_data under headers
    
    # Because the headers may either have one or two levels in the financial statement (sometimes over the year, there is 
    # a statement like "12 months ended in"), we need to specify the headers that match up best with the columns
    
    # This may not make a whole bunch of sense but that's because getting the headers is specific to two different types
    # of headers for the financial documents.
    
    #if the headers only have one level (one row that holds all the headers)
    if len(statements_data[statements_num]['headers']) == 1:
        
        #headers get all the values in 'headers' except the first one which is used as the header for the index
        header = statements_data[statements_num]['headers'][0][1:]
        document = statements_data[statements_num]['headers'][0][0]
    
    #if the headers have two levels (there are two rows that hold all the headers)
    elif len(statements_data[statements_num]['headers']) == 2:
        
        #headers get the bottom row
        header = statements_data[statements_num]['headers'][-1]
        
        #document name gets first element of the top row
        document = statements_data[statements_num]['headers'][0][0] 
        
    #there are probably more edge cases, so we'll just keep everything the same to keep things moving
    else:
        header = df.columns
        document = 'Category'
    
    
    df.columns = header
    df.index.name = document
    
    return df

# %%
## Purpose: Some indices repeat in a financial statement (e.g. others). To make sure each index is unique without
##          losing information in the dataframe, we can add a tag to the end. The number of tags at the end represent
##          the number of times that index value has been seen before (no tag means first time, one tag means second, two
##          tags means third)
def add_tags_to_repeating_indices(df, tag):
    name = df.index.name
    idx = df.index.to_list()
    dup = {x for x in idx if idx.count(x) > 1}

    for ele in dup:
        end = ''
        for i in range(len(idx)):
            if ele == idx[i]:
                idx[i] = idx[i] + end
                end = end + tag
            
    df.index = idx
    df.index.name = name
    return df

# %%
def add_tags_for_sections(sections, df):
    if len(sections) < 2:
        return df
    idx = df.index.to_list()
    name = df.index.name
    
    idx_tags = []
    
    count = 0
    
    for ele in idx:
        if ele in sections:
            count = count + 1
        idx_tags.append(ele + '-' + str(count))
        
            
    df.index = idx_tags
    df.index.name = name
    
    return df

# %% [markdown]
# # Run Scrape

# %%
#look into master index file for precise spelling
#selectedcompany = 'Booz Allen Hamilton Holding Corp'

selectedcompany = r'Booz'

#get the CIK number (id for company)
#CIK_number = get_CIK_number(selectedcompany, selectedreport)

#select a year you are interested in
selectedyear = 2021
current_year = 2021

#make sure to put in report exact (10-K vs 10-k)
selectedreport = "10-K"

master_index_file = str(selectedyear) + '-' + find_10k_quarter(selectedcompany, selectedreport, selectedyear) + '.tsv'


#define a user agent for access to the SEC Edgar servers (use browser)
user_agent = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36 Edg/97.0.1072.62"}

print(selectedcompany)
print(master_index_file)
# Out:
# Booz
# 2021-QTR2.tsv

# %%
def scrape_SEC_for_statements(selectedcompany, selectedreport, year):
    master_index_file = str(year) + '-' + find_10k_quarter(selectedcompany, selectedreport, year) + '.tsv'
    filing_index = get_index_info_on_company(selectedcompany, selectedreport, master_index_file)
    xml_summary = get_xml_summary_of_file(selectedcompany, selectedreport, master_index_file, user_agent)
    master_reports = parse_xml_summary_of_file(xml_summary, user_agent)
    statements_data = grab_financial_statements(master_reports)
    
    dataframes = []
    for i in range(len(statements_data)):
        df = convert_statements_data_to_pandas(statements_data, i)
        df = add_tags_for_sections(statements_data[i]['sections'], df)
        df = add_tags_to_repeating_indices(df, '@')
        dataframes.append(df)
    return dataframes

# %%
## Purpose: Scrapes the SEC for financial information (specifically balance sheets, income statements, and cash flow 
##          statements) and places this information into dataframes. This function goes back a specified many years from
##          a starting "current" year
## 
## Return: A list containing a list of dataframes (financial statements) for a given year

def scrape_SEC_many_years(selectedcompany, selectedreport, current_year, num_years):
    
    # to store all the dataframes (will be a list (year) of lists (each financial statement) of dataframes (describing the statement))
    dfs = []

    # scrape the SEC for the past 10 years and store all that information in dataframes
    for i in range(num_years):
        year = current_year - i
    
        #scrape the SEC for statements, returns a list of dataframes
        temp_dataframes = scrape_SEC_for_statements(selectedcompany, selectedreport, year)
        
        #append the list of dataframes into a master list representing the year
        dfs.append(temp_dataframes)
    
    return dfs

# %%
#START SCRAPING

num_years = 10

dfs = scrape_SEC_many_years(selectedcompany, selectedreport, current_year, num_years)

#drop all the columns that do not pertain to the specific year of that dataframe

for i in range(len(dfs)):
    for j in range(len(dfs[i])):
        dfs[i][j].drop(columns=dfs[i][j].columns[1:], axis=1, inplace=True)
# Out:
# ['1443646', 'Booz Allen Hamilton Holding Corp', '10-K', '2021-05-21', 'edgar/data/1443646/0001443646-21-000079.txt', 'edgar/data/1443646/0001443646-21-000079-index.html\r']
# ----------------------------------------------------------------------------------------------------
# File Name: FilingSummary.xml
# File Path: https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/FilingSummary.xml
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R1.htm
# 0001001 - Document - Cover
# Cover
# 1
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R2.htm
# 1001002 - Statement - Consolidated Balance Sheets
# Consolidated Balance Sheets
# 2
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R3.htm
# 1002003 - Statement - Consolidated Balance Sheets (Parenthetical)
# Consolidated Balance Sheets (Parenthetical)
# 3
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R4.htm
# 1003004 - Statement - Consolidated Statements of Operations
# Consolidated Statements of Operations
# 4
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R5.htm
# 1004005 - Statement - Consolidated Statements of Comprehensive Income
# Consolidated Statements of Comprehensive Income
# 5
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R6.htm
# 1005006 - Statement - Consolidated Statements of Cash Flows
# Consolidated Statements of Cash Flows
# 6
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R7.htm
# 1006007 - Statement - Consolidated Statements of Stockholders' Equity
# Consolidated Statements of Stockholders' Equity
# 7
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R8.htm
# 1007008 - Statement - Consolidated Statements of Stockholders' Equity (Parenthetical)
# Consolidated Statements of Stockholders' Equity (Parenthetical)
# 8
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R9.htm
# 2101101 - Disclosure - Business Overview
# Business Overview
# 9
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R10.htm
# 2103102 - Disclosure - Summary of Significant Accounting Policies
# Summary of Significant Accounting Policies
# 10
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R11.htm
# 2107103 - Disclosure - Revenue
# Revenue
# 11
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R12.htm
# 2112104 - Disclosure - Earnings Per Share
# Earnings Per Share
# 12
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R13.htm
# 2115105 - Disclosure - Goodwill and Intangible Assets
# Goodwill and Intangible Assets
# 13
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R14.htm
# 2120106 - Disclosure - Accounts Receivable, Net
# Accounts Receivable, Net
# 14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R15.htm
# 2123107 - Disclosure - Property and Equipment, Net
# Property and Equipment, Net
# 15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R16.htm
# 2126108 - Disclosure - Accounts Payable and Other Accrued Expenses
# Accounts Payable and Other Accrued Expenses
# 16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R17.htm
# 2129109 - Disclosure - Accrued Compensation and Benefits
# Accrued Compensation and Benefits
# 17
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R18.htm
# 2132110 - Disclosure - Debt
# Debt
# 18
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R19.htm
# 2138111 - Disclosure - Derivatives
# Derivatives
# 19
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R20.htm
# 2142112 - Disclosure - Leases
# Leases
# 20
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R21.htm
# 2147113 - Disclosure - Income Taxes
# Income Taxes
# 21
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R22.htm
# 2154114 - Disclosure - Employee Benefit Plans
# Employee Benefit Plans
# 22
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R23.htm
# 2162115 - Disclosure - Accumulated Other Comprehensive Loss
# Accumulated Other Comprehensive Loss
# 23
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R24.htm
# 2166116 - Disclosure - Other Long-Term Liabilities
# Other Long-Term Liabilities
# 24
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R25.htm
# 2169117 - Disclosure - Stockholders' Equity
# Stockholders' Equity
# 25
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R26.htm
# 2173118 - Disclosure - Stock-Based Compensation
# Stock-Based Compensation
# 26
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R27.htm
# 2181119 - Disclosure - Fair Value Measurements
# Fair Value Measurements
# 27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R28.htm
# 2184120 - Disclosure - Related-Party Transactions
# Related-Party Transactions
# 28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R29.htm
# 2186121 - Disclosure - Commitments and Contingencies
# Commitments and Contingencies
# 29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R30.htm
# 2188122 - Disclosure - Business Segment Information
# Business Segment Information
# 30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R31.htm
# 2190123 - Disclosure - Unaudited Quarterly Financial Data
# Unaudited Quarterly Financial Data
# 31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R32.htm
# 2193124 - Disclosure - Supplemental Financial Information
# Supplemental Financial Information
# 32
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R33.htm
# 2196125 - Disclosure - Subsequent Events
# Subsequent Events
# 33
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R34.htm
# 2204201 - Disclosure - Summary of Significant Accounting Policies (Policies)
# Summary of Significant Accounting Policies (Policies)
# 34
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R35.htm
# 2308301 - Disclosure - Revenue (Tables)
# Revenue (Tables)
# 35
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R36.htm
# 2313302 - Disclosure - Earnings Per Share (Tables)
# Earnings Per Share (Tables)
# 36
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R37.htm
# 2316303 - Disclosure - Goodwill and Intangible Assets (Tables)
# Goodwill and Intangible Assets (Tables)
# 37
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R38.htm
# 2321304 - Disclosure - Accounts Receivable, Net (Tables)
# Accounts Receivable, Net (Tables)
# 38
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R39.htm
# 2324305 - Disclosure - Property and Equipment, Net (Tables)
# Property and Equipment, Net (Tables)
# 39
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R40.htm
# 2327306 - Disclosure - Accounts Payable and Other Accrued Expenses (Tables)
# Accounts Payable and Other Accrued Expenses (Tables)
# 40
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R41.htm
# 2330307 - Disclosure - Accrued Compensation and Benefits (Tables)
# Accrued Compensation and Benefits (Tables)
# 41
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R42.htm
# 2333308 - Disclosure - Debt (Tables)
# Debt (Tables)
# 42
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R43.htm
# 2339309 - Disclosure - Derivatives (Tables)
# Derivatives (Tables)
# 43
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R44.htm
# 2343310 - Disclosure - Leases (Tables)
# Leases (Tables)
# 44
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R45.htm
# 2348311 - Disclosure - Income Taxes (Tables)
# Income Taxes (Tables)
# 45
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R46.htm
# 2355312 - Disclosure - Employee Benefit Plans (Tables)
# Employee Benefit Plans (Tables)
# 46
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R47.htm
# 2363313 - Disclosure - Accumulated Other Comprehensive Loss (Tables)
# Accumulated Other Comprehensive Loss (Tables)
# 47
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R48.htm
# 2367314 - Disclosure - Other Long-Term Liabilities (Tables)
# Other Long-Term Liabilities (Tables)
# 48
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R49.htm
# 2370315 - Disclosure - Stockholders Equity (Tables)
# Stockholders Equity (Tables)
# 49
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R50.htm
# 2374316 - Disclosure - Stock-Based Compensation (Tables)
# Stock-Based Compensation (Tables)
# 50
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R51.htm
# 2382317 - Disclosure - Fair Value Measurements (Tables)
# Fair Value Measurements (Tables)
# 51
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R52.htm
# 2391318 - Disclosure - Unaudited Quarterly Financial Data (Tables)
# Unaudited Quarterly Financial Data (Tables)
# 52
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R53.htm
# 2394319 - Disclosure - Supplemental Financial Information (Tables)
# Supplemental Financial Information (Tables)
# 53
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R54.htm
# 2402401 - Disclosure - Business Overview (Details)
# Business Overview (Details)
# 54
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R55.htm
# 2405402 - Disclosure - Summary of Significant Accounting Policies - Property, Plant and Equipment (Details)
# Summary of Significant Accounting Policies - Property, Plant and Equipment (Details)
# 55
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R56.htm
# 2406403 - Disclosure - Summary of Significant Accounting Policies - Intangible Assets and Goodwill (Details)
# Summary of Significant Accounting Policies - Intangible Assets and Goodwill (Details)
# 56
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R57.htm
# 2409404 - Disclosure - Revenue - Disaggregation of Revenue (Details)
# Revenue - Disaggregation of Revenue (Details)
# 57
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R58.htm
# 2410405 - Disclosure - Revenue - Narrative (Details)
# Revenue - Narrative (Details)
# 58
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R59.htm
# 2411406 - Disclosure - Revenue - Summary of Contract Balances (Details)
# Revenue - Summary of Contract Balances (Details)
# 59
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R60.htm
# 2414407 - Disclosure - Earnings Per Share (Details)
# Earnings Per Share (Details)
# 60
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R61.htm
# 2417408 - Disclosure - Goodwill and Intangible Assets - Narrative (Details)
# Goodwill and Intangible Assets - Narrative (Details)
# 61
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R62.htm
# 2418409 - Disclosure - Goodwill and Intangible Assets - Schedule of Finite-Lived Intangible Assets (Details)
# Goodwill and Intangible Assets - Schedule of Finite-Lived Intangible Assets (Details)
# 62
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R63.htm
# 2419410 - Disclosure - Goodwill and Intangible Assets - Schedule of Expected Amortization Expense (Details)
# Goodwill and Intangible Assets - Schedule of Expected Amortization Expense (Details)
# 63
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R64.htm
# 2422411 - Disclosure - Accounts Receivable, Net (Details)
# Accounts Receivable, Net (Details)
# 64
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R65.htm
# 2425412 - Disclosure - Property and Equipment, Net (Details)
# Property and Equipment, Net (Details)
# 65
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R66.htm
# 2428413 - Disclosure - Accounts Payable and Other Accrued Expenses (Details)
# Accounts Payable and Other Accrued Expenses (Details)
# 66
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R67.htm
# 2431414 - Disclosure - Accrued Compensation and Benefits (Details)
# Accrued Compensation and Benefits (Details)
# 67
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R68.htm
# 2434415 - Disclosure - Debt - Schedule of Debt (Details)
# Debt - Schedule of Debt (Details)
# 68
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R69.htm
# 2435416 - Disclosure - Debt - Narrative (Details)
# Debt - Narrative (Details)
# 69
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R70.htm
# 2436417 - Disclosure - Debt - Schedule of Future Debt Principal Repayments (Details)
# Debt - Schedule of Future Debt Principal Repayments (Details)
# 70
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R71.htm
# 2437418 - Disclosure - Debt - Schedule of Detail of Interest Expense (Details)
# Debt - Schedule of Detail of Interest Expense (Details)
# 71
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R72.htm
# 2440419 - Disclosure - Derivatives - Narrative (Details)
# Derivatives - Narrative (Details)
# 72
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R73.htm
# 2441420 - Disclosure - Derivatives - Schedule of Effect of Derivatives on Financial Statements (Details)
# Derivatives - Schedule of Effect of Derivatives on Financial Statements (Details)
# 73
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R74.htm
# 2444421 - Disclosure - Leases - Schedule of Lease Cost (Details)
# Leases - Schedule of Lease Cost (Details)
# 74
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R75.htm
# 2445422 - Disclosure - Leases - Future Minimum Obligations for Noncancelable Operating Leases (Details)
# Leases - Future Minimum Obligations for Noncancelable Operating Leases (Details)
# 75
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R76.htm
# 2446423 - Disclosure - Leases - Supplemental Cash Flow and Other Information (Details)
# Leases - Supplemental Cash Flow and Other Information (Details)
# 76
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R77.htm
# 2449424 - Disclosure - Income Taxes - Components of Income Taxes (Details)
# Income Taxes - Components of Income Taxes (Details)
# 77
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R78.htm
# 2450425 - Disclosure - Income Taxes - Reconciliation of Income Tax (Details)
# Income Taxes - Reconciliation of Income Tax (Details)
# 78
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R79.htm
# 2451426 - Disclosure - Income Taxes - Narrative (Details)
# Income Taxes - Narrative (Details)
# 79
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R80.htm
# 2452427 - Disclosure - Income Taxes - Schedule of Income Tax Receivable and Payable (Details)
# Income Taxes - Schedule of Income Tax Receivable and Payable (Details)
# 80
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R81.htm
# 2453428 - Disclosure - Income Taxes - Components of Net Deferred Income Taxes (Details)
# Income Taxes - Components of Net Deferred Income Taxes (Details)
# 81
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R82.htm
# 2456429 - Disclosure - Employee Benefit Plans - Narrative (Details)
# Employee Benefit Plans - Narrative (Details)
# 82
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R83.htm
# 2457430 - Disclosure - Employee Benefit Plans - Components of Net Postretirement Medical Expense (Details)
# Employee Benefit Plans - Components of Net Postretirement Medical Expense (Details)
# 83
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R84.htm
# 2458431 - Disclosure - Employee Benefit Plans - Healthcare Cost Trend Rates (Details)
# Employee Benefit Plans - Healthcare Cost Trend Rates (Details)
# 84
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R85.htm
# 2459432 - Disclosure - Employee Benefit Plans - Change in Benefit Obligation and Change in Plan Assets (Details)
# Employee Benefit Plans - Change in Benefit Obligation and Change in Plan Assets (Details)
# 85
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R86.htm
# 2460433 - Disclosure - Employee Benefit Plans - Future Benefit Payments (Details)
# Employee Benefit Plans - Future Benefit Payments (Details)
# 86
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R87.htm
# 2461434 - Disclosure - Employee Benefit Plans - Weighted Average Discount Rate (Details)
# Employee Benefit Plans - Weighted Average Discount Rate (Details)
# 87
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R88.htm
# 2464435 - Disclosure - Accumulated Other Comprehensive Loss - Schedule of Changes in Accumulated Other Comprehensive Income (Loss) (Details)
# Accumulated Other Comprehensive Loss - Schedule of Changes in Accumulated Other Comprehensive Income (Loss) (Details)
# 88
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R89.htm
# 2465436 - Disclosure - Accumulated Other Comprehensive Loss - Schedule of Reclassifications out of Accumulated Other Comprehensive Loss to Net Income (Details)
# Accumulated Other Comprehensive Loss - Schedule of Reclassifications out of Accumulated Other Comprehensive Loss to Net Income (Details)
# 89
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R90.htm
# 2468437 - Disclosure - Other Long-Term Liabilities (Details)
# Other Long-Term Liabilities (Details)
# 90
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R91.htm
# 2471438 - Disclosure - Stockholders' Equity - Narrative (Details)
# Stockholders' Equity - Narrative (Details)
# 91
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R92.htm
# 2472439 - Disclosure - Stockholders' Equity - Summary of Dividends (Details)
# Stockholders' Equity - Summary of Dividends (Details)
# 92
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R93.htm
# 2475440 - Disclosure - Stock-Based Compensation - Stock-based Compensation Expense (Details)
# Stock-Based Compensation - Stock-based Compensation Expense (Details)
# 93
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R94.htm
# 2476441 - Disclosure - Stock-Based Compensation - Summary of Unrecognized Compensation (Details)
# Stock-Based Compensation - Summary of Unrecognized Compensation (Details)
# 94
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R95.htm
# 2477442 - Disclosure - Stock-Based Compensation - Summary of Stock Plans (Details)
# Stock-Based Compensation - Summary of Stock Plans (Details)
# 95
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R96.htm
# 2478443 - Disclosure - Stock-Based Compensation - Stock Option Assumptions (Details)
# Stock-Based Compensation - Stock Option Assumptions (Details)
# 96
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R97.htm
# 2479444 - Disclosure - Stock-Based Compensation - Stock Option and Restricted Stock Award Activity (Details)
# Stock-Based Compensation - Stock Option and Restricted Stock Award Activity (Details)
# 97
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R98.htm
# 2480445 - Disclosure - Stock-Based Compensation - Employee Stock purchase Plan (Details)
# Stock-Based Compensation - Employee Stock purchase Plan (Details)
# 98
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R99.htm
# 2483446 - Disclosure - Fair Value Measurements - Schedule of Recurring Fair Value Measurements (Details)
# Fair Value Measurements - Schedule of Recurring Fair Value Measurements (Details)
# 99
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R100.htm
# 2485447 - Disclosure - Related-Party Transactions (Details)
# Related-Party Transactions (Details)
# 100
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R101.htm
# 2487448 - Disclosure - Commitments and Contingencies - Government Contracting and Guarantees (Details)
# Commitments and Contingencies - Government Contracting and Guarantees (Details)
# 101
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R102.htm
# 2489449 - Disclosure - Business Segment Information (Details)
# Business Segment Information (Details)
# 102
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R103.htm
# 2492450 - Disclosure - Unaudited Quarterly Financial Data (Details)
# Unaudited Quarterly Financial Data (Details)
# 103
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R104.htm
# 2495451 - Disclosure - Supplemental Financial Information (Details)
# Supplemental Financial Information (Details)
# 104
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/R105.htm
# 2497452 - Disclosure - Subsequent Events (Details)
# Subsequent Events (Details)
# 105
# ['1443646', 'Booz Allen Hamilton Holding Corp', '10-K', '2020-05-26', 'edgar/data/1443646/0001443646-20-000086.txt', 'edgar/data/1443646/0001443646-20-000086-index.html\r']
# ----------------------------------------------------------------------------------------------------
# File Name: FilingSummary.xml
# File Path: https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/FilingSummary.xml
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R1.htm
# 0001000 - Document - Cover
# Cover
# 1
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R2.htm
# 1001000 - Statement - Consolidated Balance Sheets
# Consolidated Balance Sheets
# 2
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R3.htm
# 1001501 - Statement - Consolidated Balance Sheets (Parenthetical)
# Consolidated Balance Sheets (Parenthetical)
# 3
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R4.htm
# 1002000 - Statement - Consolidated Statements of Operations
# Consolidated Statements of Operations
# 4
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R5.htm
# 1003000 - Statement - Consolidated Statements of Comprehensive Income
# Consolidated Statements of Comprehensive Income
# 5
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R6.htm
# 1004000 - Statement - Consolidated Statements of Cash Flows
# Consolidated Statements of Cash Flows
# 6
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R7.htm
# 1005000 - Statement - Consolidated Statements of Stockholders' Equity
# Consolidated Statements of Stockholders' Equity
# 7
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R8.htm
# 1005001 - Statement - Consolidated Statements of Stockholders' Equity Consolidated Statements of Stockholders' Equity (Parenthetical)
# Consolidated Statements of Stockholders' Equity Consolidated Statements of Stockholders' Equity (Parenthetical)
# 8
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R9.htm
# 2101100 - Disclosure - Business Overview
# Business Overview
# 9
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R10.htm
# 2102100 - Disclosure - Summary of Significant Accounting Policies
# Summary of Significant Accounting Policies
# 10
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R11.htm
# 2103100 - Disclosure - Revenue
# Revenue
# 11
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R12.htm
# 2104100 - Disclosure - Earnings Per Share
# Earnings Per Share
# 12
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R13.htm
# 2111100 - Disclosure - Goodwill and Intangible Assets
# Goodwill and Intangible Assets
# 13
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R14.htm
# 2112100 - Disclosure - Accounts Receivable, Net of Allowance
# Accounts Receivable, Net of Allowance
# 14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R15.htm
# 2114100 - Disclosure - Property and Equipment, Net
# Property and Equipment, Net
# 15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R16.htm
# 2115100 - Disclosure - Accounts Payable and Other Accrued Expenses
# Accounts Payable and Other Accrued Expenses
# 16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R17.htm
# 2118100 - Disclosure - Accrued Compensation and Benefits
# Accrued Compensation and Benefits
# 17
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R18.htm
# 2119100 - Disclosure - Deferred Payment Obligation
# Deferred Payment Obligation
# 18
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R19.htm
# 2120100 - Disclosure - Debt
# Debt
# 19
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R20.htm
# 2121100 - Disclosure - Derivatives
# Derivatives
# 20
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R21.htm
# 2122100 - Disclosure - Leases (Notes)
# Leases (Notes)
# 21
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R22.htm
# 2123100 - Disclosure - Income Taxes
# Income Taxes
# 22
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R23.htm
# 2125100 - Disclosure - Employee Benefit Plans
# Employee Benefit Plans
# 23
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R24.htm
# 2126100 - Disclosure - Accumulated Other Comprehensive Loss
# Accumulated Other Comprehensive Loss
# 24
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R25.htm
# 2127100 - Disclosure - Other Long-Term Liabilities
# Other Long-Term Liabilities
# 25
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R26.htm
# 2129100 - Disclosure - Stockholders' Equity
# Stockholders' Equity
# 26
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R27.htm
# 213100 - Disclosure - Related-Party Transactions
# Related-Party Transactions
# 27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R28.htm
# 2131100 - Disclosure - Stock-Based Compensation
# Stock-Based Compensation
# 28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R29.htm
# 2133100 - Disclosure - Fair Value Measurements
# Fair Value Measurements
# 29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R30.htm
# 2134100 - Disclosure - Commitments and Contingencies
# Commitments and Contingencies
# 30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R31.htm
# 2135100 - Disclosure - Business Segment Information
# Business Segment Information
# 31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R32.htm
# 2136100 - Disclosure - Unaudited Quarterly Financial Data
# Unaudited Quarterly Financial Data
# 32
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R33.htm
# 2137100 - Disclosure - Supplemental Financial Information
# Supplemental Financial Information
# 33
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R34.htm
# 2138100 - Disclosure - Subsequent Events
# Subsequent Events
# 34
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R35.htm
# 2202201 - Disclosure - Summary of Significant Accounting Policies (Policies)
# Summary of Significant Accounting Policies (Policies)
# 35
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R36.htm
# 2302302 - Disclosure - Summary of Significant Accounting Policies (Tables)
# Summary of Significant Accounting Policies (Tables)
# 36
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R37.htm
# 2303301 - Disclosure - Revenue (Tables)
# Revenue (Tables)
# 37
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R38.htm
# 2304301 - Disclosure - Earnings Per Share (Tables)
# Earnings Per Share (Tables)
# 38
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R39.htm
# 2311301 - Disclosure - Goodwill and Intangible Assets (Tables)
# Goodwill and Intangible Assets (Tables)
# 39
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R40.htm
# 2312301 - Disclosure - Accounts Receivable, Net of Allowance (Tables)
# Accounts Receivable, Net of Allowance (Tables)
# 40
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R41.htm
# 2314301 - Disclosure - Property and Equipment, Net (Tables)
# Property and Equipment, Net (Tables)
# 41
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R42.htm
# 2315301 - Disclosure - Accounts Payable and Other Accrued Expenses (Tables)
# Accounts Payable and Other Accrued Expenses (Tables)
# 42
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R43.htm
# 2318301 - Disclosure - Accrued Compensation and Benefits (Tables)
# Accrued Compensation and Benefits (Tables)
# 43
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R44.htm
# 2320301 - Disclosure - Debt (Tables)
# Debt (Tables)
# 44
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R45.htm
# 2321301 - Disclosure - Derivatives (Tables)
# Derivatives (Tables)
# 45
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R46.htm
# 2322301 - Disclosure - Leases (Tables)
# Leases (Tables)
# 46
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R47.htm
# 2323301 - Disclosure - Income Taxes (Tables)
# Income Taxes (Tables)
# 47
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R48.htm
# 2325301 - Disclosure - Employee Benefit Plans (Tables)
# Employee Benefit Plans (Tables)
# 48
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R49.htm
# 2326301 - Disclosure - Accumulated Other Comprehensive Loss (Tables)
# Accumulated Other Comprehensive Loss (Tables)
# 49
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R50.htm
# 2327301 - Disclosure - Other Long-Term Liabilities (Tables)
# Other Long-Term Liabilities (Tables)
# 50
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R51.htm
# 2329301 - Disclosure - Stockholders Equity (Tables)
# Stockholders Equity (Tables)
# 51
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R52.htm
# 2331301 - Disclosure - Stock-Based Compensation (Tables)
# Stock-Based Compensation (Tables)
# 52
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R53.htm
# 2333301 - Disclosure - Fair Value Measurements (Tables)
# Fair Value Measurements (Tables)
# 53
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R54.htm
# 2336301 - Disclosure - Unaudited Quarterly Financial Data (Tables)
# Unaudited Quarterly Financial Data (Tables)
# 54
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R55.htm
# 2337301 - Disclosure - Supplemental Financial Information (Tables)
# Supplemental Financial Information (Tables)
# 55
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R56.htm
# 2401401 - Disclosure - Business Overview (Details)
# Business Overview (Details)
# 56
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R57.htm
# 2402403 - Disclosure - Summary of Significant Accounting Policies - Property, Plant and Equipment (Details)
# Summary of Significant Accounting Policies - Property, Plant and Equipment (Details)
# 57
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R58.htm
# 2402404 - Disclosure - Summary of Significant Accounting Policies - Intangible Assets and Goodwill (Details)
# Summary of Significant Accounting Policies - Intangible Assets and Goodwill (Details)
# 58
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R59.htm
# 2402405 - Disclosure - Summary of Significant Accounting Policies - Recent Accounting Pronouncements (Details)
# Summary of Significant Accounting Policies - Recent Accounting Pronouncements (Details)
# 59
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R60.htm
# 2402406 - Disclosure - Summary of Significant Accounting Policies - Schedule of Effect of Adoption (Details)
# Summary of Significant Accounting Policies - Schedule of Effect of Adoption (Details)
# 60
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364620000086/R61.htm
# 2403402 - Disclosure - Revenue - Disaggregation of Revenue (Details)
# ...
# 2419404 - Disclosure - Employee Benefit Plans (Weighted Average Discount Rate) (Details)
# Employee Benefit Plans (Weighted Average Discount Rate) (Details)
# 76
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R77.htm
# 2419405 - Disclosure - Employee Benefit Plans (Healthcare Cost Trend Rates) (Details)
# Employee Benefit Plans (Healthcare Cost Trend Rates) (Details)
# 77
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R78.htm
# 2419406 - Disclosure - Employee Benefit Plans (Retired Officers' Bonus Plan) (Details)
# Employee Benefit Plans (Retired Officers' Bonus Plan) (Details)
# 78
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R79.htm
# 2419407 - Disclosure - Employee Benefit Plans Employee Benefit Plans (Accumulated Other Comprehensive Income) (Details)
# Employee Benefit Plans Employee Benefit Plans (Accumulated Other Comprehensive Income) (Details)
# 79
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R80.htm
# 2419408 - Disclosure - Employee Benefit Plans Employee Benefit Plans (Change in Benefit Obligation and Change in Plan Assets) (Details)
# Employee Benefit Plans Employee Benefit Plans (Change in Benefit Obligation and Change in Plan Assets) (Details)
# 80
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R81.htm
# 2419409 - Disclosure - Employee Benefit Plans Employee Benefit Plans (Future Benefit Payments) (Details)
# Employee Benefit Plans Employee Benefit Plans (Future Benefit Payments) (Details)
# 81
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R82.htm
# 2420402 - Disclosure - Accumulated Other Comprehensive Loss (Details)
# Accumulated Other Comprehensive Loss (Details)
# 82
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R83.htm
# 2420403 - Disclosure - Accumulated Other Comprehensive Loss (Reclassifications out of Accumulated Other Comprehensive Loss to Net Income) (Details)
# Accumulated Other Comprehensive Loss (Reclassifications out of Accumulated Other Comprehensive Loss to Net Income) (Details)
# 83
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R84.htm
# 2421402 - Disclosure - Other Long-Term Liabilities (Details)
# Other Long-Term Liabilities (Details)
# 84
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R85.htm
# 2422401 - Disclosure - Stockholders' Equity (Common Stock Shares Activity) (Details)
# Stockholders' Equity (Common Stock Shares Activity) (Details)
# 85
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R86.htm
# 2422402 - Disclosure - Stockholders' Equity (Employee Stock Purchase Plan and Share Repurchase Program) (Details)
# Stockholders' Equity (Employee Stock Purchase Plan and Share Repurchase Program) (Details)
# 86
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R87.htm
# 2422403 - Disclosure - Stockholders' Equity (Dividends) (Details)
# Stockholders' Equity (Dividends) (Details)
# 87
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R88.htm
# 2423402 - Disclosure - Stock-Based Compensation (Stock-based Compensation Expense) (Details)
# Stock-Based Compensation (Stock-based Compensation Expense) (Details)
# 88
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R89.htm
# 2423403 - Disclosure - Stock Based Compensation (Unrecognized Compensation) (Details)
# Stock Based Compensation (Unrecognized Compensation) (Details)
# 89
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R90.htm
# 2423404 - Disclosure - Stock-Based Compensation (Stock Plans) (Details)
# Stock-Based Compensation (Stock Plans) (Details)
# 90
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R91.htm
# 2423405 - Disclosure - Stock-Based Compensation (Stock Option Assumptions) (Details)
# Stock-Based Compensation (Stock Option Assumptions) (Details)
# 91
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R92.htm
# 2423406 - Disclosure - Stock-Based Compensation (Recorded and Unrecorded Stock-based Compensation Liability) (Details)
# Stock-Based Compensation (Recorded and Unrecorded Stock-based Compensation Liability) (Details)
# 92
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R93.htm
# 2423407 - Disclosure - Stock-Based Compensation Stock Option Activity (Details)
# Stock-Based Compensation Stock Option Activity (Details)
# 93
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R94.htm
# 2425401 - Disclosure - Related-Party Transactions (Details)
# Related-Party Transactions (Details)
# 94
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R95.htm
# 2426402 - Disclosure - Commitments and Contingecies (Details)
# Commitments and Contingecies (Details)
# 95
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R96.htm
# 2426403 - Disclosure - Commitments and Contingencies (Litigation) (Details)
# Commitments and Contingencies (Litigation) (Details)
# 96
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R97.htm
# 2427401 - Disclosure - Business Segment Information Business Segment Information (Details)
# Business Segment Information Business Segment Information (Details)
# 97
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R98.htm
# 2429402 - Disclosure - Unaudited Quarterly Financial Data Unaudited Quarterly Financial Data (Details)
# Unaudited Quarterly Financial Data Unaudited Quarterly Financial Data (Details)
# 98
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000144364613000010/R99.htm
# 2431402 - Disclosure - Supplemental Financial Information (Details)
# Supplemental Financial Information (Details)
# 99
# ['1443646', 'Booz Allen Hamilton Holding Corp', '10-K', '2012-05-30', 'edgar/data/1443646/0001193125-12-253723.txt', 'edgar/data/1443646/0001193125-12-253723-index.html\r']
# ----------------------------------------------------------------------------------------------------
# File Name: FilingSummary.xml
# File Path: https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/FilingSummary.xml
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R1.htm
# 00 - Document - Document and Entity Information
# Document and Entity Information
# 1
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R2.htm
# 01 - Statement - Consolidated Balance Sheets
# Consolidated Balance Sheets
# 2
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R3.htm
# 011 - Statement - Consolidated Balance Sheets (Parenthetical)
# Consolidated Balance Sheets (Parenthetical)
# 3
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R4.htm
# 02 - Statement - Consolidated Statements of Operations
# Consolidated Statements of Operations
# 4
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R5.htm
# 03 - Statement - Consolidated Statements of Comprehensive Income
# Consolidated Statements of Comprehensive Income
# 5
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R6.htm
# 04 - Statement - Consolidated Statements of Cash Flows
# Consolidated Statements of Cash Flows
# 6
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R7.htm
# 05 - Statement - Consolidated Statements of Stockholders' Equity
# Consolidated Statements of Stockholders' Equity
# 7
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R8.htm
# 06001 - Disclosure - Overview
# Overview
# 8
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R9.htm
# 06002 - Disclosure - Summary of Significant Accounting Policies
# Summary of Significant Accounting Policies
# 9
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R10.htm
# 06003 - Disclosure - Earnings Per Share
# Earnings Per Share
# 10
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R11.htm
# 06004 - Disclosure - Restructuring Charge
# Restructuring Charge
# 11
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R12.htm
# 06005 - Disclosure - Goodwill and Intangible Assets
# Goodwill and Intangible Assets
# 12
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R13.htm
# 06006 - Disclosure - Accounts Receivable, Net
# Accounts Receivable, Net
# 13
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R14.htm
# 06007 - Disclosure - Property and Equipment, Net
# Property and Equipment, Net
# 14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R15.htm
# 06008 - Disclosure - Accounts Payable and Other Accrued Expenses
# Accounts Payable and Other Accrued Expenses
# 15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R16.htm
# 06009 - Disclosure - Accrued Compensation and Benefits
# Accrued Compensation and Benefits
# 16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R17.htm
# 06010 - Disclosure - Deferred Payment Obligation
# Deferred Payment Obligation
# 17
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R18.htm
# 06011 - Disclosure - Debt
# Debt
# 18
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R19.htm
# 06012 - Disclosure - Deferred Financing Costs
# Deferred Financing Costs
# 19
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R20.htm
# 06013 - Disclosure - Income Taxes
# Income Taxes
# 20
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R21.htm
# 06014 - Disclosure - Employee Benefit Plans
# Employee Benefit Plans
# 21
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R22.htm
# 06015 - Disclosure - Other Long-Term Liabilities
# Other Long-Term Liabilities
# 22
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R23.htm
# 06016 - Disclosure - Stockholders' Equity
# Stockholders' Equity
# 23
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R24.htm
# 06017 - Disclosure - Stock-Based Compensation
# Stock-Based Compensation
# 24
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R25.htm
# 06018 - Disclosure - Related-Party Transactions
# Related-Party Transactions
# 25
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R26.htm
# 06019 - Disclosure - Commitments and Contingencies
# Commitments and Contingencies
# 26
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R27.htm
# 06020 - Disclosure - Business Segment Information
# Business Segment Information
# 27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R28.htm
# 06021 - Disclosure - Unaudited Quarterly Financial Data
# Unaudited Quarterly Financial Data
# 28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R29.htm
# 06022 - Disclosure - Supplemental Financial Information
# Supplemental Financial Information
# 29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1443646/000119312512253723/R30.htm
# 06023 - Disclosure - Subsequent Events
# Subsequent Events
# 30

# %%
#print the name of the documents in a given year
for i in range(len(dfs[0])):
    print(dfs[0][i].index.name)
    
#check if the documents are consistent year-to-year (otherwise might have to make manual adjustment)
for j in range(len(dfs)):
    print(len(dfs[j]))

num_docs = len(dfs[0])
# Out:
# Consolidated Balance Sheets - USD ($) $ in Thousands
# Consolidated Statements of Operations - USD ($) $ in Thousands
# Consolidated Statements of Comprehensive Income - USD ($) $ in Thousands
# Consolidated Statements of Cash Flows - USD ($) $ in Thousands
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4

# %%
dfs[0][1].head(10)
# Out:
#                                                     Mar. 31, 2021
# Consolidated Statements of Operations - USD ($)...
# INCOME STATEMENT [ABSTRACT]-1                                 NaN
# Revenue-1                                               7858938.0
# OPERATING COSTS AND EXPENSES:-2                               NaN
# Cost of revenue-2                                       3657530.0
# Billable expenses-2                                     2325888.0
# General and administrative expenses-2                   1036834.0
# Depreciation and amortization-2                           84315.0
# Total operating costs and expenses-2                    7104567.0
# Operating income-2                                       754371.0
# Interest expense-2                                       -81270.0

# %%
dfd = [ele[3] for ele in dfs]
pd.concat(dfd, axis=1)
# Out:
#                                                     Mar. 31, 2021  \
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             608958.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           84315.0
# Noncash lease expense-2                                   53202.0
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2020  \
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             482603.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           81081.0
# Noncash lease expense-2                                   55096.0
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2019  \
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             418529.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           68575.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2018  \
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             305111.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           64756.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2017  \
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             252490.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           59544.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2016  \
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             294094.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           61536.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2015  \
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             232569.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           62660.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2014  \
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             232188.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           72327.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2013  \
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             219058.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           74009.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2012
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             239955.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           75205.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...        23332.0
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5         192631.0
# Cash and cash equivalents--end of period-5               484368.0
#
# [97 rows x 10 columns]

# %%
num_docs = len(dfs[0])

multi_year_statements = []

for i in range(num_docs):
    year_statements = [ele[i] for ele in dfs]
    multi_year_statements.append(year_statements)
        
    

combined_financial_statements = []    
for i in range(len(multi_year_statements)):
    combined_fs = pd.concat(multi_year_statements[i], axis=1)
    combined_fs.index.name = multi_year_statements[i][0].index.name
    combined_financial_statements.append(combined_fs)

balance_sheet = pd.concat(multi_year_statements[0], axis=1)

combined_financial_statements[3]
# Out:
#                                                     Mar. 31, 2021  \
# Consolidated Statements of Cash Flows - USD ($)...
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             608958.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           84315.0
# Noncash lease expense-2                                   53202.0
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2020  \
# Consolidated Statements of Cash Flows - USD ($)...
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             482603.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           81081.0
# Noncash lease expense-2                                   55096.0
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2019  \
# Consolidated Statements of Cash Flows - USD ($)...
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             418529.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           68575.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2018  \
# Consolidated Statements of Cash Flows - USD ($)...
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             305111.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           64756.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2017  \
# Consolidated Statements of Cash Flows - USD ($)...
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             252490.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           59544.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2016  \
# Consolidated Statements of Cash Flows - USD ($)...
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             294094.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           61536.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2015  \
# Consolidated Statements of Cash Flows - USD ($)...
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             232569.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           62660.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2014  \
# Consolidated Statements of Cash Flows - USD ($)...
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             232188.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           72327.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2013  \
# Consolidated Statements of Cash Flows - USD ($)...
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             219058.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           74009.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...            NaN
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5              NaN
# Cash and cash equivalents--end of period-5                    NaN
#
#                                                     Mar. 31, 2012
# Consolidated Statements of Cash Flows - USD ($)...
# CASH FLOWS FROM OPERATING ACTIVITIES-1                        NaN
# Net income-1                                             239955.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO NET CASH...            NaN
# Depreciation and amortization-2                           75205.0
# Noncash lease expense-2                                       NaN
# ...                                                           ...
# Escrow payments-4                                             NaN
# Proceeds from sale of state and local transport...        23332.0
# Net proceeds from debt-5                                      NaN
# Cash and cash equivalents--beginning of period-5         192631.0
# Cash and cash equivalents--end of period-5               484368.0
#
# [97 rows x 10 columns]

# %%
with pd.ExcelWriter("Booz_Allen_finanical_statements.xlsx") as writer:
        combined_financial_statements[0].to_excel(writer, sheet_name='Balance Sheets')
        combined_financial_statements[1].to_excel(writer, sheet_name='Statements of Operations')
        combined_financial_statements[2].to_excel(writer, sheet_name='Comprehensive Income')
        combined_financial_statements[3].to_excel(writer, sheet_name='Statements of Cash Flow')

# %%
string = r"Consolidated Statements of Cash Flows - USD ( )  in Thousands"
print(string[0:30])
# Out:
# Consolidated Statements of Cas

# %%
multi_year_statements

# %%
print('-'*1000)
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Info on the company you want to analyze

# %%
#look into master index file for precise spelling
#selectedcompany = 'Booz Allen Hamilton Holding Corp'

selectedcompany = r'Booz'



#select a year you are interested in
selectedyear = 2020

#make sure to put in report exact (10-K vs 10-k)
selectedreport = "10-K"

master_index_file = str(selectedyear) + '-' + find_10k_quarter(selectedcompany, selectedreport, selectedyear) + '.tsv'


#define a user agent for access to the SEC Edgar servers (use browser)
user_agent = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36 Edg/97.0.1072.62"}

print(selectedcompany)
print(master_index_file)
# Out:
# Corsair
# 2021-QTR1.tsv

# %% [markdown]
# ### Runs Scrape (In Steps)

# %%
# get the index info from downloaded master index
filing_index = get_index_info_on_company(selectedcompany, selectedreport, master_index_file)
# Out:
# ['1743759', 'Corsair Gaming, Inc.', '10-K', '2021-03-11', 'edgar/data/1743759/0001564590-21-012507.txt', 'edgar/data/1743759/0001564590-21-012507-index.html\r']

# %%
#obtain an xml summary of the file in question
xml_summary = get_xml_summary_of_file(selectedcompany, selectedreport, master_index_file, user_agent)
# Out:
# ----------------------------------------------------------------------------------------------------
# File Name: FilingSummary.xml
# File Path: https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/FilingSummary.xml

# %%
#generate a master list of sections in the xml file to search
master_reports = parse_xml_summary_of_file(xml_summary, user_agent)
# Out:
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R1.htm
# 100000 - Document - Document and Entity Information
# Document and Entity Information
# 1
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R2.htm
# 100010 - Statement - Combined Consolidated Statements of Operations
# Combined Consolidated Statements of Operations
# 2
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R3.htm
# 100020 - Statement - Combined Consolidated Statements of Comprehensive Income (Loss)
# Combined Consolidated Statements of Comprehensive Income (Loss)
# 3
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R4.htm
# 100030 - Statement - Combined Consolidated Statements of Comprehensive Income (Loss) (Parenthetical)
# Combined Consolidated Statements of Comprehensive Income (Loss) (Parenthetical)
# 4
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R5.htm
# 100040 - Statement - Combined Consolidated Balance Sheets
# Combined Consolidated Balance Sheets
# 5
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R6.htm
# 100050 - Statement - Combined Consolidated Balance Sheets (Parenthetical)
# Combined Consolidated Balance Sheets (Parenthetical)
# 6
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R7.htm
# 100060 - Statement - Combined Consolidated Statements of Stockholders' Equity
# Combined Consolidated Statements of Stockholders' Equity
# 7
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R8.htm
# 100070 - Statement - Combined Consolidated Statements of Cash Flows
# Combined Consolidated Statements of Cash Flows
# 8
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R9.htm
# 100080 - Statement - Combined Consolidated Statements of Cash Flows (Parenthetical)
# Combined Consolidated Statements of Cash Flows (Parenthetical)
# 9
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R10.htm
# 100090 - Disclosure - Description of Business
# Description of Business
# 10
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R11.htm
# 100100 - Disclosure - Summary of Significant Accounting Policies
# Summary of Significant Accounting Policies
# 11
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R12.htm
# 100110 - Disclosure - Fair Value Measurement
# Fair Value Measurement
# 12
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R13.htm
# 100120 - Disclosure - Derivative Financial Instruments
# Derivative Financial Instruments
# 13
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R14.htm
# 100130 - Disclosure - Business Combinations
# Business Combinations
# 14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R15.htm
# 100140 - Disclosure - Goodwill and Intangible Assets
# Goodwill and Intangible Assets
# 15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R16.htm
# 100150 - Disclosure - Balance Sheet Components
# Balance Sheet Components
# 16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R17.htm
# 100160 - Disclosure - Debt
# Debt
# 17
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R18.htm
# 100170 - Disclosure - Commitments and Contingencies
# Commitments and Contingencies
# 18
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R19.htm
# 100180 - Disclosure - Stockholders??? Equity
# Stockholders??? Equity
# 19
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R20.htm
# 100190 - Disclosure - Equity Incentive Plans and Stock-Based Compensation
# Equity Incentive Plans and Stock-Based Compensation
# 20
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R21.htm
# 100200 - Disclosure - Net Income (Loss) Per Share
# Net Income (Loss) Per Share
# 21
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R22.htm
# 100210 - Disclosure - Income Taxes
# Income Taxes
# 22
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R23.htm
# 100220 - Disclosure - Accumulated Other Comprehensive Income (Loss)
# Accumulated Other Comprehensive Income (Loss)
# 23
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R24.htm
# 100230 - Disclosure - Related-Party Transactions
# Related-Party Transactions
# 24
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R25.htm
# 100240 - Disclosure - Segment and Geographic Information
# Segment and Geographic Information
# 25
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R26.htm
# 100250 - Disclosure - Leases
# Leases
# 26
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R27.htm
# 100260 - Disclosure - Selected Quarterly Financial Data (Unaudited)
# Selected Quarterly Financial Data (Unaudited)
# 27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R28.htm
# 100270 - Disclosure - Schedule II - Valuation and Qualifying Accounts
# Schedule II - Valuation and Qualifying Accounts
# 28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R29.htm
# 100280 - Disclosure - Description of Business (Policies)
# Description of Business (Policies)
# 29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R30.htm
# 100290 - Disclosure - Summary of Significant Accounting Policies (Policies)
# Summary of Significant Accounting Policies (Policies)
# 30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R31.htm
# 100300 - Disclosure - Fair Value Measurement (Tables)
# Fair Value Measurement (Tables)
# 31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R32.htm
# 100310 - Disclosure - Business Combinations (Tables)
# Business Combinations (Tables)
# 32
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R33.htm
# 100320 - Disclosure - Goodwill and Intangible Assets (Tables)
# Goodwill and Intangible Assets (Tables)
# 33
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R34.htm
# 100330 - Disclosure - Balance Sheet Components (Tables)
# Balance Sheet Components (Tables)
# 34
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R35.htm
# 100340 - Disclosure - Debt (Tables)
# Debt (Tables)
# 35
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R36.htm
# 100350 - Disclosure - Commitments and Contingencies (Tables)
# Commitments and Contingencies (Tables)
# 36
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R37.htm
# 100360 - Disclosure - Equity Incentive Plans and Stock-Based Compensation (Tables)
# Equity Incentive Plans and Stock-Based Compensation (Tables)
# 37
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R38.htm
# 100370 - Disclosure - Net Income (Loss) Per Share (Tables)
# Net Income (Loss) Per Share (Tables)
# 38
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R39.htm
# 100380 - Disclosure - Income Taxes (Tables)
# Income Taxes (Tables)
# 39
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R40.htm
# 100390 - Disclosure - Accumulated Other Comprehensive Income (Loss) (Tables)
# Accumulated Other Comprehensive Income (Loss) (Tables)
# 40
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R41.htm
# 100400 - Disclosure - Segment and Geographic Information (Tables)
# Segment and Geographic Information (Tables)
# 41
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R42.htm
# 100410 - Disclosure - Leases (Tables)
# Leases (Tables)
# 42
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R43.htm
# 100420 - Disclosure - Selected Quarterly Financial Data (Unaudited) (Tables)
# Selected Quarterly Financial Data (Unaudited) (Tables)
# 43
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R44.htm
# 100430 - Disclosure - Description of Business and Basis of Presentation - Additional Information (Detail)
# Description of Business and Basis of Presentation - Additional Information (Detail)
# 44
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R45.htm
# 100440 - Disclosure - Summary of Significant Accounting Policies - Additional Information (Detail)
# Summary of Significant Accounting Policies - Additional Information (Detail)
# 45
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R46.htm
# 100450 - Disclosure - Summary of Significant Accounting Policies - Additional Information (Detail1)
# Summary of Significant Accounting Policies - Additional Information (Detail1)
# 46
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R47.htm
# 100460 - Disclosure - Fair Value Measurement - Summary of Financial Assets and Liabilities that Measured at Fair Value (Details)
# Fair Value Measurement - Summary of Financial Assets and Liabilities that Measured at Fair Value (Details)
# 47
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R48.htm
# 100470 - Disclosure - Fair Value Measurement - Summary of Financial Assets and Liabilities that Measured at Fair Value (Parenthetical) (Details)
# Fair Value Measurement - Summary of Financial Assets and Liabilities that Measured at Fair Value (Parenthetical) (Details)
# 48
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R49.htm
# 100480 - Disclosure - Derivative Financial Instruments - Additional Information (Detail)
# Derivative Financial Instruments - Additional Information (Detail)
# 49
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R50.htm
# 100490 - Disclosure - Business Combinations - Additional Information (Details)
# Business Combinations - Additional Information (Details)
# 50
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R51.htm
# 100500 - Disclosure - Business Combinations - Summary of Estimated Fair Value of Assets Acquired and Liabilities Assumed (Details)
# Business Combinations - Summary of Estimated Fair Value of Assets Acquired and Liabilities Assumed (Details)
# 51
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R52.htm
# 100510 - Disclosure - Business Combinations - Summary of Components of Identifiable Assets Acquired and Estimated Useful Lives (Details)
# Business Combinations - Summary of Components of Identifiable Assets Acquired and Estimated Useful Lives (Details)
# 52
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R53.htm
# 100520 - Disclosure - Business Combinations - Summary of Estimated Fair Value of Assets Acquired and Liabilities Assumed (Parenthetical) (Details)
# Business Combinations - Summary of Estimated Fair Value of Assets Acquired and Liabilities Assumed (Parenthetical) (Details)
# 53
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R54.htm
# 100530 - Disclosure - Business Combinations - Business Acquisition, Pro Forma Financial Information (Details)
# Business Combinations - Business Acquisition, Pro Forma Financial Information (Details)
# 54
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R55.htm
# 100540 - Disclosure - Goodwill and Intangible Assets - Additional Information (Detail)
# Goodwill and Intangible Assets - Additional Information (Detail)
# 55
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R56.htm
# 100550 - Disclosure - Goodwill and Intangible Assets - Summary of Changes in Carrying Amount of Goodwill by Reportable Segment (Detail)
# Goodwill and Intangible Assets - Summary of Changes in Carrying Amount of Goodwill by Reportable Segment (Detail)
# 56
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R57.htm
# 100560 - Disclosure - Goodwill and Intangible Assets - Summary of Intangible Assets, Net (Detail)
# Goodwill and Intangible Assets - Summary of Intangible Assets, Net (Detail)
# 57
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R58.htm
# 100570 - Disclosure - Goodwill and Intangible Assets - Summary of Recognized Amortization Expense of Intangible Assets (Detail)
# Goodwill and Intangible Assets - Summary of Recognized Amortization Expense of Intangible Assets (Detail)
# 58
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R59.htm
# 100580 - Disclosure - Goodwill and Intangible Assets - Schedule of Estimated Future Amortization Expense of Intangible Assets (Detail)
# Goodwill and Intangible Assets - Schedule of Estimated Future Amortization Expense of Intangible Assets (Detail)
# 59
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R60.htm
# 100590 - Disclosure - Balance Sheet Components - Summary of Cash and Restricted Cash (Details)
# Balance Sheet Components - Summary of Cash and Restricted Cash (Details)
# 60
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R61.htm
# 100600 - Disclosure - Balance Sheet Components - Summary of Accounts Receivable, Net (Details)
# Balance Sheet Components - Summary of Accounts Receivable, Net (Details)
# 61
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R62.htm
# 100610 - Disclosure - Balance Sheet Components - Summary of Inventories (Details)
# Balance Sheet Components - Summary of Inventories (Details)
# 62
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R63.htm
# 100620 - Disclosure - Balance Sheet Components - Summary of Property and Equipment, Net (Details)
# Balance Sheet Components - Summary of Property and Equipment, Net (Details)
# 63
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R64.htm
# 100630 - Disclosure - Balance Sheet Components - Summary of Other Liabilities and Accrued Expenses (Details)
# Balance Sheet Components - Summary of Other Liabilities and Accrued Expenses (Details)
# 64
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R65.htm
# 100640 - Disclosure - Balance Sheet Components - Additional Information (Details)
# Balance Sheet Components - Additional Information (Details)
# 65
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R66.htm
# 100650 - Disclosure - Debt - Additional Information (Details)
# Debt - Additional Information (Details)
# 66
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R67.htm
# 100660 - Disclosure - Debt - Summary of Carrying Value of First Lien and Second Lien Term Loan (Details)
# Debt - Summary of Carrying Value of First Lien and Second Lien Term Loan (Details)
# 67
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R68.htm
# 100670 - Disclosure - Debt - Summary of Interest Expense Recognized for First Lien and Second Lien (Details)
# Debt - Summary of Interest Expense Recognized for First Lien and Second Lien (Details)
# 68
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R69.htm
# 100680 - Disclosure - Debt - Summary of Estimated Future Principal Payments under Total Long-term Debt (Details)
# Debt - Summary of Estimated Future Principal Payments under Total Long-term Debt (Details)
# 69
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R70.htm
# 100700 - Disclosure - Commitments and Contingencies - Schedule of Changes in Warranty Obligations (Details)
# Commitments and Contingencies - Schedule of Changes in Warranty Obligations (Details)
# 70
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R71.htm
# 100710 - Disclosure - Commitments and Contingencies - Schedule of Total Long-Term Non-Cancelable Purchase Commitment (Details)
# Commitments and Contingencies - Schedule of Total Long-Term Non-Cancelable Purchase Commitment (Details)
# 71
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R72.htm
# 100720 - Disclosure - Commitments and Contingencies - Additional Information (Details)
# Commitments and Contingencies - Additional Information (Details)
# 72
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R73.htm
# 100730 - Disclosure - Stockholders' Equity - Additional Information (Details)
# Stockholders' Equity - Additional Information (Details)
# 73
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R74.htm
# 100740 - Disclosure - Equity Incentive Plans and Stock-Based Compensation - Additional Information (Detail)
# Equity Incentive Plans and Stock-Based Compensation - Additional Information (Detail)
# 74
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R75.htm
# 100750 - Disclosure - Equity Incentive Plans and Stock-Based Compensation - Summary of Stock Option Activities and Related Information (Detail)
# Equity Incentive Plans and Stock-Based Compensation - Summary of Stock Option Activities and Related Information (Detail)
# 75
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R76.htm
# 100760 - Disclosure - Equity Incentive Plans and Stock-Based Compensation - Summary of RSUs Activities and Related Information (Detail)
# Equity Incentive Plans and Stock-Based Compensation - Summary of RSUs Activities and Related Information (Detail)
# 76
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R77.htm
# 100770 - Disclosure - Equity Incentive Plans and Stock-Based Compensation - Summary of Stock-based Compensation Expense (Detail)
# Equity Incentive Plans and Stock-Based Compensation - Summary of Stock-based Compensation Expense (Detail)
# 77
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R78.htm
# 100780 - Disclosure - Equity Incentive Plans and Stock-Based Compensation - Summary of Valuation Assumptions of Fair Value of Stock Options on Date of Grant (Detail)
# Equity Incentive Plans and Stock-Based Compensation - Summary of Valuation Assumptions of Fair Value of Stock Options on Date of Grant (Detail)
# 78
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R79.htm
# 100790 - Disclosure - Net Loss (Loss) Per Share - Computation of Basic and Diluted Net Income (Loss) Per Share (Detail)
# Net Loss (Loss) Per Share - Computation of Basic and Diluted Net Income (Loss) Per Share (Detail)
# 79
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R80.htm
# 100800 - Disclosure - Income Taxes - Component of Income (Loss) Before Income Taxes (Detail)
# Income Taxes - Component of Income (Loss) Before Income Taxes (Detail)
# 80
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R81.htm
# 100810 - Disclosure - Income Taxes - Components of Income Tax (Expense) Benefit (Detail)
# Income Taxes - Components of Income Tax (Expense) Benefit (Detail)
# 81
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R82.htm
# 100820 - Disclosure - Income Taxes - Income Tax (Expense) Benefit Differs from the Amount which would Result by applying the Applicable Statutory Deferral Rate to Income before Income Taxes (Detail)
# Income Taxes - Income Tax (Expense) Benefit Differs from the Amount which would Result by applying the Applicable Statutory Deferral Rate to Income before Income Taxes (Detail)
# 82
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R83.htm
# 100830 - Disclosure - Income Taxes - Components of Company's Deferred Tax Assets and Liabilities (Detail)
# Income Taxes - Components of Company's Deferred Tax Assets and Liabilities (Detail)
# 83
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R84.htm
# 100840 - Disclosure - Income Taxes - Additional Information (Detail)
# Income Taxes - Additional Information (Detail)
# 84
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R85.htm
# 100850 - Disclosure - Accumulated Other Comprehensive Income (Loss) - Components of Accumulated Other Comprehensive Income (Loss) (Detail)
# Accumulated Other Comprehensive Income (Loss) - Components of Accumulated Other Comprehensive Income (Loss) (Detail)
# 85
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R86.htm
# 100860 - Disclosure - Related-Party Transactions - Additional Information (Details)
# Related-Party Transactions - Additional Information (Details)
# 86
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R87.htm
# 100870 - Disclosure - Segment and Geographic Information - Summary of Financial Information for Each Reportable Segment (Detail)
# Segment and Geographic Information - Summary of Financial Information for Each Reportable Segment (Detail)
# 87
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R88.htm
# 100880 - Disclosure - Segment and Geographic Information - Summary of Net Revenue By Geographic Region (Detail)
# Segment and Geographic Information - Summary of Net Revenue By Geographic Region (Detail)
# 88
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R89.htm
# 100890 - Disclosure - Segment and Geographic Information - Additional Information (Detail)
# Segment and Geographic Information - Additional Information (Detail)
# 89
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R90.htm
# 100900 - Disclosure - Segment and Geographic Information - Summary of Property And Equipment, Net by Country (Detail)
# Segment and Geographic Information - Summary of Property And Equipment, Net by Country (Detail)
# 90
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R91.htm
# 100910 - Disclosure - Leases - Additional Information (Detail)
# Leases - Additional Information (Detail)
# 91
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R92.htm
# 100920 - Disclosure - Leases - Summary of Components of Lease Expenses (Detail)
# Leases - Summary of Components of Lease Expenses (Detail)
# 92
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R93.htm
# 100930 - Disclosure - Leases - Supplemental Cash Flow Information Related to Leases (Details)
# Leases - Supplemental Cash Flow Information Related to Leases (Details)
# 93
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R94.htm
# 100940 - Disclosure - Leases - Schedule of Future Undiscounted Cash Flows Related To Operating Lease Payments (Detail)
# Leases - Schedule of Future Undiscounted Cash Flows Related To Operating Lease Payments (Detail)
# 94
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R95.htm
# 100960 - Disclosure - Leases - Future Minimum Lease Payments Under Non-cancelable Operating Leases (Detail)
# Leases - Future Minimum Lease Payments Under Non-cancelable Operating Leases (Detail)
# 95
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R96.htm
# 100970 - Disclosure - Selected Quarterly Financial Data (Unaudited) (Detail)
# Selected Quarterly Financial Data (Unaudited) (Detail)
# 96
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1743759/000156459021012507/R97.htm
# 100980 - Disclosure - Schedule II - Valuation and Qualifying Accounts (Detail)
# Schedule II - Valuation and Qualifying Accounts (Detail)
# 97

# %%
statements_data = grab_financial_statements(master_reports)

# %%
statements_data
# Out:
# [{'headers': [['Combined Consolidated Statements of Operations - USD ($) shares in Thousands, $ in Thousands',
#     '12 Months Ended'],
#    ['Dec. 31, 2020', 'Dec. 31, 2019', 'Dec. 31, 2018']],
#   'sections': ['INCOME STATEMENT [ABSTRACT]',
#    'OPERATING EXPENSES:',
#    'OTHER (EXPENSE) INCOME:',
#    'NET INCOME (LOSS) PER SHARE',
#    'WEIGHTED-AVERAGE SHARES USED TO COMPUTE NET INCOME (LOSS) PER SHARE'],
#   'data': [['INCOME STATEMENT [ABSTRACT]', '', '', ''],
#    ['Net revenue', '$ 1,702,367', '$ 1,097,174', '$ 937,553'],
#    ['Cost of revenue', '1,236,938', '872,887', '744,858'],
#    ['Gross profit', '465,429', '224,287', '192,695'],
#    ['OPERATING EXPENSES:', '', '', ''],
#    ['Sales, general and administrative', '257,004', '163,033', '138,915'],
#    ['Product development', '50,064', '37,547', '31,990'],
#    ['Total operating expenses', '307,068', '200,580', '170,905'],
#    ['Operating income', '158,361', '23,707', '21,790'],
#    ['OTHER (EXPENSE) INCOME:', '', '', ''],
#    ['Interest expense', '(35,137)', '(35,548)', '(32,680)'],
#    ['Other (expense) income, net', '(1,182)', '(1,558)', '183'],
#    ['Total other expense, net', '(36,319)', '(37,106)', '(32,497)'],
#    ['Income (loss) before income taxes', '122,042', '(13,399)', '(10,707)'],
#    ['Income tax (expense) benefit', '(18,825)', '5,005', '(3,013)'],
#    ['Net income (loss)', '$ 103,217', '$ (8,394)', '$ (13,720)'],
#    ['NET INCOME (LOSS) PER SHARE', '', '', ''],
#    ['Basic', '$ 1.20', '$ 0.11', '$ 0.18'],
#    ['Diluted', '$ 1.14', '$ 0.11', '$ 0.18'],
#    ['WEIGHTED-AVERAGE SHARES USED TO COMPUTE NET INCOME (LOSS) PER SHARE',
#     '',
#     '',
#     ''],
#    ['Basic', '86,256', '76,223', '75,458'],
#    ['Diluted', '90,577', '76,223', '75,458']]},
#  {'headers': [['Combined Consolidated Statements of Comprehensive Income (Loss) - USD ($) $ in Thousands',
#     '12 Months Ended'],
#    ['Dec. 31, 2020', 'Dec. 31, 2019', 'Dec. 31, 2018']],
#   'sections': ['STATEMENT OF INCOME AND COMPREHENSIVE INCOME [ABSTRACT]',
#    'OTHER COMPREHENSIVE GAIN (LOSS):'],
#   'data': [['STATEMENT OF INCOME AND COMPREHENSIVE INCOME [ABSTRACT]',
#     '',
#     '',
#     ''],
#    ['Net income (loss)', '$ 103,217', '$ (8,394)', '$ (13,720)'],
#    ['OTHER COMPREHENSIVE GAIN (LOSS):', '', '', ''],
#    ['Foreign currency translation adjustments, net of zero tax',
#     '2,477',
#     '490',
#     '(706)'],
#    ['Unrealized foreign exchange gain (loss) from long-term intercompany loans, net of tax benefit (expense) of $(150), $55, and $300 for the years ended December 31, 2020, 2019, and 2018, respectively',
#     '1,221',
#     '(278)',
#     '(1,520)'],
#    ['Comprehensive income (loss)', '$ 106,915', '$ (8,182)', '$ (15,946)']]},
#  {'headers': [['Combined Consolidated Balance Sheets - USD ($) $ in Thousands',
#     'Dec. 31, 2020',
#     'Dec. 31, 2019']],
#   'sections': ['CURRENT ASSETS:',
#    'CURRENT LIABILITIES:',
#    'STOCKHOLDERS’ EQUITY:'],
#   'data': [['CURRENT ASSETS:', '', ''],
#    ['Cash', '$ 129,543', '$ 48,165'],
#    ['Restricted cash', '3,795', '3,552'],
#    ['Accounts receivable, net', '293,629', '202,334'],
#    ['Inventories', '226,007', '151,063'],
#    ['Prepaid expenses and other current assets', '37,997', '24,696'],
#    ['Total current assets', '690,971', '429,810'],
#    ['Property and equipment, net', '16,475', '15,365'],
#    ['Goodwill', '312,760', '312,750'],
#    ['Intangible assets, net', '259,317', '291,027'],
#    ['Restricted cash, noncurrent', '230', '230'],
#    ['Other assets', '34,362', '10,536'],
#    ['TOTAL ASSETS', '1,314,115', '1,059,718'],
#    ['CURRENT LIABILITIES:', '', ''],
#    ['Accounts payable', '299,636', '182,025'],
#    ['Current portion of debt, net', '', '2,364'],
#    ['Other liabilities and accrued expenses', '205,745', '115,541'],
#    ['Total current liabilities', '505,381', '299,930'],
#    ['Debt, net including related party balance of nil and $5,779 as of December 31, 2020 and 2019, respectively',
#     '321,393',
#     '503,448'],
#    ['Deferred tax liabilities', '29,752', '33,820'],
#    ['Other liabilities, noncurrent', '20,199', '5,745'],
#    ['TOTAL LIABILITIES', '876,725', '842,943'],
#    ['Commitments and Contingencies (Note 9)', '', ''],
#    ['STOCKHOLDERS’ EQUITY:', '', ''],
#    ['Preferred stock, $0.0001 par value: 5,000 shares and nil authorized; nil and nil issued and outstanding as of December 31, 2020 and 2019, respectively',
#     '',
#     ''],
#    ['Common stock, $0.0001 par value: 300,000 shares and 100,000 shares authorized; 91,935 and 84,079 shares issued and outstanding as of December 31, 2020 and 2019, respectively',
#     '9',
#     '8'],
#    ['Additional paid-in capital', '438,667', '324,968'],
#    ['Accumulated deficit', '(2,813)', '(106,030)'],
#    ['Accumulated other comprehensive income (loss)', '1,527', '(2,171)'],
#    ['Total Stockholders’ Equity', '437,390', '216,775'],
#    ['TOTAL LIABILITIES AND STOCKHOLDERS’ EQUITY',
#     '$ 1,314,115',
#     '$ 1,059,718']]},
#  {'headers': [['Combined Consolidated Statements of Cash Flows - USD ($) $ in Thousands',
#     '12 Months Ended'],
#    ['Dec. 31, 2020', 'Dec. 31, 2019', 'Dec. 31, 2018']],
#   'sections': ['CASH FLOWS FROM OPERATING ACTIVITIES:',
#    'ADJUSTMENTS TO RECONCILE NET INCOME (LOSS) TO NET CASH PROVIDED BY OPERATING ACTIVITIES:',
#    'CHANGES IN OPERATING ASSETS AND LIABILITIES:',
#    'CASH FLOWS FROM INVESTING ACTIVITIES:',
#    'CASH FLOWS FROM FINANCING ACTIVITIES:',
#    'SUPPLEMENTAL CASH FLOW DISCLOSURES:',
#    'SUPPLEMENTAL DISCLOSURE OF NON-CASH INVESTING AND FINANCING ACTIVITIES:'],
#   'data': [['CASH FLOWS FROM OPERATING ACTIVITIES:', '', '', ''],
#    ['Net income (loss)', '$ 103,217', '$ (8,394)', '$ (13,720)'],
#    ['ADJUSTMENTS TO RECONCILE NET INCOME (LOSS) TO NET CASH PROVIDED BY OPERATING ACTIVITIES:',
#     '',
#     '',
#     ''],
#    ['Stock-based compensation', '5,796', '3,848', '2,751'],
#    ['Depreciation', '9,318', '7,384', '5,670'],
#    ['Amortization of intangible assets', '33,916', '30,123', '30,893'],
#    ['Debt issuance costs amortization', '2,550', '2,989', '3,420'],
#    ['Loss on debt extinguishment', '4,114', '', ''],
#    ['Deferred income taxes', '(7,476)', '(11,535)', '(3,017)'],
#    ['Other', '2,594', '(347)', '(36)'],
#    ['CHANGES IN OPERATING ASSETS AND LIABILITIES:', '', '', ''],
#    ['Accounts receivable', '(91,492)', '(48,033)', '(7,339)'],
#    ['Inventories', '(80,086)', '15,711', '(29,753)'],
#    ['Prepaid expenses and other assets', '(7,953)', '(1,619)', '(10,869)'],
#    ['Accounts payable', '116,522', '16,203', '25,835'],
#    ['Other liabilities and accrued expenses', '77,933', '30,773', '(3,413)'],
#    ['Net cash provided by operating activities', '168,953', '37,103', '422'],
#    ['CASH FLOWS FROM INVESTING ACTIVITIES:', '', '', ''],
#    ['Acquisition of business, net of cash acquired',
#     '(1,291)',
#     '(126,104)',
#     '(30,210)'],
#    ['Payment of deferred consideration', '', '(10,300)', ''],
#    ['Purchase of property and equipment', '(8,989)', '(8,848)', '(8,345)'],
#    ['Purchase of intangible asset', '', '(175)', ''],
#    ['Net cash used in investing activities',
#     '(10,280)',
#     '(145,427)',
#     '(38,555)'],
#    ['CASH FLOWS FROM FINANCING ACTIVITIES:', '', '', ''],
#    ['Proceeds from issuance of debt, net', '', '113,885', '113,575'],
#    ['Repayment of debt', '(190,394)', '(3,969)', '(3,088)'],
#    ['Payment of debt issuance costs', '(194)', '(2,450)', '(1,836)'],
#    ['(Repayments of) borrowings from line of credit, net',
#     '',
#     '(27,000)',
#     '27,000'],
#    ['Proceeds from initial public offering, net of $8,925 underwriting discounts and commissions',
#     '118,575',
#     '',
#     ''],
#    ['Payment of other offering costs', '(8,455)', '(245)', '(3,307)'],
#    ['Proceeds from issuance of common stock to common stockholders',
#     '',
#     '53,500',
#     ''],
#    ['Cash dividends paid to common stockholders', '', '', '(85,000)'],
#    ['Repurchase of common stock', '', '(1,531)', ''],
#    ['Proceeds from exercise of stock options', '1,337', '124', '10'],
#    ['Net cash provided by (used in) financing activities',
#     '(79,131)',
#     '132,314',
#     '47,354'],
#    ['Effect of exchange rate changes on cash', '2,079', '37', '(331)'],
#    ['Net increase in cash and restricted cash', '81,621', '24,027', '8,890'],
#    ['Cash and restricted cash at the beginning of the period',
#     '51,947',
#     '27,920',
#     '19,030'],
#    ['Cash and restricted cash at the end of the period',
#     '133,568',
#     '51,947',
#     '27,920'],
#    ['SUPPLEMENTAL CASH FLOW DISCLOSURES:', '', '', ''],
#    ['Cash paid for interest', '27,957', '32,842', '28,865'],
#    ['Cash paid for income taxes', '13,505', '571', '6,122'],
#    ['SUPPLEMENTAL DISCLOSURE OF NON-CASH INVESTING AND FINANCING ACTIVITIES:',
#     '',
#     '',
#     ''],
#    ['Equipment purchased and unpaid at period end', '1,832', '927', '2,660'],
#    ['Issuance of common stock relating to business acquisitions',
#     '',
#     '10,000',
#     '6,226'],
#    ['Deferred purchase consideration (Note 5)', '145', '7,641', '10,331'],
#    ['Measurement period adjustments relating to business acquisitions',
#     '$ 1,531',
#     '',
#     ''],
#    ['Deferred offering costs included in accounts payable and accrued expenses',
#     '',
#     '$ 2,255',
#     '$ 1,989']]}]

# %%
df_1 = convert_statements_data_to_pandas(statements_data, 0)
df_1
# Out:
#                                                     Dec. 31, 2020  \
# Combined Consolidated Statements of Operations ...
# INCOME STATEMENT [ABSTRACT]                                   NaN
# Net revenue                                             1702367.0
# Cost of revenue                                         1236938.0
# Gross profit                                             465429.0
# OPERATING EXPENSES:                                           NaN
# Sales, general and administrative                        257004.0
# Product development                                       50064.0
# Total operating expenses                                 307068.0
# Operating income                                         158361.0
# OTHER (EXPENSE) INCOME:                                       NaN
# Interest expense                                         -35137.0
# Other (expense) income, net                               -1182.0
# Total other expense, net                                 -36319.0
# Income (loss) before income taxes                        122042.0
# Income tax (expense) benefit                             -18825.0
# Net income (loss)                                        103217.0
# NET INCOME (LOSS) PER SHARE                                   NaN
# Basic                                                       120.0
# Diluted                                                     114.0
# WEIGHTED-AVERAGE SHARES USED TO COMPUTE NET INC...            NaN
# Basic                                                     86256.0
# Diluted                                                   90577.0
#
#                                                     Dec. 31, 2019  \
# Combined Consolidated Statements of Operations ...
# INCOME STATEMENT [ABSTRACT]                                   NaN
# Net revenue                                             1097174.0
# Cost of revenue                                          872887.0
# Gross profit                                             224287.0
# OPERATING EXPENSES:                                           NaN
# Sales, general and administrative                        163033.0
# Product development                                       37547.0
# Total operating expenses                                 200580.0
# Operating income                                          23707.0
# OTHER (EXPENSE) INCOME:                                       NaN
# Interest expense                                         -35548.0
# Other (expense) income, net                               -1558.0
# Total other expense, net                                 -37106.0
# Income (loss) before income taxes                        -13399.0
# Income tax (expense) benefit                               5005.0
# Net income (loss)                                         -8394.0
# NET INCOME (LOSS) PER SHARE                                   NaN
# Basic                                                        11.0
# Diluted                                                      11.0
# WEIGHTED-AVERAGE SHARES USED TO COMPUTE NET INC...            NaN
# Basic                                                     76223.0
# Diluted                                                   76223.0
#
#                                                     Dec. 31, 2018
# Combined Consolidated Statements of Operations ...
# INCOME STATEMENT [ABSTRACT]                                   NaN
# Net revenue                                              937553.0
# Cost of revenue                                          744858.0
# Gross profit                                             192695.0
# OPERATING EXPENSES:                                           NaN
# Sales, general and administrative                        138915.0
# Product development                                       31990.0
# Total operating expenses                                 170905.0
# Operating income                                          21790.0
# OTHER (EXPENSE) INCOME:                                       NaN
# Interest expense                                         -32680.0
# Other (expense) income, net                                 183.0
# Total other expense, net                                 -32497.0
# Income (loss) before income taxes                        -10707.0
# Income tax (expense) benefit                              -3013.0
# Net income (loss)                                        -13720.0
# NET INCOME (LOSS) PER SHARE                                   NaN
# Basic                                                        18.0
# Diluted                                                      18.0
# WEIGHTED-AVERAGE SHARES USED TO COMPUTE NET INC...            NaN
# Basic                                                     75458.0
# Diluted                                                   75458.0

# %%
print('-'*10000)
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %% [markdown]
# # DEBUGGING

# %% [markdown]
# ## Gather initial index info about company you are interested in
#
# 1. Determine the company you are interested in selecting
# 2. Determine the file you are interested in selecting
# 3. Go into an index file (e.g. 2019-QTR2.tsv) and search for company name using ctrl-f
# 4. If file is not quarterly, check if file is located in that quarter

# %% [markdown]
# For the purposes of downloading a master list of sec index information (files downloaded to same directory)

# %%
#look into master index file for precise spelling
#selectedcompany = 'Booz Allen Hamilton Holding Corp'

selectedcompany = r'Booz'

#get the CIK number (id for company)
#CIK_number = get_CIK_number(selectedcompany, selectedreport)

#select a year you are interested in
selectedyear = 2021

#make sure to put in report exact (10-K vs 10-k)
selectedreport = "10-K"

master_index_file = str(selectedyear) + '-' + find_10k_quarter(selectedcompany, selectedreport, selectedyear) + '.tsv'


#define a user agent for access to the SEC Edgar servers (use browser)
user_agent = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36 Edg/97.0.1072.62"}

print(selectedcompany)
print(master_index_file)
# Out:
# Booz
# 2021-QTR2.tsv

# %%
#read master index info into a pandas dataframe
master_index = pd.read_csv(master_index_file, sep='\t', lineterminator='\n', names=None)

#rename column for convenience
master_index.columns.values[0] = 'Item'

#select the row in which the company and document you are interested in is located
filing_index = master_index[(master_index['Item'].str.contains(selectedcompany, case=False)) & (master_index['Item'].str.contains(selectedreport, case=False))]

filing_index = filing_index['Item'].str.split('|').to_list()

for elem in filing_index:
    print(elem)
    #if selectedreport in elem:
        #filing_index_specific = elem
        
print('#'*100)

for item in filing_index[0]:
    print(item)
    if '.txt' in item:
         txt_url = item
# Out:
# ['1443646', 'Booz Allen Hamilton Holding Corp', '10-K', '2021-05-21', 'edgar/data/1443646/0001443646-21-000079.txt', 'edgar/data/1443646/0001443646-21-000079-index.html\r']
# ####################################################################################################
# 1443646
# Booz Allen Hamilton Holding Corp
# 10-K
# 2021-05-21
# edgar/data/1443646/0001443646-21-000079.txt
# edgar/data/1443646/0001443646-21-000079-index.html

# %% [markdown]
# Grab the .txt file

# %% [markdown]
# ## Grab the Filing XML Summary

# %%
#define base url
base_url = r"https://www.sec.gov"

#convert the txt_url to a json url for the document landing page
documents_url = base_url + "/Archives/" + txt_url.replace('-','').replace('.txt', '/index.json')

print(documents_url)

#define user-agent of browser
user_agent = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36 Edg/97.0.1072.62"}


content = requests.get(documents_url, headers=user_agent).json()


#for each file in the document landing page
for file in content['directory']['item']:
    
    #if the filing's name is FilingSummary.xml
    if file['name'] == 'FilingSummary.xml':
        
        #create the url for the xml file
        xml_summary = base_url + content['directory']['name'] + "/" + file['name']
    
        print('-' * 100)
        print('File Name: ' + file['name'])
        print('File Path: ' + xml_summary)
# Out:
# https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/index.json
# ----------------------------------------------------------------------------------------------------
# File Name: FilingSummary.xml
# File Path: https://www.sec.gov/Archives/edgar/data/1443646/000144364621000079/FilingSummary.xml

# %% [markdown]
# ## Parsing the Filing Summary

# %%
#define a new base url that represents the filing folder. This will come in handy when we need to download the reports
base_url = xml_summary.replace('FilingSummary.xml', '')

#request and parse the content (use .content because this is an xml file not json)
content = requests.get(xml_summary, headers=user_agent).content

#create a soup object to parse the content using BeautifulSoup
soup = BeautifulSoup(content, 'lxml')

#find the 'myreports' tag because this contains all the individual reports submitted
reports = soup.find('myreports')

reports
# Out:
# <myreports>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R1.htm</htmlfilename>
# <longname>1001 - Document - Document and Entity Information</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DocumentandEntityInformation</role>
# <shortname>Document and Entity Information</shortname>
# <menucategory>Cover</menucategory>
# <position>1</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1003 - Statement - Consolidated Statements of Earnings</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/StatementOfIncome</role>
# <shortname>Consolidated Statements of Earnings</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R3.htm</htmlfilename>
# <longname>1004 - Statement - Consolidated Statements of Comprehensive (Loss) Income</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/StatementOfOtherComprehensiveIncome</role>
# <shortname>Consolidated Statements of Comprehensive (Loss) Income</shortname>
# <menucategory>Statements</menucategory>
# <position>3</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R4.htm</htmlfilename>
# <longname>1005 - Statement - Consolidated Balance Sheets</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/StatementOfFinancialPositionClassified</role>
# <shortname>Consolidated Balance Sheets</shortname>
# <menucategory>Statements</menucategory>
# <position>4</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R5.htm</htmlfilename>
# <longname>1006 - Statement - Consolidated Balance Sheets (Parenthetical)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/StatementOfFinancialPositionClassifiedParenthetical</role>
# <shortname>Consolidated Balance Sheets (Parenthetical)</shortname>
# <menucategory>Statements</menucategory>
# <position>5</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R6.htm</htmlfilename>
# <longname>1007 - Statement - Consolidated Statements of Stockholders' Equity</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/StatementOfShareholdersEquityAndOtherComprehensiveIncome</role>
# <shortname>Consolidated Statements of Stockholders' Equity</shortname>
# <menucategory>Statements</menucategory>
# <position>6</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R7.htm</htmlfilename>
# <longname>1008 - Statement - Consolidated Statements of Cash Flows</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/StatementOfCashFlowsIndirect</role>
# <shortname>Consolidated Statements of Cash Flows</shortname>
# <menucategory>Statements</menucategory>
# <position>7</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R8.htm</htmlfilename>
# <longname>1009 - Disclosure - Business</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsOrganizationConsolidationAndPresentationOfFinancialStatementsDisclosureTextBlock</role>
# <shortname>Business</shortname>
# <menucategory>Notes</menucategory>
# <position>8</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R9.htm</htmlfilename>
# <longname>1010 - Disclosure - Revision of Prior Period Financial Statements</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsAccountingChangesAndErrorCorrectionsTextBlock</role>
# <shortname>Revision of Prior Period Financial Statements</shortname>
# <menucategory>Notes</menucategory>
# <position>9</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R10.htm</htmlfilename>
# <longname>1011 - Disclosure - Significant Accounting Policies</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsSignificantAccountingPoliciesTextBlock</role>
# <shortname>Significant Accounting Policies</shortname>
# <menucategory>Notes</menucategory>
# <position>10</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R11.htm</htmlfilename>
# <longname>1012 - Disclosure - Business Combinations</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsBusinessCombinationDisclosureTextBlock</role>
# <shortname>Business Combinations</shortname>
# <menucategory>Notes</menucategory>
# <position>11</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R12.htm</htmlfilename>
# <longname>1013 - Disclosure - Share-Based Compensation</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsDisclosureOfCompensationRelatedCostsShareBasedPaymentsTextBlock</role>
# <shortname>Share-Based Compensation</shortname>
# <menucategory>Notes</menucategory>
# <position>12</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R13.htm</htmlfilename>
# <longname>1014 - Disclosure - Inventories</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsInventoryDisclosureTextBlock</role>
# <shortname>Inventories</shortname>
# <menucategory>Notes</menucategory>
# <position>13</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R14.htm</htmlfilename>
# <longname>1015 - Disclosure - Property, Plant and Equipment</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsPropertyPlantAndEquipmentDisclosureTextBlock</role>
# <shortname>Property, Plant and Equipment</shortname>
# <menucategory>Notes</menucategory>
# <position>14</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R15.htm</htmlfilename>
# <longname>1016 - Disclosure - Investments</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsInvestmentsInDebtAndMarketableEquitySecuritiesAndCertainTradingAssetsDisclosureTextBlock</role>
# <shortname>Investments</shortname>
# <menucategory>Notes</menucategory>
# <position>15</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R16.htm</htmlfilename>
# <longname>1017 - Disclosure - Fair Value Measurements of Assets and Liabilities</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsFairValueDisclosuresTextBlock</role>
# <shortname>Fair Value Measurements of Assets and Liabilities</shortname>
# <menucategory>Notes</menucategory>
# <position>16</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R17.htm</htmlfilename>
# <longname>1018 - Disclosure - Goodwill and Other Intangible Assets</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsGoodwillAndIntangibleAssetsDisclosureTextBlock</role>
# <shortname>Goodwill and Other Intangible Assets</shortname>
# <menucategory>Notes</menucategory>
# <position>17</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R18.htm</htmlfilename>
# <longname>1019 - Disclosure - Other Current and Long-term Liabilities</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsAccountsPayableAndAccruedLiabilitiesDisclosureTextBlock</role>
# <shortname>Other Current and Long-term Liabilities</shortname>
# <menucategory>Notes</menucategory>
# <position>18</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R19.htm</htmlfilename>
# <longname>1020 - Disclosure - Debt</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsDebtDisclosureTextBlock</role>
# <shortname>Debt</shortname>
# <menucategory>Notes</menucategory>
# <position>19</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R20.htm</htmlfilename>
# <longname>1021 - Disclosure - Accumulated Other Comprehensive (Loss) Income</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsComprehensiveIncomeNoteTextBlock</role>
# <shortname>Accumulated Other Comprehensive (Loss) Income</shortname>
# <menucategory>Notes</menucategory>
# <position>20</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R21.htm</htmlfilename>
# <longname>1022 - Disclosure - Derivative Instruments and Hedging Activities</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsDerivativeInstrumentsAndHedgingActivitiesDisclosureTextBlock</role>
# <shortname>Derivative Instruments and Hedging Activities</shortname>
# <menucategory>Notes</menucategory>
# <position>21</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R22.htm</htmlfilename>
# <longname>1023 - Disclosure - Retirement Benefit Plans</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsPensionAndOtherPostretirementBenefitsDisclosureTextBlock</role>
# <shortname>Retirement Benefit Plans</shortname>
# <menucategory>Notes</menucategory>
# <position>22</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R23.htm</htmlfilename>
# <longname>1024 - Disclosure - Income Taxes</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsIncomeTaxDisclosureTextBlock</role>
# <shortname>Income Taxes</shortname>
# <menucategory>Notes</menucategory>
# <position>23</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R24.htm</htmlfilename>
# <longname>1025 - Disclosure - Capital Stock and Earnings per Share</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsEarningsPerShareTextBlock</role>
# <shortname>Capital Stock and Earnings per Share</shortname>
# <menucategory>Notes</menucategory>
# <position>24</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R25.htm</htmlfilename>
# <longname>1026 - Disclosure - Segment Data</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsSegmentReportingDisclosureTextBlock</role>
# <shortname>Segment Data</shortname>
# <menucategory>Notes</menucategory>
# <position>25</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R26.htm</htmlfilename>
# <longname>1027 - Disclosure - Leases</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsLeasesOfLesseeDisclosureTextBlock</role>
# <shortname>Leases</shortname>
# <menucategory>Notes</menucategory>
# <position>26</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R27.htm</htmlfilename>
# <longname>1028 - Disclosure - Commitments and Contingencies</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsCommitmentsAndContingenciesDisclosureTextBlock</role>
# <shortname>Commitments and Contingencies</shortname>
# <menucategory>Notes</menucategory>
# <position>27</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R28.htm</htmlfilename>
# <longname>1029 - Disclosure - Quarterly Financial Information (Unaudited)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsQuarterlyFinancialInformationTextBlock</role>
# <shortname>Quarterly Financial Information (Unaudited)</shortname>
# <menucategory>Notes</menucategory>
# <position>28</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R29.htm</htmlfilename>
# <longname>1030 - Disclosure - Valuation and Qualifying Accounts</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsScheduleOfValuationAndQualifyingAccountsDisclosureTextBlock</role>
# <shortname>Valuation and Qualifying Accounts</shortname>
# <menucategory>Notes</menucategory>
# <position>29</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R30.htm</htmlfilename>
# <longname>1031 - Disclosure - Significant Accounting Policies (Policies)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsSignificantAccountingPoliciesTextBlockPolicies</role>
# <shortname>Significant Accounting Policies (Policies)</shortname>
# <menucategory>Policies</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsSignificantAccountingPoliciesTextBlock</parentrole>
# <position>30</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R31.htm</htmlfilename>
# <longname>1032 - Disclosure - Revision of Prior Period Financial Statements (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsAccountingChangesAndErrorCorrectionsTextBlockTables</role>
# <shortname>Revision of Prior Period Financial Statements (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsAccountingChangesAndErrorCorrectionsTextBlock</parentrole>
# <position>31</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R32.htm</htmlfilename>
# <longname>1033 - Disclosure - Significant Accounting Policies (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsSignificantAccountingPoliciesTextBlockTables</role>
# <shortname>Significant Accounting Policies (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsSignificantAccountingPoliciesTextBlock</parentrole>
# <position>32</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R33.htm</htmlfilename>
# <longname>1034 - Disclosure - Business Combinations (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsBusinessCombinationDisclosureTextBlockTables</role>
# <shortname>Business Combinations (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsBusinessCombinationDisclosureTextBlock</parentrole>
# <position>33</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R34.htm</htmlfilename>
# <longname>1035 - Disclosure - Share-Based Compensation (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsDisclosureOfCompensationRelatedCostsShareBasedPaymentsTextBlockTables</role>
# <shortname>Share-Based Compensation (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsDisclosureOfCompensationRelatedCostsShareBasedPaymentsTextBlock</parentrole>
# <position>34</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R35.htm</htmlfilename>
# <longname>1036 - Disclosure - Inventories (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsInventoryDisclosureTextBlockTables</role>
# <shortname>Inventories (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsInventoryDisclosureTextBlock</parentrole>
# <position>35</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R36.htm</htmlfilename>
# <longname>1037 - Disclosure - Property, Plant and Equipment (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsPropertyPlantAndEquipmentDisclosureTextBlockTables</role>
# <shortname>Property, Plant and Equipment (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsPropertyPlantAndEquipmentDisclosureTextBlock</parentrole>
# <position>36</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R37.htm</htmlfilename>
# <longname>1038 - Disclosure - Investments (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsInvestmentsInDebtAndMarketableEquitySecuritiesAndCertainTradingAssetsDisclosureTextBlockTables</role>
# <shortname>Investments (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsInvestmentsInDebtAndMarketableEquitySecuritiesAndCertainTradingAssetsDisclosureTextBlock</parentrole>
# <position>37</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R38.htm</htmlfilename>
# <longname>1039 - Disclosure - Fair Value Measurements of Assets and Liabilities (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsFairValueDisclosuresTextBlockTables</role>
# <shortname>Fair Value Measurements of Assets and Liabilities (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsFairValueDisclosuresTextBlock</parentrole>
# <position>38</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R39.htm</htmlfilename>
# <longname>1040 - Disclosure - Goodwill and Other Intangible Assets (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsGoodwillAndIntangibleAssetsDisclosureTextBlockTables</role>
# <shortname>Goodwill and Other Intangible Assets (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsGoodwillAndIntangibleAssetsDisclosureTextBlock</parentrole>
# <position>39</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R40.htm</htmlfilename>
# <longname>1041 - Disclosure - Other Current and Long-term Liabilities (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsAccountsPayableAndAccruedLiabilitiesDisclosureTextBlockTables</role>
# <shortname>Other Current and Long-term Liabilities (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsAccountsPayableAndAccruedLiabilitiesDisclosureTextBlock</parentrole>
# <position>40</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R41.htm</htmlfilename>
# <longname>1042 - Disclosure - Debt (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsDebtDisclosureTextBlockTables</role>
# <shortname>Debt (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsDebtDisclosureTextBlock</parentrole>
# <position>41</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R42.htm</htmlfilename>
# <longname>1043 - Disclosure - Accumulated Other Comprehensive (Loss) Income (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsComprehensiveIncomeNoteTextBlockTables</role>
# <shortname>Accumulated Other Comprehensive (Loss) Income (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsComprehensiveIncomeNoteTextBlock</parentrole>
# <position>42</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R43.htm</htmlfilename>
# <longname>1044 - Disclosure - Derivative Instruments and Hedging Activities (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsDerivativeInstrumentsAndHedgingActivitiesDisclosureTextBlockTables</role>
# <shortname>Derivative Instruments and Hedging Activities (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsDerivativeInstrumentsAndHedgingActivitiesDisclosureTextBlock</parentrole>
# <position>43</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R44.htm</htmlfilename>
# <longname>1045 - Disclosure - Retirement Benefit Plans (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsPensionAndOtherPostretirementBenefitsDisclosureTextBlockTables</role>
# <shortname>Retirement Benefit Plans (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsPensionAndOtherPostretirementBenefitsDisclosureTextBlock</parentrole>
# <position>44</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R45.htm</htmlfilename>
# <longname>1046 - Disclosure - Income Taxes (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsIncomeTaxDisclosureTextBlockTables</role>
# <shortname>Income Taxes (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsIncomeTaxDisclosureTextBlock</parentrole>
# <position>45</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R46.htm</htmlfilename>
# <longname>1047 - Disclosure - Capital Stock and Earnings per Share (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsEarningsPerShareTextBlockTables</role>
# <shortname>Capital Stock and Earnings per Share (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsEarningsPerShareTextBlock</parentrole>
# <position>46</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R47.htm</htmlfilename>
# <longname>1048 - Disclosure - Segment Data (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsSegmentReportingDisclosureTextBlockTables</role>
# <shortname>Segment Data (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsSegmentReportingDisclosureTextBlock</parentrole>
# <position>47</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R48.htm</htmlfilename>
# <longname>1049 - Disclosure - Leases (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsLeasesOfLesseeDisclosureTextBlockTables</role>
# <shortname>Leases (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsLeasesOfLesseeDisclosureTextBlock</parentrole>
# <position>48</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R49.htm</htmlfilename>
# <longname>1050 - Disclosure - Quarterly Financial Information (Unaudited) (Tables)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsQuarterlyFinancialInformationTextBlockTables</role>
# <shortname>Quarterly Financial Information (Unaudited) (Tables)</shortname>
# <menucategory>Tables</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsQuarterlyFinancialInformationTextBlock</parentrole>
# <position>49</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R50.htm</htmlfilename>
# <longname>1051 - Disclosure - Revision of Prior Period Financial Statements - Additional Information (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureRevisionOfPriorPeriodFinancialStatementsAdditionalInformation</role>
# <shortname>Revision of Prior Period Financial Statements - Additional Information (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>50</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R51.htm</htmlfilename>
# <longname>1052 - Disclosure - Revision of Prior Period Financial Statements - Revisions to the Consolidated Statements of Earnings and Comprehensive Income (Loss) (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureRevisionOfPriorPeriodFinancialStatementsRevisionsToTheConsolidatedStatementsOfEarningsAndComprehensiveIncomeLoss</role>
# <shortname>Revision of Prior Period Financial Statements - Revisions to the Consolidated Statements of Earnings and Comprehensive Income (Loss) (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>51</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R52.htm</htmlfilename>
# <longname>1053 - Disclosure - Revision of Prior Period Financial Statements - Revisions to the Consolidated Balance Sheet (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureRevisionOfPriorPeriodFinancialStatementsRevisionsToTheConsolidatedBalanceSheet</role>
# <shortname>Revision of Prior Period Financial Statements - Revisions to the Consolidated Balance Sheet (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>52</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R53.htm</htmlfilename>
# <longname>1054 - Disclosure - Revision of Prior Period Financial Statements - Revisions to the Consolidated Statements of Cash Flows (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureRevisionOfPriorPeriodFinancialStatementsRevisionsToTheConsolidatedStatementsOfCashFlows</role>
# <shortname>Revision of Prior Period Financial Statements - Revisions to the Consolidated Statements of Cash Flows (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>53</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R54.htm</htmlfilename>
# <longname>1055 - Disclosure - Significant Accounting Policies - Additional Information (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureSignificantAccountingPoliciesAdditionalInformation</role>
# <shortname>Significant Accounting Policies - Additional Information (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>54</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R55.htm</htmlfilename>
# <longname>1056 - Disclosure - Significant Accounting Policies - Summary of Expenses in Special Items (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureSignificantAccountingPoliciesSummaryOfExpensesInSpecialItems</role>
# <shortname>Significant Accounting Policies - Summary of Expenses in Special Items (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>55</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R56.htm</htmlfilename>
# <longname>1057 - Disclosure - Significant Accounting Policies - Summary of Liabilities Related to Integration Plans (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureSignificantAccountingPoliciesSummaryOfLiabilitiesRelatedToIntegrationPlans</role>
# <shortname>Significant Accounting Policies - Summary of Liabilities Related to Integration Plans (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>56</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R57.htm</htmlfilename>
# <longname>1058 - Disclosure - Business Combinations - Additional Information (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureBusinessCombinationsAdditionalInformation</role>
# <shortname>Business Combinations - Additional Information (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>57</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R58.htm</htmlfilename>
# <longname>1059 - Disclosure - Business Combinations - Summary of Preliminary Fair Values of Assets Acquired and Liabilities Assumed (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureBusinessCombinationsSummaryOfPreliminaryFairValuesOfAssetsAcquiredAndLiabilitiesAssumed</role>
# <shortname>Business Combinations - Summary of Preliminary Fair Values of Assets Acquired and Liabilities Assumed (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>58</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R59.htm</htmlfilename>
# <longname>1060 - Disclosure - Business Combinations - Pro forma Financial Information Adjusted to Give Effect to the Merger (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureBusinessCombinationsProFormaFinancialInformationAdjustedToGiveEffectToTheMerger</role>
# <shortname>Business Combinations - Pro forma Financial Information Adjusted to Give Effect to the Merger (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>59</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R60.htm</htmlfilename>
# <longname>1061 - Disclosure - Share-Based Compensation - Share-Based Compensation Expense (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureShareBasedCompensationShareBasedCompensationExpense</role>
# <shortname>Share-Based Compensation - Share-Based Compensation Expense (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>60</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R61.htm</htmlfilename>
# <longname>1062 - Disclosure - Share-Based Compensation - Additional Information (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureShareBasedCompensationAdditionalInformation</role>
# <shortname>Share-Based Compensation - Additional Information (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>61</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R62.htm</htmlfilename>
# <longname>1063 - Disclosure - Share-Based Compensation - Summary of Stock Option Activity (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureShareBasedCompensationSummaryOfStockOptionActivity</role>
# <shortname>Share-Based Compensation - Summary of Stock Option Activity (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>62</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R63.htm</htmlfilename>
# <longname>1064 - Disclosure - Share-Based Compensation - Weighted Average Fair Value for Stock Options Granted (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureShareBasedCompensationWeightedAverageFairValueForStockOptionsGranted</role>
# <shortname>Share-Based Compensation - Weighted Average Fair Value for Stock Options Granted (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>63</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R64.htm</htmlfilename>
# <longname>1065 - Disclosure - Share-Based Compensation - Summary of Nonvested RSU Activity (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureShareBasedCompensationSummaryOfNonvestedRSUActivity</role>
# <shortname>Share-Based Compensation - Summary of Nonvested RSU Activity (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>64</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R65.htm</htmlfilename>
# <longname>1066 - Disclosure - Inventories - Summary of Inventories (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureInventoriesSummaryOfInventories</role>
# <shortname>Inventories - Summary of Inventories (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>65</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R66.htm</htmlfilename>
# <longname>1067 - Disclosure - Inventories - Additional Information (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureInventoriesAdditionalInformation</role>
# <shortname>Inventories - Additional Information (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>66</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R67.htm</htmlfilename>
# <longname>1068 - Disclosure - Property, Plant and Equipment - Summary of Property, Plant and Equipment (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosurePropertyPlantAndEquipmentSummaryOfPropertyPlantAndEquipment</role>
# <shortname>Property, Plant and Equipment - Summary of Property, Plant and Equipment (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>67</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R68.htm</htmlfilename>
# <longname>1069 - Disclosure - Property, Plant and Equipment - Additional Information (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosurePropertyPlantAndEquipmentAdditionalInformation</role>
# <shortname>Property, Plant and Equipment - Additional Information (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>68</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R69.htm</htmlfilename>
# <longname>1070 - Disclosure - Investments - Investments in Short and Long-Term Classified as Available-for-Sale Securities (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureInvestmentsInvestmentsInShortAndLongTermClassifiedAsAvailableforSaleSecurities</role>
# <shortname>Investments - Investments in Short and Long-Term Classified as Available-for-Sale Securities (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>69</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R70.htm</htmlfilename>
# <longname>1071 - Disclosure - Investments - Cost and Fair Value of Available-for-Sale Fixed-Maturity Securities by Contractual Maturity (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureInvestmentsCostAndFairValueOfAvailableforSaleFixedMaturitySecuritiesByContractualMaturity</role>
# <shortname>Investments - Cost and Fair Value of Available-for-Sale Fixed-Maturity Securities by Contractual Maturity (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>70</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R71.htm</htmlfilename>
# <longname>1072 - Disclosure - Fair Value Measurements of Assets and Liabilities - Fair Value Measurements of Assets and Liabilities (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureFairValueMeasurementsOfAssetsAndLiabilitiesFairValueMeasurementsOfAssetsAndLiabilities</role>
# <shortname>Fair Value Measurements of Assets and Liabilities - Fair Value Measurements of Assets and Liabilities (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>71</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R72.htm</htmlfilename>
# <longname>1073 - Disclosure - Goodwill and Other Intangible Assets - Changes in Carrying Amount of Goodwill (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureGoodwillAndOtherIntangibleAssetsChangesInCarryingAmountOfGoodwill</role>
# <shortname>Goodwill and Other Intangible Assets - Changes in Carrying Amount of Goodwill (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>72</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R73.htm</htmlfilename>
# <longname>1074 - Disclosure - Goodwill and Other Intangible Assets - Components of Identifiable Intangible Assets (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureGoodwillAndOtherIntangibleAssetsComponentsOfIdentifiableIntangibleAssets</role>
# <shortname>Goodwill and Other Intangible Assets - Components of Identifiable Intangible Assets (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>73</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R74.htm</htmlfilename>
# <longname>1075 - Disclosure - Goodwill and Other Intangible Assets - Additional Information (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureGoodwillAndOtherIntangibleAssetsAdditionalInformation</role>
# <shortname>Goodwill and Other Intangible Assets - Additional Information (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>74</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R75.htm</htmlfilename>
# <longname>1076 - Disclosure - Goodwill and Other Intangible Assets - Estimated Annual Amortization Expense Based on Intangible Assets Recognized (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureGoodwillAndOtherIntangibleAssetsEstimatedAnnualAmortizationExpenseBasedOnIntangibleAssetsRecognized</role>
# <shortname>Goodwill and Other Intangible Assets - Estimated Annual Amortization Expense Based on Intangible Assets Recognized (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>75</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R76.htm</htmlfilename>
# <longname>1077 - Disclosure - Other Current and Long-term Liabilities - Summary of Other Current and Long-Term Liabilities (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureOtherCurrentAndLongtermLiabilitiesSummaryOfOtherCurrentAndLongTermLiabilities</role>
# <shortname>Other Current and Long-term Liabilities - Summary of Other Current and Long-Term Liabilities (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>76</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R77.htm</htmlfilename>
# <longname>1078 - Disclosure - Debt - Summary of Debt Instruments (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureDebtSummaryOfDebtInstruments</role>
# <shortname>Debt - Summary of Debt Instruments (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>77</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R78.htm</htmlfilename>
# <longname>1079 - Disclosure - Debt - Summary of Debt Instruments (Parenthetical) (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureDebtSummaryOfDebtInstrumentsParenthetical</role>
# <shortname>Debt - Summary of Debt Instruments (Parenthetical) (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>78</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R79.htm</htmlfilename>
# <longname>1080 - Disclosure - Debt - Additional Information (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureDebtAdditionalInformation</role>
# <shortname>Debt - Additional Information (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>79</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R80.htm</htmlfilename>
# <longname>1081 - Disclosure - Accumulated Other Comprehensive (Loss) Income - Changes in Components of Other Comprehensive Income, Net of Tax (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureAccumulatedOtherComprehensiveLossIncomeChangesInComponentsOfOtherComprehensiveIncomeNetOfTax</role>
# <shortname>Accumulated Other Comprehensive (Loss) Income - Changes in Components of Other Comprehensive Income, Net of Tax (Detail)</shortname>
# <menucategory>Details</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsComprehensiveIncomeNoteTextBlockTables</parentrole>
# <position>80</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R81.htm</htmlfilename>
# <longname>1082 - Disclosure - Accumulated Other Comprehensive (Loss) Income - Reclassification Adjustments from Accumulated Other Comprehensive Income (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureAccumulatedOtherComprehensiveLossIncomeReclassificationAdjustmentsFromAccumulatedOtherComprehensiveIncome</role>
# <shortname>Accumulated Other Comprehensive (Loss) Income - Reclassification Adjustments from Accumulated Other Comprehensive Income (Detail)</shortname>
# <menucategory>Details</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsComprehensiveIncomeNoteTextBlockTables</parentrole>
# <position>81</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R82.htm</htmlfilename>
# <longname>1083 - Disclosure - Accumulated Other Comprehensive (Loss) Income - Tax Effects on Each Component of Other Comprehensive Income Recognized in Statements of Comprehensive Income (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureAccumulatedOtherComprehensiveLossIncomeTaxEffectsOnEachComponentOfOtherComprehensiveIncomeRecognizedInStatementsOfComprehensiveIncome</role>
# <shortname>Accumulated Other Comprehensive (Loss) Income - Tax Effects on Each Component of Other Comprehensive Income Recognized in Statements of Comprehensive Income (Detail)</shortname>
# <menucategory>Details</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsComprehensiveIncomeNoteTextBlockTables</parentrole>
# <position>82</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# ...
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureRetirementBenefitPlanSummaryOfAmountsRecognizedInBalanceSheet</role>
# <shortname>Retirement Benefit Plan - Summary of Amounts Recognized in Balance Sheet (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>93</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R94.htm</htmlfilename>
# <longname>1095 - Disclosure - Retirement Benefit Plan - Summary of Amounts Recognized in Other Comprehensive Income Income (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureRetirementBenefitPlanSummaryOfAmountsRecognizedInOtherComprehensiveIncomeIncome</role>
# <shortname>Retirement Benefit Plan - Summary of Amounts Recognized in Other Comprehensive Income Income (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>94</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R95.htm</htmlfilename>
# <longname>1096 - Disclosure - Retirement Benefit Plans - Weighted Average Actuarial Assumptions Used to Determine Projected Benefit Obligation for Defined Benefit Retirement Plans (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureRetirementBenefitPlansWeightedAverageActuarialAssumptionsUsedToDetermineProjectedBenefitObligationForDefinedBenefitRetirementPlans</role>
# <shortname>Retirement Benefit Plans - Weighted Average Actuarial Assumptions Used to Determine Projected Benefit Obligation for Defined Benefit Retirement Plans (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>95</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R96.htm</htmlfilename>
# <longname>1097 - Disclosure - Retirement Benefit Plans - Plans with Benefit Obligations in Excess of Plan Assets (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureRetirementBenefitPlansPlansWithBenefitObligationsInExcessOfPlanAssets</role>
# <shortname>Retirement Benefit Plans - Plans with Benefit Obligations in Excess of Plan Assets (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>96</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R97.htm</htmlfilename>
# <longname>1098 - Disclosure - Retirement Benefit Plans - Total Accumulated Benefit Obligations and Plans with Accumulated Benefit Obligations in Excess of Plan Assets (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureRetirementBenefitPlansTotalAccumulatedBenefitObligationsAndPlansWithAccumulatedBenefitObligationsInExcessOfPlanAssets</role>
# <shortname>Retirement Benefit Plans - Total Accumulated Benefit Obligations and Plans with Accumulated Benefit Obligations in Excess of Plan Assets (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>97</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R98.htm</htmlfilename>
# <longname>1099 - Disclosure - Retirement Benefit Plans - Summary of Benefits Expected to be Paid Out (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureRetirementBenefitPlansSummaryOfBenefitsExpectedToBePaidOut</role>
# <shortname>Retirement Benefit Plans - Summary of Benefits Expected to be Paid Out (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>98</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R99.htm</htmlfilename>
# <longname>1100 - Disclosure - Retirement Benefit Plans - Additional Information (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureRetirementBenefitPlansAdditionalInformation</role>
# <shortname>Retirement Benefit Plans - Additional Information (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>99</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R100.htm</htmlfilename>
# <longname>1101 - Disclosure - Retirement Benefit Plans - Fair Value of U.S. and Puerto Rico Pension Plan Assets (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureRetirementBenefitPlansFairValueOfUSAndPuertoRicoPensionPlanAssets</role>
# <shortname>Retirement Benefit Plans - Fair Value of U.S. and Puerto Rico Pension Plan Assets (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>100</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R101.htm</htmlfilename>
# <longname>1102 - Disclosure - Retirement Benefit Plans - Fair Value of Foreign Pension Plan Assets (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureRetirementBenefitPlansFairValueOfForeignPensionPlanAssets</role>
# <shortname>Retirement Benefit Plans - Fair Value of Foreign Pension Plan Assets (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>101</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R102.htm</htmlfilename>
# <longname>1103 - Disclosure - Retirement Benefit Plans - Reconciliation of Beginning and Ending Balances of Foreign Pension Plan Assets Measured at Fair Value (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureRetirementBenefitPlansReconciliationOfBeginningAndEndingBalancesOfForeignPensionPlanAssetsMeasuredAtFairValue</role>
# <shortname>Retirement Benefit Plans - Reconciliation of Beginning and Ending Balances of Foreign Pension Plan Assets Measured at Fair Value (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>102</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R103.htm</htmlfilename>
# <longname>1104 - Disclosure - Income Taxes - Components of Earnings Before Taxes and Income Taxes Paid (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureIncomeTaxesComponentsOfEarningsBeforeTaxesAndIncomeTaxesPaid</role>
# <shortname>Income Taxes - Components of Earnings Before Taxes and Income Taxes Paid (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>103</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R104.htm</htmlfilename>
# <longname>1105 - Disclosure - Income Taxes - Reconciliation of U.S. Statutory Income Tax Rate to Our Effective Tax Rate (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureIncomeTaxesReconciliationOfUSStatutoryIncomeTaxRateToOurEffectiveTaxRate</role>
# <shortname>Income Taxes - Reconciliation of U.S. Statutory Income Tax Rate to Our Effective Tax Rate (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>104</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R105.htm</htmlfilename>
# <longname>1106 - Disclosure - Income Taxes - Components of Deferred Taxes (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureIncomeTaxesComponentsOfDeferredTaxes</role>
# <shortname>Income Taxes - Components of Deferred Taxes (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>105</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R106.htm</htmlfilename>
# <longname>1107 - Disclosure - Income Taxes - Additional Information (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureIncomeTaxesAdditionalInformation</role>
# <shortname>Income Taxes - Additional Information (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>106</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R107.htm</htmlfilename>
# <longname>1108 - Disclosure - Income Taxes - Tabular Reconciliation of Total Amounts of Unrecognized Tax Benefits (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureIncomeTaxesTabularReconciliationOfTotalAmountsOfUnrecognizedTaxBenefits</role>
# <shortname>Income Taxes - Tabular Reconciliation of Total Amounts of Unrecognized Tax Benefits (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>107</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R108.htm</htmlfilename>
# <longname>1109 - Disclosure - Capital Stock and Earnings per Share - Additional Information (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureCapitalStockAndEarningsPerShareAdditionalInformation</role>
# <shortname>Capital Stock and Earnings per Share - Additional Information (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>108</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R109.htm</htmlfilename>
# <longname>1110 - Disclosure - Capital Stock and Earnings per Share - Reconciliation of Weighted Average Share for Basic and Diluted Share Computations (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureCapitalStockAndEarningsPerShareReconciliationOfWeightedAverageShareForBasicAndDilutedShareComputations</role>
# <shortname>Capital Stock and Earnings per Share - Reconciliation of Weighted Average Share for Basic and Diluted Share Computations (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>109</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R110.htm</htmlfilename>
# <longname>1111 - Disclosure - Segment Data - Additional Information (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureSegmentDataAdditionalInformation</role>
# <shortname>Segment Data - Additional Information (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>110</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R111.htm</htmlfilename>
# <longname>1112 - Disclosure - Segment Data - Summary of Net Sales and Other Information by Segment (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureSegmentDataSummaryOfNetSalesAndOtherInformationBySegment</role>
# <shortname>Segment Data - Summary of Net Sales and Other Information by Segment (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>111</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R112.htm</htmlfilename>
# <longname>1113 - Disclosure - Segment Data - Disclosure on Geographic Areas, Long-Lived Assets (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureSegmentDataDisclosureOnGeographicAreasLongLivedAssets</role>
# <shortname>Segment Data - Disclosure on Geographic Areas, Long-Lived Assets (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>112</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R113.htm</htmlfilename>
# <longname>1114 - Disclosure - Segment Data - Summary of Net Sales by Product Category (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureSegmentDataSummaryOfNetSalesByProductCategory</role>
# <shortname>Segment Data - Summary of Net Sales by Product Category (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>113</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R114.htm</htmlfilename>
# <longname>1115 - Disclosure - Leases - Additional Information (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureLeasesAdditionalInformation</role>
# <shortname>Leases - Additional Information (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>114</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R115.htm</htmlfilename>
# <longname>1116 - Disclosure - Leases - Schedule of Future Minimum Rental Commitments Under Non-Cancelable Operating Leases (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureLeasesScheduleOfFutureMinimumRentalCommitmentsUnderNonCancelableOperatingLeases</role>
# <shortname>Leases - Schedule of Future Minimum Rental Commitments Under Non-Cancelable Operating Leases (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>115</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R116.htm</htmlfilename>
# <longname>1117 - Disclosure - Commitments and Contingencies - Additional Information (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureCommitmentsAndContingenciesAdditionalInformation</role>
# <shortname>Commitments and Contingencies - Additional Information (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>116</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R117.htm</htmlfilename>
# <longname>1118 - Disclosure - Quarterly Financial Information (Unaudited) - Quarterly Financial Information (Unaudited) (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureQuarterlyFinancialInformationUnauditedQuarterlyFinancialInformationUnaudited</role>
# <shortname>Quarterly Financial Information (Unaudited) - Quarterly Financial Information (Unaudited) (Detail)</shortname>
# <menucategory>Details</menucategory>
# <parentrole>http://www.zimmer.com/taxonomy/role/NotesToFinancialStatementsQuarterlyFinancialInformationTextBlockTables</parentrole>
# <position>117</position>
# </report>
# <report instance="zbh-20151231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R118.htm</htmlfilename>
# <longname>1119 - Disclosure - Schedule - Valuation and Qualifying Accounts (Detail)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.zimmer.com/taxonomy/role/DisclosureScheduleValuationAndQualifyingAccounts</role>
# <shortname>Schedule - Valuation and Qualifying Accounts (Detail)</shortname>
# <menucategory>Details</menucategory>
# <position>118</position>
# </report>
# <report>
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <longname>All Reports</longname>
# <reporttype>Book</reporttype>
# <shortname>All Reports</shortname>
# </report>
# </myreports>

# %%
#define a new base url that represents the filing folder. This will come in handy when we need to download the reports
base_url = xml_summary.replace('FilingSummary.xml', '')

#request and parse the content (use .content because this is an xml file not json)
content = requests.get(xml_summary, headers=user_agent).content

#create a soup object to parse the content using BeautifulSoup
soup = BeautifulSoup(content, 'lxml')

#find the 'myreports' tag because this contains all the individual reports submitted
reports = soup.find('myreports')

#want a list ot store all theindividual components of the report, so create the master list
master_reports = []

# loop through each report in the 'myreports' tag but avoid the last one as this will cause an error
# (last one has differnent formatting).
for index, report in enumerate(reports.find_all('report')[:-1]):
    
    #create a dictionary to store all the differnet parts we need
    report_dict = {}
    report_dict['name_short'] = report.shortname.text
    report_dict['name_long'] = report.longname.text
    report_dict['position'] = index+1
    #report_dict['category'] = report.menucategory.text
    report_dict['url'] = base_url + report.htmlfilename.text
    
    #append the dictionary to the master list.
    master_reports.append(report_dict)
    
    #print the info to the user.
    print('-'*100)
    print(base_url + report.htmlfilename.text)
    print(report.longname.text)
    print(report.shortname.text)
    #print(report.menucategory.text)
    print(index+1)
# Out:
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R1.htm
# 1001 - Document - Document and Entity Information
# Document and Entity Information
# 1
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R2.htm
# 1003 - Statement - Consolidated Statements of Earnings
# Consolidated Statements of Earnings
# 2
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R3.htm
# 1004 - Statement - Consolidated Statements of Comprehensive (Loss) Income
# Consolidated Statements of Comprehensive (Loss) Income
# 3
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R4.htm
# 1005 - Statement - Consolidated Balance Sheets
# Consolidated Balance Sheets
# 4
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R5.htm
# 1006 - Statement - Consolidated Balance Sheets (Parenthetical)
# Consolidated Balance Sheets (Parenthetical)
# 5
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R6.htm
# 1007 - Statement - Consolidated Statements of Stockholders' Equity
# Consolidated Statements of Stockholders' Equity
# 6
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R7.htm
# 1008 - Statement - Consolidated Statements of Cash Flows
# Consolidated Statements of Cash Flows
# 7
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R8.htm
# 1009 - Disclosure - Business
# Business
# 8
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R9.htm
# 1010 - Disclosure - Revision of Prior Period Financial Statements
# Revision of Prior Period Financial Statements
# 9
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R10.htm
# 1011 - Disclosure - Significant Accounting Policies
# Significant Accounting Policies
# 10
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R11.htm
# 1012 - Disclosure - Business Combinations
# Business Combinations
# 11
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R12.htm
# 1013 - Disclosure - Share-Based Compensation
# Share-Based Compensation
# 12
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R13.htm
# 1014 - Disclosure - Inventories
# Inventories
# 13
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R14.htm
# 1015 - Disclosure - Property, Plant and Equipment
# Property, Plant and Equipment
# 14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R15.htm
# 1016 - Disclosure - Investments
# Investments
# 15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R16.htm
# 1017 - Disclosure - Fair Value Measurements of Assets and Liabilities
# Fair Value Measurements of Assets and Liabilities
# 16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R17.htm
# 1018 - Disclosure - Goodwill and Other Intangible Assets
# Goodwill and Other Intangible Assets
# 17
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R18.htm
# 1019 - Disclosure - Other Current and Long-term Liabilities
# Other Current and Long-term Liabilities
# 18
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R19.htm
# 1020 - Disclosure - Debt
# Debt
# 19
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R20.htm
# 1021 - Disclosure - Accumulated Other Comprehensive (Loss) Income
# Accumulated Other Comprehensive (Loss) Income
# 20
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R21.htm
# 1022 - Disclosure - Derivative Instruments and Hedging Activities
# Derivative Instruments and Hedging Activities
# 21
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R22.htm
# 1023 - Disclosure - Retirement Benefit Plans
# Retirement Benefit Plans
# 22
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R23.htm
# 1024 - Disclosure - Income Taxes
# Income Taxes
# 23
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R24.htm
# 1025 - Disclosure - Capital Stock and Earnings per Share
# Capital Stock and Earnings per Share
# 24
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R25.htm
# 1026 - Disclosure - Segment Data
# Segment Data
# 25
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R26.htm
# 1027 - Disclosure - Leases
# Leases
# 26
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R27.htm
# 1028 - Disclosure - Commitments and Contingencies
# Commitments and Contingencies
# 27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R28.htm
# 1029 - Disclosure - Quarterly Financial Information (Unaudited)
# Quarterly Financial Information (Unaudited)
# 28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R29.htm
# 1030 - Disclosure - Valuation and Qualifying Accounts
# Valuation and Qualifying Accounts
# 29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R30.htm
# 1031 - Disclosure - Significant Accounting Policies (Policies)
# Significant Accounting Policies (Policies)
# 30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R31.htm
# 1032 - Disclosure - Revision of Prior Period Financial Statements (Tables)
# Revision of Prior Period Financial Statements (Tables)
# 31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R32.htm
# 1033 - Disclosure - Significant Accounting Policies (Tables)
# Significant Accounting Policies (Tables)
# 32
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R33.htm
# 1034 - Disclosure - Business Combinations (Tables)
# Business Combinations (Tables)
# 33
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R34.htm
# 1035 - Disclosure - Share-Based Compensation (Tables)
# Share-Based Compensation (Tables)
# 34
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R35.htm
# 1036 - Disclosure - Inventories (Tables)
# Inventories (Tables)
# 35
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R36.htm
# 1037 - Disclosure - Property, Plant and Equipment (Tables)
# Property, Plant and Equipment (Tables)
# 36
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R37.htm
# 1038 - Disclosure - Investments (Tables)
# Investments (Tables)
# 37
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R38.htm
# 1039 - Disclosure - Fair Value Measurements of Assets and Liabilities (Tables)
# Fair Value Measurements of Assets and Liabilities (Tables)
# 38
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R39.htm
# 1040 - Disclosure - Goodwill and Other Intangible Assets (Tables)
# Goodwill and Other Intangible Assets (Tables)
# 39
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R40.htm
# 1041 - Disclosure - Other Current and Long-term Liabilities (Tables)
# Other Current and Long-term Liabilities (Tables)
# 40
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R41.htm
# 1042 - Disclosure - Debt (Tables)
# Debt (Tables)
# 41
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R42.htm
# 1043 - Disclosure - Accumulated Other Comprehensive (Loss) Income (Tables)
# Accumulated Other Comprehensive (Loss) Income (Tables)
# 42
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R43.htm
# 1044 - Disclosure - Derivative Instruments and Hedging Activities (Tables)
# Derivative Instruments and Hedging Activities (Tables)
# 43
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R44.htm
# 1045 - Disclosure - Retirement Benefit Plans (Tables)
# Retirement Benefit Plans (Tables)
# 44
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R45.htm
# 1046 - Disclosure - Income Taxes (Tables)
# Income Taxes (Tables)
# 45
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R46.htm
# 1047 - Disclosure - Capital Stock and Earnings per Share (Tables)
# Capital Stock and Earnings per Share (Tables)
# 46
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R47.htm
# 1048 - Disclosure - Segment Data (Tables)
# Segment Data (Tables)
# 47
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R48.htm
# 1049 - Disclosure - Leases (Tables)
# Leases (Tables)
# 48
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R49.htm
# 1050 - Disclosure - Quarterly Financial Information (Unaudited) (Tables)
# Quarterly Financial Information (Unaudited) (Tables)
# 49
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R50.htm
# 1051 - Disclosure - Revision of Prior Period Financial Statements - Additional Information (Detail)
# Revision of Prior Period Financial Statements - Additional Information (Detail)
# 50
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R51.htm
# 1052 - Disclosure - Revision of Prior Period Financial Statements - Revisions to the Consolidated Statements of Earnings and Comprehensive Income (Loss) (Detail)
# Revision of Prior Period Financial Statements - Revisions to the Consolidated Statements of Earnings and Comprehensive Income (Loss) (Detail)
# 51
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R52.htm
# 1053 - Disclosure - Revision of Prior Period Financial Statements - Revisions to the Consolidated Balance Sheet (Detail)
# Revision of Prior Period Financial Statements - Revisions to the Consolidated Balance Sheet (Detail)
# 52
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R53.htm
# 1054 - Disclosure - Revision of Prior Period Financial Statements - Revisions to the Consolidated Statements of Cash Flows (Detail)
# Revision of Prior Period Financial Statements - Revisions to the Consolidated Statements of Cash Flows (Detail)
# 53
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R54.htm
# 1055 - Disclosure - Significant Accounting Policies - Additional Information (Detail)
# Significant Accounting Policies - Additional Information (Detail)
# 54
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R55.htm
# 1056 - Disclosure - Significant Accounting Policies - Summary of Expenses in Special Items (Detail)
# Significant Accounting Policies - Summary of Expenses in Special Items (Detail)
# 55
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R56.htm
# 1057 - Disclosure - Significant Accounting Policies - Summary of Liabilities Related to Integration Plans (Detail)
# Significant Accounting Policies - Summary of Liabilities Related to Integration Plans (Detail)
# 56
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R57.htm
# 1058 - Disclosure - Business Combinations - Additional Information (Detail)
# Business Combinations - Additional Information (Detail)
# 57
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R58.htm
# 1059 - Disclosure - Business Combinations - Summary of Preliminary Fair Values of Assets Acquired and Liabilities Assumed (Detail)
# Business Combinations - Summary of Preliminary Fair Values of Assets Acquired and Liabilities Assumed (Detail)
# 58
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R59.htm
# 1060 - Disclosure - Business Combinations - Pro forma Financial Information Adjusted to Give Effect to the Merger (Detail)
# Business Combinations - Pro forma Financial Information Adjusted to Give Effect to the Merger (Detail)
# 59
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R60.htm
# 1061 - Disclosure - Share-Based Compensation - Share-Based Compensation Expense (Detail)
# Share-Based Compensation - Share-Based Compensation Expense (Detail)
# 60
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R61.htm
# 1062 - Disclosure - Share-Based Compensation - Additional Information (Detail)
# Share-Based Compensation - Additional Information (Detail)
# 61
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R62.htm
# 1063 - Disclosure - Share-Based Compensation - Summary of Stock Option Activity (Detail)
# Share-Based Compensation - Summary of Stock Option Activity (Detail)
# 62
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R63.htm
# 1064 - Disclosure - Share-Based Compensation - Weighted Average Fair Value for Stock Options Granted (Detail)
# Share-Based Compensation - Weighted Average Fair Value for Stock Options Granted (Detail)
# 63
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R64.htm
# 1065 - Disclosure - Share-Based Compensation - Summary of Nonvested RSU Activity (Detail)
# Share-Based Compensation - Summary of Nonvested RSU Activity (Detail)
# 64
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R65.htm
# 1066 - Disclosure - Inventories - Summary of Inventories (Detail)
# Inventories - Summary of Inventories (Detail)
# 65
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R66.htm
# 1067 - Disclosure - Inventories - Additional Information (Detail)
# Inventories - Additional Information (Detail)
# 66
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R67.htm
# 1068 - Disclosure - Property, Plant and Equipment - Summary of Property, Plant and Equipment (Detail)
# Property, Plant and Equipment - Summary of Property, Plant and Equipment (Detail)
# 67
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R68.htm
# 1069 - Disclosure - Property, Plant and Equipment - Additional Information (Detail)
# Property, Plant and Equipment - Additional Information (Detail)
# 68
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R69.htm
# 1070 - Disclosure - Investments - Investments in Short and Long-Term Classified as Available-for-Sale Securities (Detail)
# Investments - Investments in Short and Long-Term Classified as Available-for-Sale Securities (Detail)
# 69
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R70.htm
# 1071 - Disclosure - Investments - Cost and Fair Value of Available-for-Sale Fixed-Maturity Securities by Contractual Maturity (Detail)
# Investments - Cost and Fair Value of Available-for-Sale Fixed-Maturity Securities by Contractual Maturity (Detail)
# 70
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R71.htm
# 1072 - Disclosure - Fair Value Measurements of Assets and Liabilities - Fair Value Measurements of Assets and Liabilities (Detail)
# Fair Value Measurements of Assets and Liabilities - Fair Value Measurements of Assets and Liabilities (Detail)
# 71
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R72.htm
# 1073 - Disclosure - Goodwill and Other Intangible Assets - Changes in Carrying Amount of Goodwill (Detail)
# Goodwill and Other Intangible Assets - Changes in Carrying Amount of Goodwill (Detail)
# 72
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R73.htm
# 1074 - Disclosure - Goodwill and Other Intangible Assets - Components of Identifiable Intangible Assets (Detail)
# Goodwill and Other Intangible Assets - Components of Identifiable Intangible Assets (Detail)
# 73
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R74.htm
# 1075 - Disclosure - Goodwill and Other Intangible Assets - Additional Information (Detail)
# Goodwill and Other Intangible Assets - Additional Information (Detail)
# 74
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R75.htm
# 1076 - Disclosure - Goodwill and Other Intangible Assets - Estimated Annual Amortization Expense Based on Intangible Assets Recognized (Detail)
# Goodwill and Other Intangible Assets - Estimated Annual Amortization Expense Based on Intangible Assets Recognized (Detail)
# 75
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R76.htm
# 1077 - Disclosure - Other Current and Long-term Liabilities - Summary of Other Current and Long-Term Liabilities (Detail)
# Other Current and Long-term Liabilities - Summary of Other Current and Long-Term Liabilities (Detail)
# 76
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R77.htm
# 1078 - Disclosure - Debt - Summary of Debt Instruments (Detail)
# Debt - Summary of Debt Instruments (Detail)
# 77
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R78.htm
# 1079 - Disclosure - Debt - Summary of Debt Instruments (Parenthetical) (Detail)
# Debt - Summary of Debt Instruments (Parenthetical) (Detail)
# 78
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R79.htm
# 1080 - Disclosure - Debt - Additional Information (Detail)
# Debt - Additional Information (Detail)
# 79
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R80.htm
# 1081 - Disclosure - Accumulated Other Comprehensive (Loss) Income - Changes in Components of Other Comprehensive Income, Net of Tax (Detail)
# Accumulated Other Comprehensive (Loss) Income - Changes in Components of Other Comprehensive Income, Net of Tax (Detail)
# 80
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R81.htm
# 1082 - Disclosure - Accumulated Other Comprehensive (Loss) Income - Reclassification Adjustments from Accumulated Other Comprehensive Income (Detail)
# Accumulated Other Comprehensive (Loss) Income - Reclassification Adjustments from Accumulated Other Comprehensive Income (Detail)
# 81
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R82.htm
# 1083 - Disclosure - Accumulated Other Comprehensive (Loss) Income - Tax Effects on Each Component of Other Comprehensive Income Recognized in Statements of Comprehensive Income (Detail)
# Accumulated Other Comprehensive (Loss) Income - Tax Effects on Each Component of Other Comprehensive Income Recognized in Statements of Comprehensive Income (Detail)
# 82
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R83.htm
# 1084 - Disclosure - Derivative Instruments and Hedging Activities - Additional Information (Detail)
# Derivative Instruments and Hedging Activities - Additional Information (Detail)
# 83
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R84.htm
# 1085 - Disclosure - Derivative Instruments and Hedging Activities - Derivative Instruments Designated as Fair Value Hedges (Detail)
# Derivative Instruments and Hedging Activities - Derivative Instruments Designated as Fair Value Hedges (Detail)
# 84
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R85.htm
# 1086 - Disclosure - Derivative Instruments and Hedging Activities - Gross Unrealized Losses from Derivative Instruments (Detail)
# Derivative Instruments and Hedging Activities - Gross Unrealized Losses from Derivative Instruments (Detail)
# 85
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R86.htm
# 1087 - Disclosure - Derivative Instruments and Hedging Activities - Derivative Instruments Not Designated as Hedging Instruments (Detail)
# Derivative Instruments and Hedging Activities - Derivative Instruments Not Designated as Hedging Instruments (Detail)
# 86
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R87.htm
# 1088 - Disclosure - Derivative Instruments and Hedging Activities - Fair Value of Derivative Instruments on Gross Basis (Detail)
# Derivative Instruments and Hedging Activities - Fair Value of Derivative Instruments on Gross Basis (Detail)
# 87
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R88.htm
# 1089 - Disclosure - Derivative Instruments and Hedging Activities - Schedule of Effects of Master Netting Agreements on Consolidated Balance Sheets (Detail)
# Derivative Instruments and Hedging Activities - Schedule of Effects of Master Netting Agreements on Consolidated Balance Sheets (Detail)
# 88
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R89.htm
# 1090 - Disclosure - Retirement Benefit Plans - Components of Net Pension Expense (Detail)
# Retirement Benefit Plans - Components of Net Pension Expense (Detail)
# 89
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R90.htm
# 1091 - Disclosure - Retirement Benefit Plans - Weighted Average Actuarial Assumptions Used to Determine Net Pension Expense for Our Defined Benefit Retirement Plans (Detail)
# Retirement Benefit Plans - Weighted Average Actuarial Assumptions Used to Determine Net Pension Expense for Our Defined Benefit Retirement Plans (Detail)
# 90
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R91.htm
# 1092 - Disclosure - Retirement Benefit Plans - Changes in Projected Benefit Obligations and Plan Assets (Detail)
# Retirement Benefit Plans - Changes in Projected Benefit Obligations and Plan Assets (Detail)
# 91
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R92.htm
# 1093 - Disclosure - Retirement Benefit Plan - Changes in Fair Value of Plan Assets (Detail)
# Retirement Benefit Plan - Changes in Fair Value of Plan Assets (Detail)
# 92
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R93.htm
# 1094 - Disclosure - Retirement Benefit Plan - Summary of Amounts Recognized in Balance Sheet (Detail)
# Retirement Benefit Plan - Summary of Amounts Recognized in Balance Sheet (Detail)
# 93
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R94.htm
# 1095 - Disclosure - Retirement Benefit Plan - Summary of Amounts Recognized in Other Comprehensive Income Income (Detail)
# Retirement Benefit Plan - Summary of Amounts Recognized in Other Comprehensive Income Income (Detail)
# 94
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R95.htm
# 1096 - Disclosure - Retirement Benefit Plans - Weighted Average Actuarial Assumptions Used to Determine Projected Benefit Obligation for Defined Benefit Retirement Plans (Detail)
# Retirement Benefit Plans - Weighted Average Actuarial Assumptions Used to Determine Projected Benefit Obligation for Defined Benefit Retirement Plans (Detail)
# 95
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R96.htm
# 1097 - Disclosure - Retirement Benefit Plans - Plans with Benefit Obligations in Excess of Plan Assets (Detail)
# Retirement Benefit Plans - Plans with Benefit Obligations in Excess of Plan Assets (Detail)
# 96
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R97.htm
# 1098 - Disclosure - Retirement Benefit Plans - Total Accumulated Benefit Obligations and Plans with Accumulated Benefit Obligations in Excess of Plan Assets (Detail)
# Retirement Benefit Plans - Total Accumulated Benefit Obligations and Plans with Accumulated Benefit Obligations in Excess of Plan Assets (Detail)
# 97
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R98.htm
# 1099 - Disclosure - Retirement Benefit Plans - Summary of Benefits Expected to be Paid Out (Detail)
# Retirement Benefit Plans - Summary of Benefits Expected to be Paid Out (Detail)
# 98
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R99.htm
# 1100 - Disclosure - Retirement Benefit Plans - Additional Information (Detail)
# Retirement Benefit Plans - Additional Information (Detail)
# 99
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R100.htm
# 1101 - Disclosure - Retirement Benefit Plans - Fair Value of U.S. and Puerto Rico Pension Plan Assets (Detail)
# Retirement Benefit Plans - Fair Value of U.S. and Puerto Rico Pension Plan Assets (Detail)
# 100
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R101.htm
# 1102 - Disclosure - Retirement Benefit Plans - Fair Value of Foreign Pension Plan Assets (Detail)
# Retirement Benefit Plans - Fair Value of Foreign Pension Plan Assets (Detail)
# 101
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R102.htm
# 1103 - Disclosure - Retirement Benefit Plans - Reconciliation of Beginning and Ending Balances of Foreign Pension Plan Assets Measured at Fair Value (Detail)
# Retirement Benefit Plans - Reconciliation of Beginning and Ending Balances of Foreign Pension Plan Assets Measured at Fair Value (Detail)
# 102
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R103.htm
# 1104 - Disclosure - Income Taxes - Components of Earnings Before Taxes and Income Taxes Paid (Detail)
# Income Taxes - Components of Earnings Before Taxes and Income Taxes Paid (Detail)
# 103
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R104.htm
# 1105 - Disclosure - Income Taxes - Reconciliation of U.S. Statutory Income Tax Rate to Our Effective Tax Rate (Detail)
# Income Taxes - Reconciliation of U.S. Statutory Income Tax Rate to Our Effective Tax Rate (Detail)
# 104
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R105.htm
# 1106 - Disclosure - Income Taxes - Components of Deferred Taxes (Detail)
# Income Taxes - Components of Deferred Taxes (Detail)
# 105
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R106.htm
# 1107 - Disclosure - Income Taxes - Additional Information (Detail)
# Income Taxes - Additional Information (Detail)
# 106
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R107.htm
# 1108 - Disclosure - Income Taxes - Tabular Reconciliation of Total Amounts of Unrecognized Tax Benefits (Detail)
# Income Taxes - Tabular Reconciliation of Total Amounts of Unrecognized Tax Benefits (Detail)
# 107
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R108.htm
# 1109 - Disclosure - Capital Stock and Earnings per Share - Additional Information (Detail)
# Capital Stock and Earnings per Share - Additional Information (Detail)
# 108
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R109.htm
# 1110 - Disclosure - Capital Stock and Earnings per Share - Reconciliation of Weighted Average Share for Basic and Diluted Share Computations (Detail)
# Capital Stock and Earnings per Share - Reconciliation of Weighted Average Share for Basic and Diluted Share Computations (Detail)
# 109
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R110.htm
# 1111 - Disclosure - Segment Data - Additional Information (Detail)
# Segment Data - Additional Information (Detail)
# 110
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R111.htm
# 1112 - Disclosure - Segment Data - Summary of Net Sales and Other Information by Segment (Detail)
# Segment Data - Summary of Net Sales and Other Information by Segment (Detail)
# 111
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R112.htm
# 1113 - Disclosure - Segment Data - Disclosure on Geographic Areas, Long-Lived Assets (Detail)
# Segment Data - Disclosure on Geographic Areas, Long-Lived Assets (Detail)
# 112
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R113.htm
# 1114 - Disclosure - Segment Data - Summary of Net Sales by Product Category (Detail)
# Segment Data - Summary of Net Sales by Product Category (Detail)
# 113
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R114.htm
# 1115 - Disclosure - Leases - Additional Information (Detail)
# Leases - Additional Information (Detail)
# 114
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R115.htm
# 1116 - Disclosure - Leases - Schedule of Future Minimum Rental Commitments Under Non-Cancelable Operating Leases (Detail)
# Leases - Schedule of Future Minimum Rental Commitments Under Non-Cancelable Operating Leases (Detail)
# 115
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R116.htm
# 1117 - Disclosure - Commitments and Contingencies - Additional Information (Detail)
# Commitments and Contingencies - Additional Information (Detail)
# 116
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R117.htm
# 1118 - Disclosure - Quarterly Financial Information (Unaudited) - Quarterly Financial Information (Unaudited) (Detail)
# Quarterly Financial Information (Unaudited) - Quarterly Financial Information (Unaudited) (Detail)
# 117
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1136869/000119312516485039/R118.htm
# 1119 - Disclosure - Schedule - Valuation and Qualifying Accounts (Detail)
# Schedule - Valuation and Qualifying Accounts (Detail)
# 118

# %% [markdown]
# ## Grabbing the Financial Statements
#
# 1. Balance Sheet
# 2. Statement of Cash Flows
# 3. Income Statement
# 4. Statement of Stock Holder Equity

# %%
# TO-DO: Figure out how to standardize getting the consolidated financial statements because they are not the same between
#        Booz Allen and the company Sigma Coding analyzed

#####################################################################################

#create the list to hold the statement urls
statements_url = []

for report_dict in master_reports:
    # define the statements we want to look for.
    
    item1 = r"CONSOLIDATED"
    item2 = r"PARENTHETICAL"
    
    if item1 in report_dict['name_short'].upper() and item2 not in report_dict['name_short'].upper() and report_dict['position'] < 11:
        print(report_dict['position'])
        
        statements_url.append(report_dict['url'])
# Out:
# 2
# 3
# 4
# 6
# 7

# %% [markdown]
# ## Scraping the Financial Statements

# %%
#assuming we want all the statements in a single data set
statements_data = []

#loop through each statement url
for statement in statements_url:
    
    #define a dictionary that will store the different parts of the statement
    statement_data = {}
    statement_data['headers'] = []
    statement_data['sections'] = []
    statement_data['data'] = []
    
    #request the statement file content
    content = requests.get(statement, headers=user_agent).content
    report_soup = BeautifulSoup(content, 'html')
    
    #find all the rows, figure out what type of row it is, parse the elements, and store in teh statement file list.
    #tr = table row
    for index, row in enumerate(report_soup.table.find_all('tr')):
        
        #first let's get all the elements (td = standard data cell)
        # cols represents elements in the row
        cols = row.find_all('td')
            
        # if it's a regular row and not a section or a table header (th = header, strong = important)
        if (len(row.find_all('th')) == 0 and len(row.find_all('table')) == 0): # and len(row.find_all('strong')) == 0:
            reg_row = []
            for ele in cols:
                
                if len(row.find_all('strong')) != 0:
                    reg_row.append(ele.text.strip().upper())
                else:
                    reg_row.append(ele.text.strip())
            
            #check if it is a section label and store that it in sec_row
            if len(row.find_all('strong')) != 0:
                sec_row = cols[0].text.strip().upper()
                statement_data['sections'].append(sec_row)
                    
    
                
            #reg_row = [ele.text.strip() for ele in cols]
            statement_data['data'].append(reg_row)
        
        #if it's a regular row and a section but not a table header
        #elif (len(row.find_all('th')) == 0 and len(row.find_all('strong')) != 0):
            #sec_row = cols[0].text.strip().upper()
            #statement_data['sections'].append(sec_row)
            
        #finally if it's not any of those it must be a header
        elif (len(row.find_all('th')) != 0):
            hed_row = []
            for ele in row.find_all('th'):
                if (len(ele.find_all('sup'))) == 0:
                    hed_row.append(ele.text.strip())
            statement_data['headers'].append(hed_row)
            
        else:
            print("We encountered an error")
    
    statements_data.append(statement_data)

# %% [markdown]
# ## Converting the Data into a Data Frame

# %% [markdown]
# Let's do the Balance Sheet

# %%
document_num = 0
print(statements_data[document_num]['data'])
# Out:
# [['INCOME STATEMENT [ABSTRACT]', '', '', ''], ['Net Sales', '$ 5,997.8', '$ 4,673.3', '$ 4,623.4'], ['Cost of products sold, excluding intangible asset amortization', '1,800.6', '1,242.8', '1,266.7'], ['Intangible asset amortization', '337.4', '92.5', '78.5'], ['Research and development', '268.8', '187.4', '203.0'], ['Selling, general and administrative', '2,284.2', '1,750.7', '1,749.3'], ['Certain claims (Note 20)', '7.7', '21.5', '47.0'], ['Special items (Note 3)', '831.8', '341.1', '210.3'], ['Operating expenses', '5,530.5', '3,636.0', '3,554.8'], ['Operating Profit', '467.3', '1,037.3', '1,068.6'], ['Other expense, net', '(36.9)', '(46.7)', '(6.0)'], ['Interest income', '9.4', '11.9', '15.6'], ['Interest expense', '(286.6)', '(63.1)', '(70.1)'], ['Earnings before income taxes', '153.2', '939.4', '1,008.1'], ['Provision for income taxes', '7.0', '220.2', '229.5'], ['Net earnings', '146.2', '719.2', '778.6'], ['Less: Net loss attributable to noncontrolling interest', '(0.8)', '(1.1)', '(1.8)'], ['Net Earnings of Zimmer Biomet Holdings, Inc.', '$ 147.0', '$ 720.3', '$ 780.4'], ['Earnings Per Common Share - Basic', '$ 0.78', '$ 4.26', '$ 4.60'], ['Earnings Per Common Share - Diluted', '$ 0.77', '$ 4.20', '$ 4.54'], ['WEIGHTED AVERAGE COMMON SHARES OUTSTANDING', '', '', ''], ['Basic', '187.4', '169.0', '169.6'], ['Diluted', '189.8', '171.7', '171.8'], ['Cash Dividends Declared Per Common Share', '$ 0.88', '$ 0.88', '$ 0.80']]

# %%
#define what document you want to convert (0 to n documents)
document_num = 3


#balance_header = statements_data[0]['headers'][-1]
balance_data = statements_data[document_num]['data']

df = pd.DataFrame(balance_data)


#Define the Index column, rename it, and we need to make sure to drop the old column once we reindex
df.index = df[0]
#df.index.name = 'Category'
df = df.drop(0, axis = 1)


# Get rid of the '$', '(', ')', and convert the '' to NaNs.
df = df.replace('[\$,)]','', regex=True )\
                     .replace( '[(]','-', regex=True)\
                     .replace( '', 'NaN', regex=True)


# Display
print('-'*100)
print('Before type conversion')
print('-'*100)
print(statements_data[document_num]['headers'])
display(df)
# Out:
# ----------------------------------------------------------------------------------------------------
# Before type conversion
# ----------------------------------------------------------------------------------------------------
# [["Consolidated Statements of Stockholders' Equity - USD ($) shares in Millions, $ in Millions", 'Total', 'Common Shares [Member]', 'Paid-in Capital [Member]', 'Retained Earnings [Member]', 'Accumulated Other Comprehensive (Loss) Income [Member]', 'Treasury Shares [Member]', 'Noncontrolling Interest [Member]']]
#                                                           1      2        3  \
# 0
# Balance at Dec. 31, 2012                             5848.0    2.6   3500.6
# Balance, shares at Dec. 31, 2012                        NaN  257.1      NaN
# Net earnings                                          778.6    NaN      NaN
# Other comprehensive income (loss)                      32.4    NaN      NaN
# Purchase of additional shares from noncontrolli...     -1.7    NaN     -1.1
# Cash dividends declared                              -135.4    NaN      NaN
# Stock compensation plans, including tax benefits      507.7    NaN    501.1
# Stock compensation plans, including tax benefit...      NaN    7.2      NaN
# Share repurchases                                    -719.0    NaN      NaN
# Share repurchases, shares                               NaN    NaN      NaN
# Balance at Dec. 31, 2013                             6310.6    2.6   4000.6
# Balance, shares at Dec. 31, 2013                        NaN  264.3      NaN
# Net earnings                                          719.2    NaN      NaN
# Other comprehensive income (loss)                    -262.7    NaN      NaN
# Cash dividends declared                              -148.6    NaN      NaN
# Stock compensation plans, including tax benefits      333.7    0.1    330.1
# Stock compensation plans, including tax benefit...      NaN    4.1      NaN
# Share repurchases                                    -400.5    NaN      NaN
# Share repurchases, shares                               NaN    NaN      NaN
# Balance at Dec. 31, 2014                             6551.7    2.7   4330.7
# Balance, shares at Dec. 31, 2014                        NaN  268.4      NaN
# Net earnings                                          146.2    NaN      NaN
# Other comprehensive income (loss)                    -366.6    NaN      NaN
# Cash dividends declared                              -164.4    NaN      NaN
# Stock compensation plans, including tax benefits      149.8    NaN    142.2
# Stock compensation plans, including tax benefit...      NaN    1.6      NaN
# Share repurchases                                    -150.0    NaN      NaN
# Share repurchases, shares                              -1.4    NaN      NaN
# Biomet merger consideration                          3722.7    0.3   3722.4
# Biomet merger consideration, shares                     NaN   32.7      NaN
# Balance at Dec. 31, 2015                             9889.4    3.0   8195.3
# Balance, shares at Dec. 31, 2015                        NaN  302.7      NaN
#
#                                                           4        5  \
# 0
# Balance at Dec. 31, 2012                             7143.2    268.3
# Balance, shares at Dec. 31, 2012                        NaN      NaN
# Net earnings                                          780.4      NaN
# Other comprehensive income (loss)                       NaN     32.6
# Purchase of additional shares from noncontrolli...      NaN      NaN
# Cash dividends declared                              -135.4      NaN
# Stock compensation plans, including tax benefits        1.2      NaN
# Stock compensation plans, including tax benefit...      NaN      NaN
# Share repurchases                                       NaN      NaN
# Share repurchases, shares                               NaN      NaN
# Balance at Dec. 31, 2013                             7789.4    300.9
# Balance, shares at Dec. 31, 2013                        NaN      NaN
# Net earnings                                          720.3      NaN
# Other comprehensive income (loss)                       NaN   -262.8
# Cash dividends declared                              -148.6      NaN
# Stock compensation plans, including tax benefits        1.0      NaN
# Stock compensation plans, including tax benefit...      NaN      NaN
# Share repurchases                                       NaN      NaN
# Share repurchases, shares                               NaN      NaN
# Balance at Dec. 31, 2014                             8362.1     38.1
# Balance, shares at Dec. 31, 2014                        NaN      NaN
# Net earnings                                          147.0      NaN
# Other comprehensive income (loss)                       NaN   -367.1
# Cash dividends declared                              -164.4      NaN
# Stock compensation plans, including tax benefits        3.0      NaN
# Stock compensation plans, including tax benefit...      NaN      NaN
# Share repurchases                                       NaN      NaN
# Share repurchases, shares                               NaN      NaN
# Biomet merger consideration                             NaN      NaN
# Biomet merger consideration, shares                     NaN      NaN
# Balance at Dec. 31, 2015                             8347.7   -329.0
# Balance, shares at Dec. 31, 2015                        NaN      NaN
#
#                                                            6     7
# 0
# Balance at Dec. 31, 2012                             -5072.1   5.4
# Balance, shares at Dec. 31, 2012                       -85.5   NaN
# Net earnings                                             NaN  -1.8
# Other comprehensive income (loss)                        NaN  -0.2
# Purchase of additional shares from noncontrolli...       NaN  -0.6
# Cash dividends declared                                  NaN   NaN
# Stock compensation plans, including tax benefits         5.4   NaN
# Stock compensation plans, including tax benefit...       0.1   NaN
# Share repurchases                                     -719.0   NaN
# Share repurchases, shares                               -9.1   NaN
# Balance at Dec. 31, 2013                             -5785.7   2.8
# Balance, shares at Dec. 31, 2013                       -94.5   NaN
# Net earnings                                             NaN  -1.1
# Other comprehensive income (loss)                        NaN   0.1
# Cash dividends declared                                  NaN   NaN
# Stock compensation plans, including tax benefits         2.5   NaN
# Stock compensation plans, including tax benefit...       NaN   NaN
# Share repurchases                                     -400.5   NaN
# Share repurchases, shares                               -4.2   NaN
# Balance at Dec. 31, 2014                             -6183.7   1.8
# Balance, shares at Dec. 31, 2014                       -98.7   NaN
# Net earnings                                             NaN  -0.8
# Other comprehensive income (loss)                        NaN   0.5
# Cash dividends declared                                  NaN   NaN
# Stock compensation plans, including tax benefits         4.6   NaN
# Stock compensation plans, including tax benefit...       0.1   NaN
# Share repurchases                                     -150.0   NaN
# Share repurchases, shares                               -1.4   NaN
# Biomet merger consideration                              NaN   NaN
# Biomet merger consideration, shares                      NaN   NaN
# Balance at Dec. 31, 2015                             -6329.1   1.5
# Balance, shares at Dec. 31, 2015                      -100.0   NaN

# %%
    
for i in range(df.shape[1]):
    df[df.columns[i]] = df[df.columns[i]].apply(change_to_float)    
df = df.astype(float)
df = get_rid_of_null_columns(df)
display(df)
print(df.shape)
# Out:
#                                                           1       2        3  \
# 0
# Balance at Dec. 31, 2012                            58480.0    26.0  35006.0
# Balance, shares at Dec. 31, 2012                        NaN  2571.0      NaN
# Net earnings                                         7786.0     NaN      NaN
# Other comprehensive income (loss)                     324.0     NaN      NaN
# Purchase of additional shares from noncontrolli...    -17.0     NaN    -11.0
# Cash dividends declared                             -1354.0     NaN      NaN
# Stock compensation plans, including tax benefits     5077.0     NaN   5011.0
# Stock compensation plans, including tax benefit...      NaN    72.0      NaN
# Share repurchases                                   -7190.0     NaN      NaN
# Share repurchases, shares                               NaN     NaN      NaN
# Balance at Dec. 31, 2013                            63106.0    26.0  40006.0
# Balance, shares at Dec. 31, 2013                        NaN  2643.0      NaN
# Net earnings                                         7192.0     NaN      NaN
# Other comprehensive income (loss)                   -2627.0     NaN      NaN
# Cash dividends declared                             -1486.0     NaN      NaN
# Stock compensation plans, including tax benefits     3337.0     1.0   3301.0
# Stock compensation plans, including tax benefit...      NaN    41.0      NaN
# Share repurchases                                   -4005.0     NaN      NaN
# Share repurchases, shares                               NaN     NaN      NaN
# Balance at Dec. 31, 2014                            65517.0    27.0  43307.0
# Balance, shares at Dec. 31, 2014                        NaN  2684.0      NaN
# Net earnings                                         1462.0     NaN      NaN
# Other comprehensive income (loss)                   -3666.0     NaN      NaN
# Cash dividends declared                             -1644.0     NaN      NaN
# Stock compensation plans, including tax benefits     1498.0     NaN   1422.0
# Stock compensation plans, including tax benefit...      NaN    16.0      NaN
# Share repurchases                                   -1500.0     NaN      NaN
# Share repurchases, shares                             -14.0     NaN      NaN
# Biomet merger consideration                         37227.0     3.0  37224.0
# Biomet merger consideration, shares                     NaN   327.0      NaN
# Balance at Dec. 31, 2015                            98894.0    30.0  81953.0
# Balance, shares at Dec. 31, 2015                        NaN  3027.0      NaN
#
#                                                           4       5        6  \
# 0
# Balance at Dec. 31, 2012                            71432.0  2683.0 -50721.0
# Balance, shares at Dec. 31, 2012                        NaN     NaN   -855.0
# Net earnings                                         7804.0     NaN      NaN
# Other comprehensive income (loss)                       NaN   326.0      NaN
# Purchase of additional shares from noncontrolli...      NaN     NaN      NaN
# Cash dividends declared                             -1354.0     NaN      NaN
# Stock compensation plans, including tax benefits       12.0     NaN     54.0
# Stock compensation plans, including tax benefit...      NaN     NaN      1.0
# Share repurchases                                       NaN     NaN  -7190.0
# Share repurchases, shares                               NaN     NaN    -91.0
# Balance at Dec. 31, 2013                            77894.0  3009.0 -57857.0
# Balance, shares at Dec. 31, 2013                        NaN     NaN   -945.0
# Net earnings                                         7203.0     NaN      NaN
# Other comprehensive income (loss)                       NaN -2628.0      NaN
# Cash dividends declared                             -1486.0     NaN      NaN
# Stock compensation plans, including tax benefits       10.0     NaN     25.0
# Stock compensation plans, including tax benefit...      NaN     NaN      NaN
# Share repurchases                                       NaN     NaN  -4005.0
# Share repurchases, shares                               NaN     NaN    -42.0
# Balance at Dec. 31, 2014                            83621.0   381.0 -61837.0
# Balance, shares at Dec. 31, 2014                        NaN     NaN   -987.0
# Net earnings                                         1470.0     NaN      NaN
# Other comprehensive income (loss)                       NaN -3671.0      NaN
# Cash dividends declared                             -1644.0     NaN      NaN
# Stock compensation plans, including tax benefits       30.0     NaN     46.0
# Stock compensation plans, including tax benefit...      NaN     NaN      1.0
# Share repurchases                                       NaN     NaN  -1500.0
# Share repurchases, shares                               NaN     NaN    -14.0
# Biomet merger consideration                             NaN     NaN      NaN
# Biomet merger consideration, shares                     NaN     NaN      NaN
# Balance at Dec. 31, 2015                            83477.0 -3290.0 -63291.0
# Balance, shares at Dec. 31, 2015                        NaN     NaN  -1000.0
#
#                                                        7
# 0
# Balance at Dec. 31, 2012                            54.0
# Balance, shares at Dec. 31, 2012                     NaN
# Net earnings                                       -18.0
# Other comprehensive income (loss)                   -2.0
# Purchase of additional shares from noncontrolli...  -6.0
# Cash dividends declared                              NaN
# Stock compensation plans, including tax benefits     NaN
# Stock compensation plans, including tax benefit...   NaN
# Share repurchases                                    NaN
# Share repurchases, shares                            NaN
# Balance at Dec. 31, 2013                            28.0
# Balance, shares at Dec. 31, 2013                     NaN
# Net earnings                                       -11.0
# Other comprehensive income (loss)                    1.0
# Cash dividends declared                              NaN
# Stock compensation plans, including tax benefits     NaN
# Stock compensation plans, including tax benefit...   NaN
# Share repurchases                                    NaN
# Share repurchases, shares                            NaN
# Balance at Dec. 31, 2014                            18.0
# Balance, shares at Dec. 31, 2014                     NaN
# Net earnings                                        -8.0
# Other comprehensive income (loss)                    5.0
# Cash dividends declared                              NaN
# Stock compensation plans, including tax benefits     NaN
# Stock compensation plans, including tax benefit...   NaN
# Share repurchases                                    NaN
# Share repurchases, shares                            NaN
# Biomet merger consideration                          NaN
# Biomet merger consideration, shares                  NaN
# Balance at Dec. 31, 2015                            15.0
# Balance, shares at Dec. 31, 2015                     NaN
# (32, 7)

# %%
#below is to account for the headers having multiple levels versus only one level
if len(statements_data[document_num]['headers']) == 1:
    header = statements_data[document_num]['headers'][0][1:]
    document = statements_data[document_num]['headers'][0][0]
    
elif len(statements_data[document_num]['headers']) == 2:
    header = statements_data[document_num]['headers'][-1]
    document = statements_data[document_num]['headers'][0][0] 
else:
    header = df.columns
    document = 'Category'
    
    
    
print(header)
print(document)
# Out:
# ['Total', 'Common Shares [Member]', 'Paid-in Capital [Member]', 'Retained Earnings [Member]', 'Accumulated Other Comprehensive (Loss) Income [Member]', 'Treasury Shares [Member]', 'Noncontrolling Interest [Member]']
# Consolidated Statements of Stockholders' Equity - USD ($) shares in Millions, $ in Millions

# %%
# everything is a string, so let's convert all the data to a float
df = df.astype(float)

#Change the column headers 
df.columns = header

#Change the name of the index
df.index.name = document

#Display
print('-'*100)
print('Final Product')
print('-'*100)

#show the df
df
# Out:
# ----------------------------------------------------------------------------------------------------
# Final Product
# ----------------------------------------------------------------------------------------------------
#                                                       Total  \
# Consolidated Statements of Stockholders' Equity...
# Balance at Dec. 31, 2012                            58480.0
# Balance, shares at Dec. 31, 2012                        NaN
# Net earnings                                         7786.0
# Other comprehensive income (loss)                     324.0
# Purchase of additional shares from noncontrolli...    -17.0
# Cash dividends declared                             -1354.0
# Stock compensation plans, including tax benefits     5077.0
# Stock compensation plans, including tax benefit...      NaN
# Share repurchases                                   -7190.0
# Share repurchases, shares                               NaN
# Balance at Dec. 31, 2013                            63106.0
# Balance, shares at Dec. 31, 2013                        NaN
# Net earnings                                         7192.0
# Other comprehensive income (loss)                   -2627.0
# Cash dividends declared                             -1486.0
# Stock compensation plans, including tax benefits     3337.0
# Stock compensation plans, including tax benefit...      NaN
# Share repurchases                                   -4005.0
# Share repurchases, shares                               NaN
# Balance at Dec. 31, 2014                            65517.0
# Balance, shares at Dec. 31, 2014                        NaN
# Net earnings                                         1462.0
# Other comprehensive income (loss)                   -3666.0
# Cash dividends declared                             -1644.0
# Stock compensation plans, including tax benefits     1498.0
# Stock compensation plans, including tax benefit...      NaN
# Share repurchases                                   -1500.0
# Share repurchases, shares                             -14.0
# Biomet merger consideration                         37227.0
# Biomet merger consideration, shares                     NaN
# Balance at Dec. 31, 2015                            98894.0
# Balance, shares at Dec. 31, 2015                        NaN
#
#                                                     Common Shares [Member]  \
# Consolidated Statements of Stockholders' Equity...
# Balance at Dec. 31, 2012                                              26.0
# Balance, shares at Dec. 31, 2012                                    2571.0
# Net earnings                                                           NaN
# Other comprehensive income (loss)                                      NaN
# Purchase of additional shares from noncontrolli...                     NaN
# Cash dividends declared                                                NaN
# Stock compensation plans, including tax benefits                       NaN
# Stock compensation plans, including tax benefit...                    72.0
# Share repurchases                                                      NaN
# Share repurchases, shares                                              NaN
# Balance at Dec. 31, 2013                                              26.0
# Balance, shares at Dec. 31, 2013                                    2643.0
# Net earnings                                                           NaN
# Other comprehensive income (loss)                                      NaN
# Cash dividends declared                                                NaN
# Stock compensation plans, including tax benefits                       1.0
# Stock compensation plans, including tax benefit...                    41.0
# Share repurchases                                                      NaN
# Share repurchases, shares                                              NaN
# Balance at Dec. 31, 2014                                              27.0
# Balance, shares at Dec. 31, 2014                                    2684.0
# Net earnings                                                           NaN
# Other comprehensive income (loss)                                      NaN
# Cash dividends declared                                                NaN
# Stock compensation plans, including tax benefits                       NaN
# Stock compensation plans, including tax benefit...                    16.0
# Share repurchases                                                      NaN
# Share repurchases, shares                                              NaN
# Biomet merger consideration                                            3.0
# Biomet merger consideration, shares                                  327.0
# Balance at Dec. 31, 2015                                              30.0
# Balance, shares at Dec. 31, 2015                                    3027.0
#
#                                                     Paid-in Capital [Member]  \
# Consolidated Statements of Stockholders' Equity...
# Balance at Dec. 31, 2012                                             35006.0
# Balance, shares at Dec. 31, 2012                                         NaN
# Net earnings                                                             NaN
# Other comprehensive income (loss)                                        NaN
# Purchase of additional shares from noncontrolli...                     -11.0
# Cash dividends declared                                                  NaN
# Stock compensation plans, including tax benefits                      5011.0
# Stock compensation plans, including tax benefit...                       NaN
# Share repurchases                                                        NaN
# Share repurchases, shares                                                NaN
# Balance at Dec. 31, 2013                                             40006.0
# Balance, shares at Dec. 31, 2013                                         NaN
# Net earnings                                                             NaN
# Other comprehensive income (loss)                                        NaN
# Cash dividends declared                                                  NaN
# Stock compensation plans, including tax benefits                      3301.0
# Stock compensation plans, including tax benefit...                       NaN
# Share repurchases                                                        NaN
# Share repurchases, shares                                                NaN
# Balance at Dec. 31, 2014                                             43307.0
# Balance, shares at Dec. 31, 2014                                         NaN
# Net earnings                                                             NaN
# Other comprehensive income (loss)                                        NaN
# Cash dividends declared                                                  NaN
# Stock compensation plans, including tax benefits                      1422.0
# Stock compensation plans, including tax benefit...                       NaN
# Share repurchases                                                        NaN
# Share repurchases, shares                                                NaN
# Biomet merger consideration                                          37224.0
# Biomet merger consideration, shares                                      NaN
# Balance at Dec. 31, 2015                                             81953.0
# Balance, shares at Dec. 31, 2015                                         NaN
#
#                                                     Retained Earnings [Member]  \
# Consolidated Statements of Stockholders' Equity...
# Balance at Dec. 31, 2012                                               71432.0
# Balance, shares at Dec. 31, 2012                                           NaN
# Net earnings                                                            7804.0
# Other comprehensive income (loss)                                          NaN
# Purchase of additional shares from noncontrolli...                         NaN
# Cash dividends declared                                                -1354.0
# Stock compensation plans, including tax benefits                          12.0
# Stock compensation plans, including tax benefit...                         NaN
# Share repurchases                                                          NaN
# Share repurchases, shares                                                  NaN
# Balance at Dec. 31, 2013                                               77894.0
# Balance, shares at Dec. 31, 2013                                           NaN
# Net earnings                                                            7203.0
# Other comprehensive income (loss)                                          NaN
# Cash dividends declared                                                -1486.0
# Stock compensation plans, including tax benefits                          10.0
# Stock compensation plans, including tax benefit...                         NaN
# Share repurchases                                                          NaN
# Share repurchases, shares                                                  NaN
# Balance at Dec. 31, 2014                                               83621.0
# Balance, shares at Dec. 31, 2014                                           NaN
# Net earnings                                                            1470.0
# Other comprehensive income (loss)                                          NaN
# Cash dividends declared                                                -1644.0
# Stock compensation plans, including tax benefits                          30.0
# Stock compensation plans, including tax benefit...                         NaN
# Share repurchases                                                          NaN
# Share repurchases, shares                                                  NaN
# Biomet merger consideration                                                NaN
# Biomet merger consideration, shares                                        NaN
# Balance at Dec. 31, 2015                                               83477.0
# Balance, shares at Dec. 31, 2015                                           NaN
#
#                                                     Accumulated Other Comprehensive (Loss) Income [Member]  \
# Consolidated Statements of Stockholders' Equity...
# Balance at Dec. 31, 2012                                                                       2683.0
# Balance, shares at Dec. 31, 2012                                                                  NaN
# Net earnings                                                                                      NaN
# Other comprehensive income (loss)                                                               326.0
# Purchase of additional shares from noncontrolli...                                                NaN
# Cash dividends declared                                                                           NaN
# Stock compensation plans, including tax benefits                                                  NaN
# Stock compensation plans, including tax benefit...                                                NaN
# Share repurchases                                                                                 NaN
# Share repurchases, shares                                                                         NaN
# Balance at Dec. 31, 2013                                                                       3009.0
# Balance, shares at Dec. 31, 2013                                                                  NaN
# Net earnings                                                                                      NaN
# Other comprehensive income (loss)                                                             -2628.0
# Cash dividends declared                                                                           NaN
# Stock compensation plans, including tax benefits                                                  NaN
# Stock compensation plans, including tax benefit...                                                NaN
# Share repurchases                                                                                 NaN
# Share repurchases, shares                                                                         NaN
# Balance at Dec. 31, 2014                                                                        381.0
# Balance, shares at Dec. 31, 2014                                                                  NaN
# Net earnings                                                                                      NaN
# Other comprehensive income (loss)                                                             -3671.0
# Cash dividends declared                                                                           NaN
# Stock compensation plans, including tax benefits                                                  NaN
# Stock compensation plans, including tax benefit...                                                NaN
# Share repurchases                                                                                 NaN
# Share repurchases, shares                                                                         NaN
# Biomet merger consideration                                                                       NaN
# Biomet merger consideration, shares                                                               NaN
# Balance at Dec. 31, 2015                                                                      -3290.0
# Balance, shares at Dec. 31, 2015                                                                  NaN
#
#                                                     Treasury Shares [Member]  \
# Consolidated Statements of Stockholders' Equity...
# Balance at Dec. 31, 2012                                            -50721.0
# Balance, shares at Dec. 31, 2012                                      -855.0
# Net earnings                                                             NaN
# Other comprehensive income (loss)                                        NaN
# Purchase of additional shares from noncontrolli...                       NaN
# Cash dividends declared                                                  NaN
# Stock compensation plans, including tax benefits                        54.0
# Stock compensation plans, including tax benefit...                       1.0
# Share repurchases                                                    -7190.0
# Share repurchases, shares                                              -91.0
# Balance at Dec. 31, 2013                                            -57857.0
# Balance, shares at Dec. 31, 2013                                      -945.0
# Net earnings                                                             NaN
# Other comprehensive income (loss)                                        NaN
# Cash dividends declared                                                  NaN
# Stock compensation plans, including tax benefits                        25.0
# Stock compensation plans, including tax benefit...                       NaN
# Share repurchases                                                    -4005.0
# Share repurchases, shares                                              -42.0
# Balance at Dec. 31, 2014                                            -61837.0
# Balance, shares at Dec. 31, 2014                                      -987.0
# Net earnings                                                             NaN
# Other comprehensive income (loss)                                        NaN
# Cash dividends declared                                                  NaN
# Stock compensation plans, including tax benefits                        46.0
# Stock compensation plans, including tax benefit...                       1.0
# Share repurchases                                                    -1500.0
# Share repurchases, shares                                              -14.0
# Biomet merger consideration                                              NaN
# Biomet merger consideration, shares                                      NaN
# Balance at Dec. 31, 2015                                            -63291.0
# Balance, shares at Dec. 31, 2015                                     -1000.0
#
#                                                     Noncontrolling Interest [Member]
# Consolidated Statements of Stockholders' Equity...
# Balance at Dec. 31, 2012                                                        54.0
# Balance, shares at Dec. 31, 2012                                                 NaN
# Net earnings                                                                   -18.0
# Other comprehensive income (loss)                                               -2.0
# Purchase of additional shares from noncontrolli...                              -6.0
# Cash dividends declared                                                          NaN
# Stock compensation plans, including tax benefits                                 NaN
# Stock compensation plans, including tax benefit...                               NaN
# Share repurchases                                                                NaN
# Share repurchases, shares                                                        NaN
# Balance at Dec. 31, 2013                                                        28.0
# Balance, shares at Dec. 31, 2013                                                 NaN
# Net earnings                                                                   -11.0
# Other comprehensive income (loss)                                                1.0
# Cash dividends declared                                                          NaN
# Stock compensation plans, including tax benefits                                 NaN
# Stock compensation plans, including tax benefit...                               NaN
# Share repurchases                                                                NaN
# Share repurchases, shares                                                        NaN
# Balance at Dec. 31, 2014                                                        18.0
# Balance, shares at Dec. 31, 2014                                                 NaN
# Net earnings                                                                    -8.0
# Other comprehensive income (loss)                                                5.0
# Cash dividends declared                                                          NaN
# Stock compensation plans, including tax benefits                                 NaN
# Stock compensation plans, including tax benefit...                               NaN
# Share repurchases                                                                NaN
# Share repurchases, shares                                                        NaN
# Biomet merger consideration                                                      NaN
# Biomet merger consideration, shares                                              NaN
# Balance at Dec. 31, 2015                                                        15.0
# Balance, shares at Dec. 31, 2015                                                 NaN

# %%
print(statements_data[document_num]['sections'])
# Out:
# []

# %%
sections = statements_data[document_num]['sections']

for ele in df.index:
    if ele in sections:
        print('True')

df4 = add_tags_for_sections(statements_data[document_num]['sections'], df.copy())
#print(statements_data[document_num]['sections'])
#print(df.index)

df4
# Out:
#                                                       Total  \
# Consolidated Statements of Stockholders' Equity...
# Balance at Dec. 31, 2012                            58480.0
# Balance, shares at Dec. 31, 2012                        NaN
# Net earnings                                         7786.0
# Other comprehensive income (loss)                     324.0
# Purchase of additional shares from noncontrolli...    -17.0
# Cash dividends declared                             -1354.0
# Stock compensation plans, including tax benefits     5077.0
# Stock compensation plans, including tax benefit...      NaN
# Share repurchases                                   -7190.0
# Share repurchases, shares                               NaN
# Balance at Dec. 31, 2013                            63106.0
# Balance, shares at Dec. 31, 2013                        NaN
# Net earnings                                         7192.0
# Other comprehensive income (loss)                   -2627.0
# Cash dividends declared                             -1486.0
# Stock compensation plans, including tax benefits     3337.0
# Stock compensation plans, including tax benefit...      NaN
# Share repurchases                                   -4005.0
# Share repurchases, shares                               NaN
# Balance at Dec. 31, 2014                            65517.0
# Balance, shares at Dec. 31, 2014                        NaN
# Net earnings                                         1462.0
# Other comprehensive income (loss)                   -3666.0
# Cash dividends declared                             -1644.0
# Stock compensation plans, including tax benefits     1498.0
# Stock compensation plans, including tax benefit...      NaN
# Share repurchases                                   -1500.0
# Share repurchases, shares                             -14.0
# Biomet merger consideration                         37227.0
# Biomet merger consideration, shares                     NaN
# Balance at Dec. 31, 2015                            98894.0
# Balance, shares at Dec. 31, 2015                        NaN
#
#                                                     Common Shares [Member]  \
# Consolidated Statements of Stockholders' Equity...
# Balance at Dec. 31, 2012                                              26.0
# Balance, shares at Dec. 31, 2012                                    2571.0
# Net earnings                                                           NaN
# Other comprehensive income (loss)                                      NaN
# Purchase of additional shares from noncontrolli...                     NaN
# Cash dividends declared                                                NaN
# Stock compensation plans, including tax benefits                       NaN
# Stock compensation plans, including tax benefit...                    72.0
# Share repurchases                                                      NaN
# Share repurchases, shares                                              NaN
# Balance at Dec. 31, 2013                                              26.0
# Balance, shares at Dec. 31, 2013                                    2643.0
# Net earnings                                                           NaN
# Other comprehensive income (loss)                                      NaN
# Cash dividends declared                                                NaN
# Stock compensation plans, including tax benefits                       1.0
# Stock compensation plans, including tax benefit...                    41.0
# Share repurchases                                                      NaN
# Share repurchases, shares                                              NaN
# Balance at Dec. 31, 2014                                              27.0
# Balance, shares at Dec. 31, 2014                                    2684.0
# Net earnings                                                           NaN
# Other comprehensive income (loss)                                      NaN
# Cash dividends declared                                                NaN
# Stock compensation plans, including tax benefits                       NaN
# Stock compensation plans, including tax benefit...                    16.0
# Share repurchases                                                      NaN
# Share repurchases, shares                                              NaN
# Biomet merger consideration                                            3.0
# Biomet merger consideration, shares                                  327.0
# Balance at Dec. 31, 2015                                              30.0
# Balance, shares at Dec. 31, 2015                                    3027.0
#
#                                                     Paid-in Capital [Member]  \
# Consolidated Statements of Stockholders' Equity...
# Balance at Dec. 31, 2012                                             35006.0
# Balance, shares at Dec. 31, 2012                                         NaN
# Net earnings                                                             NaN
# Other comprehensive income (loss)                                        NaN
# Purchase of additional shares from noncontrolli...                     -11.0
# Cash dividends declared                                                  NaN
# Stock compensation plans, including tax benefits                      5011.0
# Stock compensation plans, including tax benefit...                       NaN
# Share repurchases                                                        NaN
# Share repurchases, shares                                                NaN
# Balance at Dec. 31, 2013                                             40006.0
# Balance, shares at Dec. 31, 2013                                         NaN
# Net earnings                                                             NaN
# Other comprehensive income (loss)                                        NaN
# Cash dividends declared                                                  NaN
# Stock compensation plans, including tax benefits                      3301.0
# Stock compensation plans, including tax benefit...                       NaN
# Share repurchases                                                        NaN
# Share repurchases, shares                                                NaN
# Balance at Dec. 31, 2014                                             43307.0
# Balance, shares at Dec. 31, 2014                                         NaN
# Net earnings                                                             NaN
# Other comprehensive income (loss)                                        NaN
# Cash dividends declared                                                  NaN
# Stock compensation plans, including tax benefits                      1422.0
# Stock compensation plans, including tax benefit...                       NaN
# Share repurchases                                                        NaN
# Share repurchases, shares                                                NaN
# Biomet merger consideration                                          37224.0
# Biomet merger consideration, shares                                      NaN
# Balance at Dec. 31, 2015                                             81953.0
# Balance, shares at Dec. 31, 2015                                         NaN
#
#                                                     Retained Earnings [Member]  \
# Consolidated Statements of Stockholders' Equity...
# Balance at Dec. 31, 2012                                               71432.0
# Balance, shares at Dec. 31, 2012                                           NaN
# Net earnings                                                            7804.0
# Other comprehensive income (loss)                                          NaN
# Purchase of additional shares from noncontrolli...                         NaN
# Cash dividends declared                                                -1354.0
# Stock compensation plans, including tax benefits                          12.0
# Stock compensation plans, including tax benefit...                         NaN
# Share repurchases                                                          NaN
# Share repurchases, shares                                                  NaN
# Balance at Dec. 31, 2013                                               77894.0
# Balance, shares at Dec. 31, 2013                                           NaN
# Net earnings                                                            7203.0
# Other comprehensive income (loss)                                          NaN
# Cash dividends declared                                                -1486.0
# Stock compensation plans, including tax benefits                          10.0
# Stock compensation plans, including tax benefit...                         NaN
# Share repurchases                                                          NaN
# Share repurchases, shares                                                  NaN
# Balance at Dec. 31, 2014                                               83621.0
# Balance, shares at Dec. 31, 2014                                           NaN
# Net earnings                                                            1470.0
# Other comprehensive income (loss)                                          NaN
# Cash dividends declared                                                -1644.0
# Stock compensation plans, including tax benefits                          30.0
# Stock compensation plans, including tax benefit...                         NaN
# Share repurchases                                                          NaN
# Share repurchases, shares                                                  NaN
# Biomet merger consideration                                                NaN
# Biomet merger consideration, shares                                        NaN
# Balance at Dec. 31, 2015                                               83477.0
# Balance, shares at Dec. 31, 2015                                           NaN
#
#                                                     Accumulated Other Comprehensive (Loss) Income [Member]  \
# Consolidated Statements of Stockholders' Equity...
# Balance at Dec. 31, 2012                                                                       2683.0
# Balance, shares at Dec. 31, 2012                                                                  NaN
# Net earnings                                                                                      NaN
# Other comprehensive income (loss)                                                               326.0
# Purchase of additional shares from noncontrolli...                                                NaN
# Cash dividends declared                                                                           NaN
# Stock compensation plans, including tax benefits                                                  NaN
# Stock compensation plans, including tax benefit...                                                NaN
# Share repurchases                                                                                 NaN
# Share repurchases, shares                                                                         NaN
# Balance at Dec. 31, 2013                                                                       3009.0
# Balance, shares at Dec. 31, 2013                                                                  NaN
# Net earnings                                                                                      NaN
# Other comprehensive income (loss)                                                             -2628.0
# Cash dividends declared                                                                           NaN
# Stock compensation plans, including tax benefits                                                  NaN
# Stock compensation plans, including tax benefit...                                                NaN
# Share repurchases                                                                                 NaN
# Share repurchases, shares                                                                         NaN
# Balance at Dec. 31, 2014                                                                        381.0
# Balance, shares at Dec. 31, 2014                                                                  NaN
# Net earnings                                                                                      NaN
# Other comprehensive income (loss)                                                             -3671.0
# Cash dividends declared                                                                           NaN
# Stock compensation plans, including tax benefits                                                  NaN
# Stock compensation plans, including tax benefit...                                                NaN
# Share repurchases                                                                                 NaN
# Share repurchases, shares                                                                         NaN
# Biomet merger consideration                                                                       NaN
# Biomet merger consideration, shares                                                               NaN
# Balance at Dec. 31, 2015                                                                      -3290.0
# Balance, shares at Dec. 31, 2015                                                                  NaN
#
#                                                     Treasury Shares [Member]  \
# Consolidated Statements of Stockholders' Equity...
# Balance at Dec. 31, 2012                                            -50721.0
# Balance, shares at Dec. 31, 2012                                      -855.0
# Net earnings                                                             NaN
# Other comprehensive income (loss)                                        NaN
# Purchase of additional shares from noncontrolli...                       NaN
# Cash dividends declared                                                  NaN
# Stock compensation plans, including tax benefits                        54.0
# Stock compensation plans, including tax benefit...                       1.0
# Share repurchases                                                    -7190.0
# Share repurchases, shares                                              -91.0
# Balance at Dec. 31, 2013                                            -57857.0
# Balance, shares at Dec. 31, 2013                                      -945.0
# Net earnings                                                             NaN
# Other comprehensive income (loss)                                        NaN
# Cash dividends declared                                                  NaN
# Stock compensation plans, including tax benefits                        25.0
# Stock compensation plans, including tax benefit...                       NaN
# Share repurchases                                                    -4005.0
# Share repurchases, shares                                              -42.0
# Balance at Dec. 31, 2014                                            -61837.0
# Balance, shares at Dec. 31, 2014                                      -987.0
# Net earnings                                                             NaN
# Other comprehensive income (loss)                                        NaN
# Cash dividends declared                                                  NaN
# Stock compensation plans, including tax benefits                        46.0
# Stock compensation plans, including tax benefit...                       1.0
# Share repurchases                                                    -1500.0
# Share repurchases, shares                                              -14.0
# Biomet merger consideration                                              NaN
# Biomet merger consideration, shares                                      NaN
# Balance at Dec. 31, 2015                                            -63291.0
# Balance, shares at Dec. 31, 2015                                     -1000.0
#
#                                                     Noncontrolling Interest [Member]
# Consolidated Statements of Stockholders' Equity...
# Balance at Dec. 31, 2012                                                        54.0
# Balance, shares at Dec. 31, 2012                                                 NaN
# Net earnings                                                                   -18.0
# Other comprehensive income (loss)                                               -2.0
# Purchase of additional shares from noncontrolli...                              -6.0
# Cash dividends declared                                                          NaN
# Stock compensation plans, including tax benefits                                 NaN
# Stock compensation plans, including tax benefit...                               NaN
# Share repurchases                                                                NaN
# Share repurchases, shares                                                        NaN
# Balance at Dec. 31, 2013                                                        28.0
# Balance, shares at Dec. 31, 2013                                                 NaN
# Net earnings                                                                   -11.0
# Other comprehensive income (loss)                                                1.0
# Cash dividends declared                                                          NaN
# Stock compensation plans, including tax benefits                                 NaN
# Stock compensation plans, including tax benefit...                               NaN
# Share repurchases                                                                NaN
# Share repurchases, shares                                                        NaN
# Balance at Dec. 31, 2014                                                        18.0
# Balance, shares at Dec. 31, 2014                                                 NaN
# Net earnings                                                                    -8.0
# Other comprehensive income (loss)                                                5.0
# Cash dividends declared                                                          NaN
# Stock compensation plans, including tax benefits                                 NaN
# Stock compensation plans, including tax benefit...                               NaN
# Share repurchases                                                                NaN
# Share repurchases, shares                                                        NaN
# Biomet merger consideration                                                      NaN
# Biomet merger consideration, shares                                              NaN
# Balance at Dec. 31, 2015                                                        15.0
# Balance, shares at Dec. 31, 2015                                                 NaN

# %%
df.shape
# Out:
# (33, 2)

# %%
df3 = add_tags_to_repeating_indices(df.copy(), '@')
df3
# Out:
#                                                     Mar. 31, 2020  \
# Consolidated Balance Sheets - USD ($) $ in Thou...
# CURRENT ASSETS:                                               NaN
# Cash and cash equivalents                                741901.0
# Accounts receivable, net of allowance                   1459471.0
# Prepaid expenses and other current assets                126816.0
# Total current assets                                    2328188.0
# Property and equipment, net of accumulated depr...       208077.0
# Operating lease right-of-use assets                      240122.0
# Intangible assets, net of accumulated amortization       300987.0
# Goodwill                                                1581160.0
# Other long-term assets                                   135432.0
# Total assets                                            4793966.0
# CURRENT LIABILITIES:                                          NaN
# Current portion of long-term debt                        177865.0
# Accounts payable and other accrued expenses              698011.0
# Accrued compensation and benefits                        348775.0
# Operating lease liabilities                               49021.0
# Other current liabilities                                 54006.0
# Total current liabilities                               1327678.0
# Long-term debt, net of current portion                  2007979.0
# Operating lease liabilities, net of current por...       270266.0
# Income tax reserves                                       56130.0
# Deferred tax liabilities                                  88086.0
# Other long-term liabilities                              187471.0
# Total liabilities                                       3937610.0
# Commitments and contingencies (Note 22)                       NaN
# STOCKHOLDERS’ EQUITY:                                         NaN
# Common stock, Class A — $0.01 par value — autho...         1613.0
# Treasury stock, at cost — 22,614,052 at March 3...      -898095.0
# Additional paid-in capital                               468027.0
# Retained earnings                                       1330812.0
# Accumulated other comprehensive loss                     -46001.0
# Total stockholders’ equity                               856356.0
# Total liabilities and stockholders’ equity              4793966.0
#
#                                                     Mar. 31, 2019
# Consolidated Balance Sheets - USD ($) $ in Thou...
# CURRENT ASSETS:                                               NaN
# Cash and cash equivalents                                283990.0
# Accounts receivable, net of allowance                   1330364.0
# Prepaid expenses and other current assets                 84986.0
# Total current assets                                    1699340.0
# Property and equipment, net of accumulated depr...       172453.0
# Operating lease right-of-use assets                           0.0
# Intangible assets, net of accumulated amortization       287051.0
# Goodwill                                                1581160.0
# Other long-term assets                                    91837.0
# Total assets                                            3831841.0
# CURRENT LIABILITIES:                                          NaN
# Current portion of long-term debt                         57924.0
# Accounts payable and other accrued expenses              664948.0
# Accrued compensation and benefits                        325553.0
# Operating lease liabilities                                   0.0
# Other current liabilities                                130814.0
# Total current liabilities                               1179239.0
# Long-term debt, net of current portion                  1701837.0
# Operating lease liabilities, net of current por...            0.0
# Income tax reserves                                       11509.0
# Deferred tax liabilities                                  33238.0
# Other long-term liabilities                              230652.0
# Total liabilities                                       3156475.0
# Commitments and contingencies (Note 22)                       NaN
# STOCKHOLDERS’ EQUITY:                                         NaN
# Common stock, Class A — $0.01 par value — autho...         1599.0
# Treasury stock, at cost — 22,614,052 at March 3...      -711450.0
# Additional paid-in capital                               401596.0
# Retained earnings                                        994811.0
# Accumulated other comprehensive loss                     -11190.0
# Total stockholders’ equity                               675366.0
# Total liabilities and stockholders’ equity              3831841.0

# %%
## Purpose: Some indices repeat in a financial statement (e.g. others). To make sure each index is unique without
##          losing information in the dataframe, we can add a tag to the end. The number of tags at the end represent
##          the number of times that index value has been seen before (no tag means first time, one tag means second, two
##          tags means third)
def add_tags_to_repeating_indices(df, tag):
    name = df.index.name
    idx = df.index.to_list()
    dup = {x for x in idx if idx.count(x) > 1}

    for ele in dup:
        end = ''
        for i in range(len(idx)):
            if ele == idx[i]:
                idx[i] = idx[i] + end
                end = end + tag
            
    df.index = idx
    df.index.name = name
    return df

# %%
# Purpose: Obtains the CIK number pertaining to a specified company.

def get_CIK_number(selected_company):
    master_index_file = '2020-QTR1.tsv'
    
    
    master_index = pd.read_csv(master_index_file, sep='\t', lineterminator='\n', names=None)
        
    master_index.columns.values[0] = 'Item'
    
    filing_index = master_index[(master_index['Item'].str.contains(selected_company, case=False))]
    
    return filing_index.iloc[0, 0].split('|')[0]
