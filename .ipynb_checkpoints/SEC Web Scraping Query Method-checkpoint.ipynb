# %%
# import our libraries
import requests
import pandas as pd
from bs4 import BeautifulSoup
import datetime
import edgar
import os
directory_path = os.getcwd()
print(directory_path)

#download sec edgar index info (refer to files in same direxctory)
edgar.download_index(directory_path, 2012, "your_name your@email.address", skip_all_present_except_last=False)
# Out:
# C:\Users\605089\Desktop\Personal Projects\Financial-Projects

# %%
#download sec edgar index info (refer to files in same direxctory)
edgar.download_index(directory_path, 2012, "your_name your@email.address", skip_all_present_except_last=False)

# %%
# Purpose: Obtains the CIK number pertaining to a specified company based on 
# Parameters: a company as a string and the year that company is in business
def get_CIK_number(selected_company, year):
    
    #attach the year to the first quarter (any quarter works)
    master_index_file = str(year) + '-QTR1.tsv'
    
    #
    master_index = pd.read_csv(master_index_file, sep='\t', lineterminator='\n', names=None)
        
    master_index.columns.values[0] = 'Item'
    
    filing_index = master_index[(master_index['Item'].str.contains(selected_company, case=False))]
    
    CIK_set = set()
    
    companyname_set = set()
    
    CIK_dict = {}
    
    
    for i in range(filing_index.shape[0]):
        
        #initial_len = len(CIK_set)
        CIK_num = filing_index.iloc[i,0].split('|')[0]
        company_name = filing_index.iloc[i, 0].split('|')[1]
        
        if company_name not in CIK_dict.keys():
            CIK_dict[company_name] = int(CIK_num)
        #CIK_set.add(filing_index.iloc[i,0].split('|')[0])
        #new_len = len(CIK_set)
        
        #if initial_len != new_len:
            #companyname_set.add(filing_index.iloc[i,0].split('|')[1])
        
    #convert sets into lists
    #CIK_set = list(CIK_set)
    #companyname_set = list(companyname_set)
    
    #print(len(CIK_set))
    #print(len(companyname_set))
        
    #for j in range(len(CIK_set)):
        #CIK_list.append([CIK_set[j], companyname_set[j]])
    
    
    return CIK_dict # .iloc[0, 0] #.split('|')[0]

# %%
today = datetime.datetime.now()
current_date = str(today.year) + '{:02d}'.format(today.month) + '{:02d}'.format(today.day)
current_date
# Out:
# '20220719'

# %%
def get_all_filings(CIK_num, filing, user_agent):
    #base URL for the SEC EDGAR browser
    endpoint = r"https://www.sec.gov/cgi-bin/browse-edgar"
    
    today = datetime.datetime.now()
    current_date = str(today.year) + '{:02d}'.format(today.month) + '{:02d}'.format(today.day)

    # define our parameters dictionary
    param_dict = {'action':'getcompany',
                  'CIK':CIK_num,
                  'type':filing,
                  'dateb': current_date, #'20190101',
                  'owner':'exclude',
                  'start':'',
                  'output':'',
                  'count':'100'}
    
    #perform a request via  query (params)
    response = requests.get(url = endpoint, params = param_dict, headers=user_agent)
    

    soup = BeautifulSoup(response.content, 'html.parser')


    # find the document table with our data
    doc_table = soup.find_all('table', class_='tableFile2')

    # define a base url that will be used for link building.
    base_url_sec = r"https://www.sec.gov"

    master_list = []

    # loop through each row in the table.
    for row in doc_table[0].find_all('tr'):
    
        # find all the columns
        cols = row.find_all('td')
    
        # if there are no columns move on to the next row.
        if len(cols) != 0:        
        
            # grab the text
            filing_type = cols[0].text.strip()                 
            filing_date = cols[3].text.strip()
            filing_numb = cols[4].text.strip()
        
            #pull the year
            filing_year = datetime.datetime.strptime(filing_date, "%Y-%m-%d").year
        
            # find the links
            filing_doc_href = cols[1].find('a', {'href':True, 'id':'documentsbutton'})       
            filing_int_href = cols[1].find('a', {'href':True, 'id':'interactiveDataBtn'})
            filing_num_href = cols[4].find('a')
        
        
            # grab the the first href
            if filing_doc_href != None:
                filing_doc_link = base_url_sec + filing_doc_href['href'] 
            else:
                filing_doc_link = 'no link'
        
            # grab the second href
            if filing_int_href != None:
                filing_int_link = base_url_sec + filing_int_href['href'] 
            else:
                filing_int_link = 'no link'
        
            # grab the third href
            if filing_num_href != None:
                filing_num_link = base_url_sec + filing_num_href['href'] 
            else:
                filing_num_link = 'no link'
        
            # create and store data in the dictionary
            file_dict = {}
            file_dict['file_type'] = filing_type
            file_dict['file_number'] = filing_numb
            file_dict['file_date'] = filing_date
            file_dict['file_year'] = filing_year
            file_dict['links'] = {}
            file_dict['links']['documents'] = filing_doc_link
            file_dict['links']['interactive_data'] = filing_int_link
            file_dict['links']['filing_number'] = filing_num_link
    
            '''
            # let the user know it's working
            print('-'*100)        
            print("Filing Type: " + filing_type)
            print("Filing Date: " + filing_date)
            print("Filing Year  " + str(filing_year))
            print("Filing Number: " + filing_numb)
            print("Document Link: " + filing_doc_link)
            print("Filing Number Link: " + filing_num_link)
            print("Interactive Data Link: " + filing_int_link) '''
        
            # append dictionary to master list
            if file_dict['file_type'].upper() == filing.upper():
                master_list.append(file_dict)
            
    return master_list

# %%
#returns htm file of the filing and specific year from master list
def get_filing_htm(master_list, year, user_agent):
    base_url = r"https://www.sec.gov"
    main_filing_row = ""
    
    for filing_info in master_list:
    
        if filing_info['file_year'] == year:
        
            response = requests.get(filing_info['links']['documents'], headers=user_agent)
            soup = BeautifulSoup(response.content, 'html.parser')
            
            doc_table = soup.find_all('table')
            
            for row in doc_table[0].find_all('tr'):
            
                for ele in row.find_all('td'):
                    #might want to revist this if statement
                    if ele.text.strip() == filing_info['file_type']:
                        main_filing_row = row
                        break
                 
    return base_url + main_filing_row.find('a', {'href':True})['href']

# %%
# Function: Get Filing Json
# Purpose: Obtains the complete submission text file and uses its url format to get a json description of the filing

def get_filing_json(filing_info, CIK_num, user_agent):
    #perform a request for the document using hte link from the master list
    response = requests.get(filing_info['links']['documents'], headers=user_agent)

    #create a beautiful soup object to parse the html
    soup = BeautifulSoup(response.content, 'html.parser')


    # filing is split into a table, so we want to get that table
    doc_table = soup.find_all('table')

    # the last item on the table is the complete submission text file (ignoring xbrl stuff)
    text_row = doc_table[0].find_all('tr')[-1]

    base_url = r"https://www.sec.gov"
    json_url = ""

    #grab the portion of the row that gives the end of the .txt url
    end = text_row.find('a', {'href':True}).text.strip()

    '''
    #for grabbing the newer filing format (hard to convert to Filing.xml)
    print(text_row.find('a', {'href':True})['href'])
    '''

    
    #txt_url = base_url + "/Archives/edgar/data/" + str(CIK_num) + "/" + end
    json_url = base_url + "/Archives/edgar/data/" + str(CIK_num) + "/" + end.replace('-', '').replace('.txt', '/index.json')
    #print(txt_url)
    #print(json_url)
    return json_url

# %%
def get_xml_Filing_Summary(json_url, user_agent):
    base_url = r"https://www.sec.gov"
    
    content = requests.get(json_url, headers=user_agent).json()
    #for each file in the document landing page
    for file in content['directory']['item']:
    
        #if the filing's name is FilingSummary.xml
        if file['name'] == 'FilingSummary.xml':
        
            #create the url for the xml file
            xml_summary = base_url + content['directory']['name'] + "/" + file['name']
    
            '''print('-' * 100)
            print('File Name: ' + file['name'])
            print('File Path: ' + xml_summary) '''
            
    return xml_summary

# %%
def parse_xml_summary_of_file(xml_summary, user_agent):
    #define a new base url that represents the filing folder. This will come in handy when we need to download the reports
    base_url = xml_summary.replace('FilingSummary.xml', '')

    #request and parse the content (use .content because this is an xml file not json)
    content = requests.get(xml_summary, headers=user_agent).content

    #create a soup object to parse the content using BeautifulSoup
    soup = BeautifulSoup(content, 'lxml')

    #find the 'myreports' tag because this contains all the individual reports submitted
    reports = soup.find('myreports')

    #want a list ot store all theindividual components of the report, so create the master list
    master_reports = []

    # loop through each report in the 'myreports' tag but avoid the last one as this will cause an error
    # (last one has differnent formatting).
    for index, report in enumerate(reports.find_all('report')[:-1]):
    
        #create a dictionary to store all the differnet parts we need
        report_dict = {}
        report_dict['name_short'] = report.shortname.text
        report_dict['name_long'] = report.longname.text
        report_dict['position'] = index+1
        #report_dict['category'] = report.menucategory.text
        report_dict['url'] = base_url + report.htmlfilename.text
    
        #append the dictionary to the master list.
        master_reports.append(report_dict)
    
    '''
        #print the info to the user.
        print('-'*100)
        print(base_url + report.htmlfilename.text)
        print(report.longname.text)
        print(report.shortname.text)
        #print(report.menucategory."text)
        print(index+1) '''
        
    return master_reports

# %%
##################### REVIST LATER #########################################################

def grab_financial_statements(master_reports):
    #create the list to hold the statement urls
    statements_url = []

    for report_dict in master_reports:
    
    # define the statements we want to look for.   
    #######################################################################################
    # MAY WANT TO REVISIT THIS
    #######################################################################################
        item1 = r"CONSOLIDATED"
        item2 = r"PARENTHETICAL"
        item3 = r"EQUITY"
    
        if item1 in report_dict['name_short'].upper() and item2 not in report_dict['name_short'].upper() and item3 not in report_dict['name_short'].upper() and report_dict['position'] < 12:
            #print(report_dict['name_short'].upper())
            statements_url.append(report_dict['url'])
        
        
    # NOW WE HAVE THE URLS OF THE STATEMENTS WE WANT TO SCRAPE
        
        
    #assuming we want all the statements in a single data set
    statements_data = []

    #loop through each statement url
    for statement in statements_url:
    
        #define a dictionary that will store the different parts of the statement
        statement_data = {}
        statement_data['headers'] = []
        statement_data['sections'] = []
        statement_data['data'] = []
    
        #request the statement file content
        content = requests.get(statement, headers=user_agent).content
        report_soup = BeautifulSoup(content, 'html')
    
        #find all the rows, figure out what type of row it is, parse the elements, and store in teh statement file list.
        #tr = table row
        for index, row in enumerate(report_soup.table.find_all('tr')):
        
            #first let's get all the elements (td = standard data cell)
            # cols represents elements in the row
            cols = row.find_all('td')
            
           # if it's a regular row and not a section or a table header (th = header, strong = important)
            if (len(row.find_all('th')) == 0 and len(row.find_all('table')) == 0): # and len(row.find_all('strong')) == 0:
                reg_row = []
                for ele in cols:
                
                    if len(row.find_all('strong')) != 0:
                        reg_row.append(ele.text.strip().upper())
                    else:
                        reg_row.append(ele.text.strip())
                        
                #reg_row = [ele.text.strip() for ele in cols]
                statement_data['data'].append(reg_row)
                        
                #check if it is a section label and store that it in sec_row
                if len(row.find_all('strong')) != 0:
                    sec_row = cols[0].text.strip().upper()
                    statement_data['sections'].append(sec_row)
                    
            
            #finally if it's not any of those it must be a header
            elif (len(row.find_all('th')) != 0):
                hed_row = []
                for ele in row.find_all('th'):
                    if (len(ele.find_all('sup'))) == 0:
                        hed_row.append(ele.text.strip())
                statement_data['headers'].append(hed_row)
            
            else:
                print("We encountered an error")
    
        statements_data.append(statement_data)
    
    return statements_data

# %% [markdown]
# Below are functions that deal with converting data into a pandas dataframe

# %%
## Purpose: Checks if a character can be converted into a float

def char_is_float(char):
    try:
        float(char)
        return True
    except:
        return False
    

## Purpose: Changes a (assumed) string into a float, getting rid of any non-number values in the string in the process.
## Assumptions: We are only interested in strings, so anything else will get a NaN value. In other words, we expect a string
##              but if otherwise then we ignore/erase the passed value as it was not expected and could cause further problems
##              if kept as is.
## Example: Converts '900f' to 900.0

def change_to_float(string):
    
    #if already a float, no need to continue
    if type(string) == float:
        return float(string)
    
    #check if the value is a string (since we want to strip the string and that doesn't work for other types)
    elif type(string) == str:
        
        #get rid of spaces
        string = string.strip()
        
        #just checking ... again
        if string == 'None':
            return 'NaN'
    
        #string to append float characters to
        string_to_convert = ""
        
        #iterate through each element of the string
        for i, char in enumerate(string):
            
            #check the first element of the string, as that can be a minus sign, otherwise only append chars that are numbers
            if i == 0:
                if char_is_float(char) or char == '-':
                    string_to_convert = string_to_convert + char
                
                #if the first character is not a number, why bother
                else:
                    return None
            else:
                if char_is_float(char):
                    string_to_convert = string_to_convert + char
            
        return float(string_to_convert)
    
    #if not a float or a string, I'm assuming its a Nonetype. Return NaN because that is float terminology
    else:
        return 'NaN'

# %%
## Purpose: Gets rid of any columns in a pandas datframe that do not contain any information (i.e. irrelevant)
def get_rid_of_null_columns(df):

    #store the column index of columns we want to drop in a list
    column_index_to_drop = []

    #for each column in the dataframe
    for i in range(df.shape[1]):
        
        #if all values within that column are NaN, assign that column to be dropped
        if df[df.columns[i]].isnull().all():
            column_index_to_drop.append(i)
        
    df.drop(df.columns[column_index_to_drop], axis = 1, inplace=True)

    return df

# %%
## Parameters: Takes in a dictionary called statements data that holds 'headers' and 'data' from the html that describes
##             the financial statements scraped from the SEC website. The 'headers' describe the columns, while the 'data'
##             are the elements below the 'headers' in the table. Statements data contains multiple documents, but this funciton
##             only works with one statement, so a number describing what statement from statements data is given as a 
##             parameter.
##
## Purpose:    Converts a dictionary describing financial data into a pandas dataframe. There are many steps to cleaning
##             the data so that it can be machine readable (e.g. cleaning the data, dealing with edge cases such as multiple
##             levels of headers)

def convert_statements_data_to_pandas(statements_data, statements_num):
    
    #take the raw table data (without the headers)
    balance_data = statements_data[statements_num]['data']
    
    df = pd.DataFrame(balance_data)
    
    #Define the Index column as the first column
    df.index = df[0]
    
    #since the index makes up the first column, we can get rid of the first column
    df = df.drop(0, axis = 1)
    
    # Get rid of the '$', '(', ')', and convert the '' to NaNs.
    df = df.replace('[\$,)]','', regex=True )\
                     .replace( '[(]','-', regex=True)\
                     .replace( '', 'NaN', regex=True)
    
    #convert each element in the table portion into a float (excluding indexes or headers) 
    for i in range(df.shape[1]):
        
        #apply change_to_float which cleans the element to be prepared to turn into a float
        df[df.columns[i]] = df[df.columns[i]].apply(change_to_float) 
    
    #change_to_float should already accomplish this, but this is to double check if any values were not converted into floats
    df = df.astype(float)
    
    df = get_rid_of_null_columns(df)
    
    
    # Now we need the headers for the document (as well as the document's name) 
    # This is also stored in the statements_data under headers
    
    # Because the headers may either have one or two levels in the financial statement (sometimes over the year, there is 
    # a statement like "12 months ended in"), we need to specify the headers that match up best with the columns
    
    # This may not make a whole bunch of sense but that's because getting the headers is specific to two different types
    # of headers for the financial documents.
    
    #if the headers only have one level (one row that holds all the headers)
    if len(statements_data[statements_num]['headers']) == 1:
        
        #headers get all the values in 'headers' except the first one which is used as the header for the index
        header = statements_data[statements_num]['headers'][0][1:]
        document = statements_data[statements_num]['headers'][0][0]
    
    #if the headers have two levels (there are two rows that hold all the headers)
    elif len(statements_data[statements_num]['headers']) == 2:
        
        #headers get the bottom row
        header = statements_data[statements_num]['headers'][-1]
        
        #document name gets first element of the top row
        document = statements_data[statements_num]['headers'][0][0] 
        
    #there are probably more edge cases, so we'll just keep everything the same to keep things moving
    else:
        header = df.columns
        document = 'Category'
    
    
    try:
        df.columns = header
        df.index.name = document
    except:
        print('title error')
        df = pd.DataFrame()

    
    return df

# %%
## Purpose: Some indices repeat in a financial statement (e.g. others). To make sure each index is unique without
##          losing information in the dataframe, we can add a tag to the end. The number of tags at the end represent
##          the number of times that index value has been seen before (no tag means first time, one tag means second, two
##          tags means third)
def add_tags_to_repeating_indices(df, tag):
    name = df.index.name
    idx = df.index.to_list()
    dup = {x for x in idx if idx.count(x) > 1}

    for ele in dup:
        end = ''
        for i in range(len(idx)):
            if ele == idx[i]:
                idx[i] = idx[i] + end
                end = end + tag
            
    df.index = idx
    df.index.name = name
    return df

# %%
def add_tags_for_sections(sections, df):
    if len(sections) < 2:
        idx = df.index.to_list()
        name = df.index.name
        idx_tags = []
        for ele in idx:
            idx_tags.append(ele + '-' + str(1))
        df.index = idx_tags
        df.index.name = name
        return df

    idx = df.index.to_list()
    name = df.index.name
    
    idx_tags = []
    
    count = 0
    
    for ele in idx:
        if ele in sections:
            count = count + 1
        idx_tags.append(ele + '-' + str(count))
        
            
    df.index = idx_tags
    df.index.name = name
    
    return df

# %%
### Function: Filings within a set year range
### Purpose: Takes the master list of all filings, and culls it a set number of years starting at the latest desired year
### Returns: A list of dictionaries containing information on filings based on year

def filings_within_year_range(master_list, filing, latest_year, num_years):
    
    culled_master_list = []
    
    #run loop until we run out of asked-for years
    while num_years > 0:
        
        #for each dictionary in the master list, check if the filing matches the asked-for year and is the exact filing
        #and then appends that dictionary to the new master list
        for file in master_list:
            if file['file_year'] == latest_year:
                if file['file_type'] == filing:
                    culled_master_list.append(file)
                    
        latest_year = latest_year - 1
        
        num_years = num_years - 1
        
    return culled_master_list

# %%
def get_statements_data_from_filing_to_dataframes(filing, user_agent):
    json_url = get_filing_json(filing, user_agent)
    xml_summary = get_xml_Filing_Summary(json_url, user_agent)

    master_reports = parse_xml_summary_of_file(xml_summary, user_agent)
    
    statements_data = grab_financial_statements(master_reports)
    
    dataframes = []
    for i in range(len(statements_data)):
        df = convert_statements_data_to_pandas(statements_data, i)
        df = add_tags_for_sections(statements_data[i]['sections'], df)
        df = add_tags_to_repeating_indices(df, '@')
        dataframes.append(df)
        
    return dataframes

# %%
### Function: Scrape Company Financial Statements
### Input: Company's CIK number, the type of filing you are searching for, the year you want to start from and
###        the number of years you want to go back from that starting year, and the user agent to access the SEC website
### Purpose: Performs a query search on the SEC website for a company's filings, accesses that filing, and then pulls out 
###          the relevant financial statements (balance sheet, cash flow, income, etc.) into a pandas dataframe
### Returns: A 2-dimensional array of dataframes with the rows being the years and the columns being which financial statement

def scrape_company_financial_statements(CIK_num, filing_type, start_year, num_years, user_agent):
    
    #query for a master list of all filings given a CIK_number and a filing type
    master_list = get_all_filings(CIK_num, filing_type, user_agent)

    #focus the master list on the years you want
    culled_master_list = filings_within_year_range(master_list, filing_type, start_year, num_years)
    

    #array to store dataframes
    dfs = []

    #for each filing in the master list
    for filing in culled_master_list:
    
        #get the statements data from the filing and store it in pandas dataframes
        dataframes = get_statements_data_from_filing_to_dataframes(filing, user_agent)
        dfs.append(dataframes)
        
    #financial statements tend to have multiple years, but we just want the current year so we drop the other columns
    for i in range(len(dfs)):
        for j in range(len(dfs[i])):
            
            #columns = years, drop all the columns that isn't the first one
            dfs[i][j].drop(columns=dfs[i][j].columns[1:], axis=1, inplace=True)
        
    return dfs

# %%
def combine_yearly_financial_statements(dfs):
    num_docs = len(dfs[0])
    
    multi_year_statements = []
    for i in range(num_docs):
        year_statements = []
        for ele in dfs:
            if len(ele) == num_docs:
                year_statements.append(ele[i])
            else:
                print(len(ele))
        multi_year_statements.append(year_statements)

    combined_financial_statements = []

    for i in range(len(multi_year_statements)):
        combined_fs = pd.concat(multi_year_statements[i], axis=1)
       # combined_fs.index.name = multi_year_statements[i][0].index.name
        combined_financial_statements.append(combined_fs)
        
    return combined_financial_statements

# %%
def reindex_combined_financial_statements(combined_financial_statements):
    
    for i in range(len(combined_financial_statements)):
        current_index = list(combined_financial_statements[i].index)

        current_tag = 1
        num_elements_with_tag = 0

        new_index = []
        while True:
            for name in current_index:
                if name[-1] == str(current_tag):
                    new_index.append(name)
                    num_elements_with_tag = num_elements_with_tag + 1
                elif name[-1] == '@':
                    if name[-2] == str(current_tag):
                        new_index.append(name)
                        num_elements_with_tag = num_elements_with_tag + 1
                
            if num_elements_with_tag < 1:
                break
            current_tag = current_tag + 1
            num_elements_with_tag = 0

        
        combined_financial_statements[i] = combined_financial_statements[i].reindex(new_index)
    
    return combined_financial_statements

# %%
def scrape_company_financial_statements_combined(CIK_num, filing_type, start_year, num_years, user_agent):
    statements_dataframes = scrape_company_financial_statements(CIK_num, filing_type, start_year, num_years, user_agent)
    combined_financial_statements = combine_yearly_financial_statements(statements_dataframes)
    combined_financial_statements = reindex_combined_financial_statements(combined_financial_statements)
    
    return combined_financial_statements

# %%
def get_summaries(CIK_num, filing_type, start_year, num_years, user_agent):
    #query for a master list of all filings given a CIK_number and a filing type
    master_list = get_all_filings(CIK_num, filing_type, user_agent)

    #focus the master list on the years you want
    culled_master_list = filings_within_year_range(master_list, filing_type, start_year, num_years)


    #for each filing in the master list
    for filing in culled_master_list:
        json_url = get_filing_json(filing, CIK_num, user_agent)
        xml_summary = get_xml_Filing_Summary(json_url, user_agent)

        print_xml_summaries(xml_summary, user_agent)
        #get the statements data from the filing and store it in pandas dataframes

# %%
def print_xml_summaries(xml_summary, user_agent):
        #define a new base url that represents the filing folder. This will come in handy when we need to download the reports
    base_url = xml_summary.replace('FilingSummary.xml', '')

    #request and parse the content (use .content because this is an xml file not json)
    content = requests.get(xml_summary, headers=user_agent).content

    #create a soup object to parse the content using BeautifulSoup
    soup = BeautifulSoup(content, 'lxml')

    #find the 'myreports' tag because this contains all the individual reports submitted
    reports = soup.find('myreports')

    #want a list ot store all theindividual components of the report, so create the master list
    master_reports = []

    # loop through each report in the 'myreports' tag but avoid the last one as this will cause an error
    # (last one has differnent formatting).
    for index, report in enumerate(reports.find_all('report')[:-1]):

        #create a dictionary to store all the differnet parts we need
        report_dict = {}
        report_dict['name_short'] = report.shortname.text
        report_dict['name_long'] = report.longname.text
        report_dict['position'] = index+1
        #report_dict['category'] = report.menucategory.text
        report_dict['url'] = base_url + report.htmlfilename.text

        #append the dictionary to the master list.
        master_reports.append(report_dict)

    
        #print the info to the user.
        print('-'*100)
        print(base_url + report.htmlfilename.text)
        print(report.longname.text)
        print(report.shortname.text)
        #print(report.menucategory."text)
        print(index+1)

# %%
print("-" * 2000)
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
get_summaries(CIK_num, filing_type, start_year, num_years, user_agent)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-6f02c3242890> in <module>
# ----> 1 get_summaries(CIK_num, filing_type, start_year, num_years, user_agent)
#
# <ipython-input-40-3905469f16b9> in get_summaries(CIK_num, filing_type, start_year, num_years, user_agent)
#       9     #for each filing in the master list
#      10     for filing in culled_master_list:
# ---> 11         json_url = get_filing_json(filing, CIK_num, user_agent)
#      12         xml_summary = get_xml_Filing_Summary(json_url, user_agent)
#      13
#
# TypeError: get_filing_json() takes 2 positional arguments but 3 were given

# %% [markdown]
# ## Obtain CIK number for Company

# %% [markdown]
# Type in a company's name in the "company" variable to query for that company's particular CIK number. The CIK number is used to search for that companies financials on the SEC website.

# %%
#Find CIK number on a certain company. Enter a company name, and obtain a list of companies that contain that name with 
#the associated CIK number

company = "Disney"
year = 2022

CIK_dict = get_CIK_number(company, year)
for key, value in CIK_dict.items():
    print(key + '||', value)
# Out:
# Walt Disney Co|| 1744489

# %% [markdown]
# # Run Scrape

# %%
#base URL for the SEC EDGAR browser
endpoint = r"https://www.sec.gov/cgi-bin/browse-edgar"

#choose from list above or obtain from other source
CIK_num = 1744489

filing_type = '10-K'

start_year = 2022

num_years = 10

user_agent = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36 Edg/97.0.1072.62"}

# %%
#returns a master list of all filings of the specified filing_type and company
master_list = get_all_filings(CIK_num, filing_type, user_agent)

#returns htm file of the filing and specific year from master list
print(get_filing_htm(master_list, 2020, user_agent))
# Out:
# <tr>
# <td scope="row">1</td>
# <td scope="row">FORM 10-K</td>
# <td scope="row"><a href="/ix?doc=/Archives/edgar/data/1744489/000174448920000197/dis-20201003.htm">dis-20201003.htm</a>   <span style="color: green">iXBRL</span></td>
# <td scope="row">10-K</td>
# <td scope="row">6111384</td>
# </tr>
# None

# %%
#culls the master list by a specified amount at a start date
culled_master_list = filings_within_year_range(master_list, filing_type, 2021, 10)
culled_master_list[0]
# Out:
# {'file_type': '10-K',
#  'file_number': '001-3475621598537',
#  'file_date': '2021-02-08',
#  'file_year': 2021,
#  'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/0001564590-21-004599-index.htm',
#   'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001564590-21-004599&xbrl_type=v',
#   'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}}

# %%
combined_financial_statements = scrape_company_financial_statements_combined(CIK_num, filing_type, start_year, num_years, user_agent)
combined_financial_statements[0]
# Out:
# We encountered an error
# We encountered an error
# We encountered an error
#                                                     Dec. 31, 2021  \
# CURRENT ASSETS-1                                              NaN
# Cash and cash equivalents-1                               17576.0
# Short-term marketable securities-1                          131.0
# Accounts receivable, net-1                                 1913.0
# Inventory-1                                                5757.0
# ...                                                           ...
# Current portion of solar bonds issued to relate...            NaN
# Solar bonds issued to related parties, net of c...            NaN
# CURRENT LIABILITIES-6                                         NaN
# Current portion of solar bonds and promissory n...            NaN
# Solar bonds issued to related parties, net of c...            NaN
#
#                                                     Dec. 31, 2020  \
# CURRENT ASSETS-1                                              NaN
# Cash and cash equivalents-1                               19384.0
# Short-term marketable securities-1                            NaN
# Accounts receivable, net-1                                 1886.0
# Inventory-1                                                4101.0
# ...                                                           ...
# Current portion of solar bonds issued to relate...            NaN
# Solar bonds issued to related parties, net of c...            NaN
# CURRENT LIABILITIES-6                                         NaN
# Current portion of solar bonds and promissory n...            NaN
# Solar bonds issued to related parties, net of c...            NaN
#
#                                                     Dec. 31, 2019  \
# CURRENT ASSETS-1                                              NaN
# Cash and cash equivalents-1                                6268.0
# Short-term marketable securities-1                            NaN
# Accounts receivable, net-1                                 1324.0
# Inventory-1                                                3552.0
# ...                                                           ...
# Current portion of solar bonds issued to relate...            NaN
# Solar bonds issued to related parties, net of c...            NaN
# CURRENT LIABILITIES-6                                         NaN
# Current portion of solar bonds and promissory n...            NaN
# Solar bonds issued to related parties, net of c...            NaN
#
#                                                     Dec. 31, 2018  \
# CURRENT ASSETS-1                                              NaN
# Cash and cash equivalents-1                             3685618.0
# Short-term marketable securities-1                            NaN
# Accounts receivable, net-1                               949022.0
# Inventory-1                                             3113446.0
# ...                                                           ...
# Current portion of solar bonds issued to relate...            NaN
# Solar bonds issued to related parties, net of c...            NaN
# CURRENT LIABILITIES-6                                         NaN
# Current portion of solar bonds and promissory n...            NaN
# Solar bonds issued to related parties, net of c...            NaN
#
#                                                     Dec. 31, 2017  \
# CURRENT ASSETS-1                                              NaN
# Cash and cash equivalents-1                             3367914.0
# Short-term marketable securities-1                            NaN
# Accounts receivable, net-1                               515381.0
# Inventory-1                                             2263537.0
# ...                                                           ...
# Current portion of solar bonds issued to relate...            NaN
# Solar bonds issued to related parties, net of c...            NaN
# CURRENT LIABILITIES-6                                         NaN
# Current portion of solar bonds and promissory n...       100000.0
# Solar bonds issued to related parties, net of c...          100.0
#
#                                                     Dec. 31, 2016  \
# CURRENT ASSETS-1                                              NaN
# Cash and cash equivalents-1                             3393216.0
# Short-term marketable securities-1                            NaN
# Accounts receivable, net-1                               499142.0
# Inventory-1                                             2067454.0
# ...                                                           ...
# Current portion of solar bonds issued to relate...       165936.0
# Solar bonds issued to related parties, net of c...        99164.0
# CURRENT LIABILITIES-6                                         NaN
# Current portion of solar bonds and promissory n...            NaN
# Solar bonds issued to related parties, net of c...            NaN
#
#                                                     Dec. 31, 2015  \
# CURRENT ASSETS-1                                              NaN
# Cash and cash equivalents-1                             1196908.0
# Short-term marketable securities-1                            NaN
# Accounts receivable, net-1                                    NaN
# Inventory-1                                             1277838.0
# ...                                                           ...
# Current portion of solar bonds issued to relate...            NaN
# Solar bonds issued to related parties, net of c...            NaN
# CURRENT LIABILITIES-6                                         NaN
# Current portion of solar bonds and promissory n...            NaN
# Solar bonds issued to related parties, net of c...            NaN
#
#                                                     Dec. 31, 2014  \
# CURRENT ASSETS-1                                              NaN
# Cash and cash equivalents-1                             1905713.0
# Short-term marketable securities-1                            NaN
# Accounts receivable, net-1                                    NaN
# Inventory-1                                              953675.0
# ...                                                           ...
# Current portion of solar bonds issued to relate...            NaN
# Solar bonds issued to related parties, net of c...            NaN
# CURRENT LIABILITIES-6                                         NaN
# Current portion of solar bonds and promissory n...            NaN
# Solar bonds issued to related parties, net of c...            NaN
#
#                                                     Dec. 31, 2013  \
# CURRENT ASSETS-1                                              NaN
# Cash and cash equivalents-1                              845889.0
# Short-term marketable securities-1                            NaN
# Accounts receivable, net-1                                    NaN
# Inventory-1                                              340355.0
# ...                                                           ...
# Current portion of solar bonds issued to relate...            NaN
# Solar bonds issued to related parties, net of c...            NaN
# CURRENT LIABILITIES-6                                         NaN
# Current portion of solar bonds and promissory n...            NaN
# Solar bonds issued to related parties, net of c...            NaN
#
#                                                     Dec. 31, 2012
# CURRENT ASSETS-1                                              NaN
# Cash and cash equivalents-1                              201890.0
# Short-term marketable securities-1                            NaN
# Accounts receivable, net-1                                    NaN
# Inventory-1                                              268504.0
# ...                                                           ...
# Current portion of solar bonds issued to relate...            NaN
# Solar bonds issued to related parties, net of c...            NaN
# CURRENT LIABILITIES-6                                         NaN
# Current portion of solar bonds and promissory n...            NaN
# Solar bonds issued to related parties, net of c...            NaN
#
# [116 rows x 10 columns]

# %%
combined_financial_statements[1]
# Out:
#                       Dec. 31, 2021  Dec. 31, 2020  Dec. 31, 2019  \
# REVENUES-1                      NaN            NaN            NaN
# Total revenues-1            53823.0        31536.0        24578.0
# REVENUES-11                     NaN            NaN            NaN
# Revenues-11                  2789.0            NaN            NaN
# Automotive leasing-1            NaN         1052.0          869.0
# ...                             ...            ...            ...
# Revenues-9                  47232.0            NaN            NaN
# COST OF REVENUES-9              NaN            NaN            NaN
# Cost of revenues-9              NaN         1976.0         1341.0
# -9                              NaN            NaN            NaN
# [1]-9                           NaN            NaN            NaN
#
#                       Dec. 31, 2018  Dec. 31, 2017  Dec. 31, 2016  \
# REVENUES-1                      NaN            NaN            NaN
# Total revenues-1         21461268.0     11758751.0      7000132.0
# REVENUES-11                     NaN            NaN            NaN
# Revenues-11                     NaN            NaN            NaN
# Automotive leasing-1       883461.0      1106548.0       761759.0
# ...                             ...            ...            ...
# Revenues-9                      NaN            NaN            NaN
# COST OF REVENUES-9              NaN            NaN            NaN
# Cost of revenues-9        1364896.0            NaN            NaN
# -9                              NaN            NaN            NaN
# [1]-9                           NaN            NaN            NaN
#
#                       Dec. 31, 2015  Dec. 31, 2014  Dec. 31, 2013  \
# REVENUES-1                      NaN            NaN            NaN
# Total revenues-1          4046025.0      3198356.0      2013496.0
# REVENUES-11                     NaN            NaN            NaN
# Revenues-11                     NaN            NaN            NaN
# Automotive leasing-1            NaN            NaN            NaN
# ...                             ...            ...            ...
# Revenues-9                      NaN            NaN            NaN
# COST OF REVENUES-9              NaN            NaN            NaN
# Cost of revenues-9              NaN            NaN            NaN
# -9                              NaN            NaN            NaN
# [1]-9                           NaN            NaN            NaN
#
#                       Dec. 31, 2012
# REVENUES-1                      NaN
# Total revenues-1           413256.0
# REVENUES-11                     NaN
# Revenues-11                     NaN
# Automotive leasing-1            NaN
# ...                             ...
# Revenues-9                      NaN
# COST OF REVENUES-9              NaN
# Cost of revenues-9              NaN
# -9                              NaN
# [1]-9                           NaN
#
# [86 rows x 10 columns]

# %%
print("-"*10000)
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
statements_dataframes = scrape_company_financial_statements(CIK_num, filing_type, start_year, num_years, user_agent)
print(len(statements_dataframes))
print(len(statements_dataframes[0]))
statements_dataframes[0][0].head(5)
# Out:
# We encountered an error
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-aa563f7cdcaf> in <module>
# ----> 1 statements_dataframes = scrape_company_financial_statements(CIK_num, filing_type, start_year, num_years, user_agent)
#       2 print(len(statements_dataframes))
#       3 print(len(statements_dataframes[0]))
#       4 statements_dataframes[0][0].head(5)
#
# <ipython-input-62-64f3b9e4f1d9> in scrape_company_financial_statements(CIK_num, filing_type, start_year, num_years, user_agent)
#      22
#      23         #get the statements data from the filing and store it in pandas dataframes
# ---> 24         dataframes = get_statements_data_from_filing_to_dataframes(filing, user_agent)
#      25         dfs.append(dataframes)
#      26
#
# <ipython-input-61-2fac265234ac> in get_statements_data_from_filing_to_dataframes(filing, user_agent)
#       9     dataframes = []
#      10     for i in range(len(statements_data)):
# ---> 11         df = convert_statements_data_to_pandas(statements_data, i)
#      12         df = add_tags_for_sections(statements_data[i]['sections'], df)
#      13         df = add_tags_to_repeating_indices(df, '@')
#
# <ipython-input-31-19478a902db5> in convert_statements_data_to_pandas(statements_data, statements_num)
#      70
#      71
# ---> 72     df.columns = header
#      73     df.index.name = document
#      74
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     668     def _set_axis(self, axis: int, labels: Index) -> None:
#     669         labels = ensure_index(labels)
# --> 670         self._mgr.set_axis(axis, labels)
#     671         self._clear_item_cache()
#     672
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     218
#     219         if new_len != old_len:
# --> 220             raise ValueError(
#     221                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     222                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 8 elements, new values have 1 elements

# %%
combined_financial_statements = combine_yearly_financial_statements(statements_dataframes)
#combined_financial_statements[0]

# %%
combined_financial_statements = combine_yearly_financial_statements(statements_dataframes)
combined_financial_statements = reindex_combined_financial_statements(combined_financial_statements)
print(len(combined_financial_statements[0]))
combined_financial_statements[0]
# Out:
# 37
#                                                     Dec. 25, 2021  \
# INCOME STATEMENT [ABSTRACT]-1                                 NaN
# Net revenue-1                                             79024.0
# Cost of sales-1                                           35209.0
# Gross margin-1                                            43815.0
# Research and development-1                                15190.0
# Marketing, general and administrative-1                    6543.0
# Restructuring and other charges-1                          2626.0
# Operating expenses-1                                      24359.0
# Operating income-1                                        19456.0
# Gains (losses) on equity investments, net-1                2729.0
# Interest and other, net-1                                  -482.0
# Income before taxes-1                                     21703.0
# Provision for taxes-1                                      1835.0
# Net income-1                                              19868.0
# Earnings per share—basic-1                                  489.0
# Earnings per share—diluted-1                                486.0
# Amortization of acquisition-related intangibles-1             NaN
# Earnings per share—Basic-1                                    NaN
# Earnings per share—Diluted-1                                  NaN
# Earnings per share - Basic-1                                  NaN
# Earnings per share - Diluted-1                                NaN
# Depreciation, Depletion and Amortization, Nonpr...            NaN
# Nonoperating Income (Expense)-1                               NaN
# Basic earnings per share of common stock-1                    NaN
# Diluted earnings per share of common stock-1                  NaN
# Restructuring and asset impairment charges-1                  NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-1                                              NaN
# Diluted (shares)-1                                            NaN
# Operating Expense [Member]-1                                  NaN
# Amortization of acquisition-related intangibles-1@            NaN
# Basic earnings per common share (in dollars per...            NaN
# Diluted earnings per common share (in dollars p...            NaN
# WEIGHTED AVERAGE COMMON SHARES OUTSTANDING:-1                 NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-2                                           4059.0
# Diluted (shares)-2                                         4090.0
#
#                                                     Dec. 26, 2020  \
# INCOME STATEMENT [ABSTRACT]-1                                 NaN
# Net revenue-1                                             77867.0
# Cost of sales-1                                           34255.0
# Gross margin-1                                            43612.0
# Research and development-1                                13556.0
# Marketing, general and administrative-1                    6180.0
# Restructuring and other charges-1                           198.0
# Operating expenses-1                                      19934.0
# Operating income-1                                        23678.0
# Gains (losses) on equity investments, net-1                1904.0
# Interest and other, net-1                                  -504.0
# Income before taxes-1                                     25078.0
# Provision for taxes-1                                      4179.0
# Net income-1                                              20899.0
# Earnings per share—basic-1                                  498.0
# Earnings per share—diluted-1                                494.0
# Amortization of acquisition-related intangibles-1             NaN
# Earnings per share—Basic-1                                    NaN
# Earnings per share—Diluted-1                                  NaN
# Earnings per share - Basic-1                                  NaN
# Earnings per share - Diluted-1                                NaN
# Depreciation, Depletion and Amortization, Nonpr...            NaN
# Nonoperating Income (Expense)-1                               NaN
# Basic earnings per share of common stock-1                    NaN
# Diluted earnings per share of common stock-1                  NaN
# Restructuring and asset impairment charges-1                  NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-1                                              NaN
# Diluted (shares)-1                                            NaN
# Operating Expense [Member]-1                                  NaN
# Amortization of acquisition-related intangibles-1@            NaN
# Basic earnings per common share (in dollars per...            NaN
# Diluted earnings per common share (in dollars p...            NaN
# WEIGHTED AVERAGE COMMON SHARES OUTSTANDING:-1                 NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-2                                           4199.0
# Diluted (shares)-2                                         4232.0
#
#                                                     Dec. 28, 2019  \
# INCOME STATEMENT [ABSTRACT]-1                                 NaN
# Net revenue-1                                             71965.0
# Cost of sales-1                                           29825.0
# Gross margin-1                                            42140.0
# Research and development-1                                13362.0
# Marketing, general and administrative-1                    6150.0
# Restructuring and other charges-1                           393.0
# Operating expenses-1                                      20105.0
# Operating income-1                                        22035.0
# Gains (losses) on equity investments, net-1                1539.0
# Interest and other, net-1                                   484.0
# Income before taxes-1                                     24058.0
# Provision for taxes-1                                      3010.0
# Net income-1                                              21048.0
# Earnings per share—basic-1                                    NaN
# Earnings per share—diluted-1                                  NaN
# Amortization of acquisition-related intangibles-1           200.0
# Earnings per share—Basic-1                                  477.0
# Earnings per share—Diluted-1                                471.0
# Earnings per share - Basic-1                                  NaN
# Earnings per share - Diluted-1                                NaN
# Depreciation, Depletion and Amortization, Nonpr...            NaN
# Nonoperating Income (Expense)-1                               NaN
# Basic earnings per share of common stock-1                    NaN
# Diluted earnings per share of common stock-1                  NaN
# Restructuring and asset impairment charges-1                  NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-1                                              NaN
# Diluted (shares)-1                                            NaN
# Operating Expense [Member]-1                                  NaN
# Amortization of acquisition-related intangibles-1@            NaN
# Basic earnings per common share (in dollars per...            NaN
# Diluted earnings per common share (in dollars p...            NaN
# WEIGHTED AVERAGE COMMON SHARES OUTSTANDING:-1                 NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-2                                           4417.0
# Diluted (shares)-2                                         4473.0
#
#                                                     Dec. 29, 2018  \
# INCOME STATEMENT [ABSTRACT]-1                                 NaN
# Net revenue-1                                             70848.0
# Cost of sales-1                                           27111.0
# Gross margin-1                                            43737.0
# Research and development-1                                13543.0
# Marketing, general and administrative-1                    6750.0
# Restructuring and other charges-1                           -72.0
# Operating expenses-1                                      20421.0
# Operating income-1                                        23316.0
# Gains (losses) on equity investments, net-1                -125.0
# Interest and other, net-1                                   126.0
# Income before taxes-1                                     23317.0
# Provision for taxes-1                                      2264.0
# Net income-1                                              21053.0
# Earnings per share—basic-1                                    NaN
# Earnings per share—diluted-1                                  NaN
# Amortization of acquisition-related intangibles-1           200.0
# Earnings per share—Basic-1                                    NaN
# Earnings per share—Diluted-1                                  NaN
# Earnings per share - Basic-1                                457.0
# Earnings per share - Diluted-1                              448.0
# Depreciation, Depletion and Amortization, Nonpr...            NaN
# Nonoperating Income (Expense)-1                               NaN
# Basic earnings per share of common stock-1                    NaN
# Diluted earnings per share of common stock-1                  NaN
# Restructuring and asset impairment charges-1                  NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-1                                              NaN
# Diluted (shares)-1                                            NaN
# Operating Expense [Member]-1                                  NaN
# Amortization of acquisition-related intangibles-1@            NaN
# Basic earnings per common share (in dollars per...            NaN
# Diluted earnings per common share (in dollars p...            NaN
# WEIGHTED AVERAGE COMMON SHARES OUTSTANDING:-1                 NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-2                                           4611.0
# Diluted (shares)-2                                         4701.0
#
#                                                     Dec. 30, 2017  \
# INCOME STATEMENT [ABSTRACT]-1                                 NaN
# Net revenue-1                                             62761.0
# Cost of sales-1                                           23692.0
# Gross margin-1                                            39069.0
# Research and development-1                                13098.0
# Marketing, general and administrative-1                    7474.0
# Restructuring and other charges-1                           384.0
# Operating expenses-1                                      21133.0
# Operating income-1                                        17936.0
# Gains (losses) on equity investments, net-1                2651.0
# Interest and other, net-1                                     NaN
# Income before taxes-1                                     20352.0
# Provision for taxes-1                                     10751.0
# Net income-1                                               9601.0
# Earnings per share—basic-1                                    NaN
# Earnings per share—diluted-1                                  NaN
# Amortization of acquisition-related intangibles-1             NaN
# Earnings per share—Basic-1                                    NaN
# Earnings per share—Diluted-1                                  NaN
# Earnings per share - Basic-1                                204.0
# Earnings per share - Diluted-1                              199.0
# Depreciation, Depletion and Amortization, Nonpr...          177.0
# Nonoperating Income (Expense)-1                            -235.0
# Basic earnings per share of common stock-1                    NaN
# Diluted earnings per share of common stock-1                  NaN
# Restructuring and asset impairment charges-1                  NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-1                                              NaN
# Diluted (shares)-1                                            NaN
# Operating Expense [Member]-1                                  NaN
# Amortization of acquisition-related intangibles-1@            NaN
# Basic earnings per common share (in dollars per...            NaN
# Diluted earnings per common share (in dollars p...            NaN
# WEIGHTED AVERAGE COMMON SHARES OUTSTANDING:-1                 NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-2                                           4701.0
# Diluted (shares)-2                                         4835.0
#
#                                                     Dec. 31, 2016  \
# INCOME STATEMENT [ABSTRACT]-1                                 NaN
# Net revenue-1                                             59387.0
# Cost of sales-1                                           23196.0
# Gross margin-1                                            36191.0
# Research and development-1                                12740.0
# Marketing, general and administrative-1                    8397.0
# Restructuring and other charges-1                          1886.0
# Operating expenses-1                                      23317.0
# Operating income-1                                        12874.0
# Gains (losses) on equity investments, net-1                 506.0
# Interest and other, net-1                                  -444.0
# Income before taxes-1                                     12936.0
# Provision for taxes-1                                      2620.0
# Net income-1                                              10316.0
# Earnings per share—basic-1                                    NaN
# Earnings per share—diluted-1                                  NaN
# Amortization of acquisition-related intangibles-1           294.0
# Earnings per share—Basic-1                                    NaN
# Earnings per share—Diluted-1                                  NaN
# Earnings per share - Basic-1                                  NaN
# Earnings per share - Diluted-1                                NaN
# Depreciation, Depletion and Amortization, Nonpr...            NaN
# Nonoperating Income (Expense)-1                               NaN
# Basic earnings per share of common stock-1                  218.0
# Diluted earnings per share of common stock-1                212.0
# Restructuring and asset impairment charges-1                  NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-1                                              NaN
# Diluted (shares)-1                                            NaN
# Operating Expense [Member]-1                                  NaN
# Amortization of acquisition-related intangibles-1@            NaN
# Basic earnings per common share (in dollars per...            NaN
# Diluted earnings per common share (in dollars p...            NaN
# WEIGHTED AVERAGE COMMON SHARES OUTSTANDING:-1                 NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-2                                           4730.0
# Diluted (shares)-2                                         4875.0
#
#                                                     Dec. 26, 2015  \
# INCOME STATEMENT [ABSTRACT]-1                                 NaN
# Net revenue-1                                             55355.0
# Cost of sales-1                                           20676.0
# Gross margin-1                                            34679.0
# Research and development-1                                12128.0
# Marketing, general and administrative-1                    7930.0
# Restructuring and other charges-1                             NaN
# Operating expenses-1                                      20677.0
# Operating income-1                                        14002.0
# Gains (losses) on equity investments, net-1                 315.0
# Interest and other, net-1                                  -105.0
# Income before taxes-1                                     14212.0
# Provision for taxes-1                                      2792.0
# Net income-1                                              11420.0
# Earnings per share—basic-1                                    NaN
# Earnings per share—diluted-1                                  NaN
# Amortization of acquisition-related intangibles-1           265.0
# Earnings per share—Basic-1                                    NaN
# Earnings per share—Diluted-1                                  NaN
# Earnings per share - Basic-1                                  NaN
# Earnings per share - Diluted-1                                NaN
# Depreciation, Depletion and Amortization, Nonpr...            NaN
# Nonoperating Income (Expense)-1                               NaN
# Basic earnings per share of common stock-1                  241.0
# Diluted earnings per share of common stock-1                233.0
# Restructuring and asset impairment charges-1                354.0
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-1                                              NaN
# Diluted (shares)-1                                            NaN
# Operating Expense [Member]-1                                  NaN
# Amortization of acquisition-related intangibles-1@            NaN
# Basic earnings per common share (in dollars per...            NaN
# Diluted earnings per common share (in dollars p...            NaN
# WEIGHTED AVERAGE COMMON SHARES OUTSTANDING:-1                 NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-2                                           4742.0
# Diluted (shares)-2                                         4894.0
#
#                                                     Dec. 27, 2014  \
# INCOME STATEMENT [ABSTRACT]-1                                 NaN
# Net revenue-1                                             55870.0
# Cost of sales-1                                           20261.0
# Gross margin-1                                            35609.0
# Research and development-1                                11537.0
# Marketing, general and administrative-1                    8136.0
# Restructuring and other charges-1                             NaN
# Operating expenses-1                                      20262.0
# Operating income-1                                        15347.0
# Gains (losses) on equity investments, net-1                 411.0
# Interest and other, net-1                                    43.0
# Income before taxes-1                                     15801.0
# Provision for taxes-1                                      4097.0
# Net income-1                                              11704.0
# Earnings per share—basic-1                                    NaN
# Earnings per share—diluted-1                                  NaN
# Amortization of acquisition-related intangibles-1          1169.0
# Earnings per share—Basic-1                                    NaN
# Earnings per share—Diluted-1                                  NaN
# Earnings per share - Basic-1                                  NaN
# Earnings per share - Diluted-1                                NaN
# Depreciation, Depletion and Amortization, Nonpr...            NaN
# Nonoperating Income (Expense)-1                               NaN
# Basic earnings per share of common stock-1                  239.0
# Diluted earnings per share of common stock-1                231.0
# Restructuring and asset impairment charges-1                295.0
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-1                                           4901.0
# Diluted (shares)-1                                         5056.0
# Operating Expense [Member]-1                                  NaN
# Amortization of acquisition-related intangibles-1@          294.0
# Basic earnings per common share (in dollars per...            NaN
# Diluted earnings per common share (in dollars p...            NaN
# WEIGHTED AVERAGE COMMON SHARES OUTSTANDING:-1                 NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-2                                              NaN
# Diluted (shares)-2                                            NaN
#
#                                                     Dec. 28, 2013  \
# INCOME STATEMENT [ABSTRACT]-1                                 NaN
# Net revenue-1                                             52708.0
# Cost of sales-1                                           21187.0
# Gross margin-1                                            31521.0
# Research and development-1                                10611.0
# Marketing, general and administrative-1                    8088.0
# Restructuring and other charges-1                             NaN
# Operating expenses-1                                      19230.0
# Operating income-1                                        12291.0
# Gains (losses) on equity investments, net-1                 471.0
# Interest and other, net-1                                  -151.0
# Income before taxes-1                                     12611.0
# Provision for taxes-1                                      2991.0
# Net income-1                                               9620.0
# Earnings per share—basic-1                                    NaN
# Earnings per share—diluted-1                                  NaN
# Amortization of acquisition-related intangibles-1           291.0
# Earnings per share—Basic-1                                    NaN
# Earnings per share—Diluted-1                                  NaN
# Earnings per share - Basic-1                                  NaN
# Earnings per share - Diluted-1                                NaN
# Depreciation, Depletion and Amortization, Nonpr...            NaN
# Nonoperating Income (Expense)-1                               NaN
# Basic earnings per share of common stock-1                    NaN
# Diluted earnings per share of common stock-1                  NaN
# Restructuring and asset impairment charges-1                240.0
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-1                                           4970.0
# Diluted (shares)-1                                         5097.0
# Operating Expense [Member]-1                                  NaN
# Amortization of acquisition-related intangibles-1@            NaN
# Basic earnings per common share (in dollars per...          194.0
# Diluted earnings per common share (in dollars p...          189.0
# WEIGHTED AVERAGE COMMON SHARES OUTSTANDING:-1                 NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-2                                              NaN
# Diluted (shares)-2                                            NaN
#
#                                                     Dec. 29, 2012
# INCOME STATEMENT [ABSTRACT]-1                                 NaN
# Net revenue-1                                             53341.0
# Cost of sales-1                                           20190.0
# Gross margin-1                                            33151.0
# Research and development-1                                10148.0
# Marketing, general and administrative-1                    8057.0
# Restructuring and other charges-1                             NaN
# Operating expenses-1                                      18513.0
# Operating income-1                                        14638.0
# Gains (losses) on equity investments, net-1                 141.0
# Interest and other, net-1                                    94.0
# Income before taxes-1                                     14873.0
# Provision for taxes-1                                      3868.0
# Net income-1                                              11005.0
# Earnings per share—basic-1                                    NaN
# Earnings per share—diluted-1                                  NaN
# Amortization of acquisition-related intangibles-1           308.0
# Earnings per share—Basic-1                                    NaN
# Earnings per share—Diluted-1                                  NaN
# Earnings per share - Basic-1                                  NaN
# Earnings per share - Diluted-1                                NaN
# Depreciation, Depletion and Amortization, Nonpr...            NaN
# Nonoperating Income (Expense)-1                               NaN
# Basic earnings per share of common stock-1                    NaN
# Diluted earnings per share of common stock-1                  NaN
# Restructuring and asset impairment charges-1                  NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-1                                           4996.0
# Diluted (shares)-1                                         5160.0
# Operating Expense [Member]-1                                  NaN
# Amortization of acquisition-related intangibles-1@            NaN
# Basic earnings per common share (in dollars per...          220.0
# Diluted earnings per common share (in dollars p...          213.0
# WEIGHTED AVERAGE COMMON SHARES OUTSTANDING:-1                 NaN
# WEIGHTED AVERAGE SHARES OF COMMON STOCK OUTSTAN...            NaN
# Basic (shares)-2                                              NaN
# Diluted (shares)-2                                            NaN

# %%
print('-'*2000)
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
master_list[0]
# Out:
# {'file_type': '10-K/A',
#  'file_number': '001-3475622878151',
#  'file_date': '2022-05-02',
#  'file_year': 2022,
#  'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000156459022016871/0001564590-22-016871-index.htm',
#   'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001564590-22-016871&xbrl_type=v',
#   'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}}

# %%
json_url = get_filing_json(master_list[0], user_agent)

# %%
print(get_filing_htm(master_list, 2017, user_agent))
# Out:
# https://www.sec.gov/Archives/edgar/data/1318605/000156459017003118/tsla-10k_20161231.htm

# %%
content = requests.get(json_url, headers=user_agent)
content.status_code
# Out:
# 200

# %%
xml_summary = get_xml_Filing_Summary(json_url, user_agent)

# %%
master_reports = parse_xml_summary_of_file(xml_summary, user_agent)

# %%
statements_data = grab_financial_statements(master_reports)
statements_data
# Out:
# []

# %%
df = convert_statements_data_to_pandas(statements_data, 0)
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-126-60e445d0f9d6> in <module>
# ----> 1 df = convert_statements_data_to_pandas(statements_data, 0)
#       2 df
#
# <ipython-input-93-fc4c5d974146> in convert_statements_data_to_pandas(statements_data, statements_num)
#      12
#      13     #take the raw table data (without the headers)
# ---> 14     balance_data = statements_data[statements_num]['data']
#      15
#      16     df = pd.DataFrame(balance_data)
#
# IndexError: list index out of range

# %%
#for each file in the document landing page
for file in content['directory']['item']:
    
    #if the filing's name is FilingSummary.xml
    if file['name'] == 'FilingSummary.xml':
        
        #create the url for the xml file
        xml_summary = base_url + content['directory']['name'] + "/" + file['name']
    
        print('-' * 100)
        print('File Name: ' + file['name'])
        print('File Path: ' + xml_summary)
# Out:
# ----------------------------------------------------------------------------------------------------
# File Name: FilingSummary.xml
# File Path: https://www.sec.gov/Archives/edgar/data/21344/000002134418000008/FilingSummary.xml

# %%
#define a new base url that represents the filing folder. This will come in handy when we need to download the reports
base_url = xml_summary.replace('FilingSummary.xml', '')

#request and parse the content (use .content because this is an xml file not json)
content = requests.get(xml_summary, headers=user_agent).content

#create a soup object to parse the content using BeautifulSoup
soup = BeautifulSoup(content, 'lxml')

#find the 'myreports' tag because this contains all the individual reports submitted
reports = soup.find('myreports')

reports

# %%
#define a new base url that represents the filing folder. This will come in handy when we need to download the reports
base_url = xml_summary.replace('FilingSummary.xml', '')

#request and parse the content (use .content because this is an xml file not json)
content = requests.get(xml_summary, headers=user_agent).content

#create a soup object to parse the content using BeautifulSoup
soup = BeautifulSoup(content, 'lxml')

#find the 'myreports' tag because this contains all the individual reports submitted
reports = soup.find('myreports')

#want a list ot store all theindividual components of the report, so create the master list
master_reports = []

# loop through each report in the 'myreports' tag but avoid the last one as this will cause an error
# (last one has differnent formatting).
for index, report in enumerate(reports.find_all('report')[:-1]):
    
    #create a dictionary to store all the differnet parts we need
    report_dict = {}
    report_dict['name_short'] = report.shortname.text
    report_dict['name_long'] = report.longname.text
    report_dict['position'] = index+1
    #report_dict['category'] = report.menucategory.text
    report_dict['url'] = base_url + report.htmlfilename.text
    
    #append the dictionary to the master list.
    master_reports.append(report_dict)
    
    #print the info to the user.
    print('-'*100)
    print(base_url + report.htmlfilename.text)
    print(report.longname.text)
    print(report.shortname.text)
    #print(report.menucategory.text)
    print(index+1)

# %%
def scrape_company_financial_statements_combined(CIK_num, filing_type, start_year, num_years, user_agent):
    statements_dataframes = scrape_company_financial_statements(CIK_num, filing_type, start_year, num_years, user_agent)
    combined_financial_statements = combine_yearly_financial_statements(statements_dataframes)
    combined_financial_statements = reindex_combined_financial_statements(combined_financial_statements)
    
    return combined_financial_statements

# %%
### Function: Scrape Company Financial Statements
### Input: Company's CIK number, the type of filing you are searching for, the year you want to start from and
###        the number of years you want to go back from that starting year, and the user agent to access the SEC website
### Purpose: Performs a query search on the SEC website for a company's filings, accesses that filing, and then pulls out 
###          the relevant financial statements (balance sheet, cash flow, income, etc.) into a pandas dataframe
### Returns: A 2-dimensional array of dataframes with the rows being the years and the columns being which financial statement

def scrape_company_financial_statements(CIK_num, filing_type, start_year, num_years, user_agent):
    
    #query for a master list of all filings given a CIK_number and a filing type
    master_list = get_all_filings(CIK_num, filing_type, user_agent)

    #focus the master list on the years you want
    culled_master_list = filings_within_year_range(master_list, filing_type, start_year, num_years)
    

    #array to store dataframes
    dfs = []

    #for each filing in the master list
    for filing in culled_master_list:
    
        #get the statements data from the filing and store it in pandas dataframes
        dataframes = get_statements_data_from_filing_to_dataframes(filing, user_agent)
        dfs.append(dataframes)
        
    #financial statements tend to have multiple years, but we just want the current year so we drop the other columns
    for i in range(len(dfs)):
        for j in range(len(dfs[i])):
            
            #columns = years, drop all the columns that isn't the first one
            dfs[i][j].drop(columns=dfs[i][j].columns[1:], axis=1, inplace=True)
        
    return dfs

# %%
def get_statements_data_from_filing_to_dataframes(filing, user_agent):
    json_url = get_filing_json(filing, user_agent)
    xml_summary = get_xml_Filing_Summary(json_url, user_agent)

    master_reports = parse_xml_summary_of_file(xml_summary, user_agent)
    
    statements_data = grab_financial_statements(master_reports)
    
    dataframes = []
    for i in range(len(statements_data)):
        df = convert_statements_data_to_pandas(statements_data, i)
        df = add_tags_for_sections(statements_data[i]['sections'], df)
        df = add_tags_to_repeating_indices(df, '@')
        dataframes.append(df)
        
    return dataframes

# %%
master_list
# Out:
# [{'file_type': '10-K/A',
#   'file_number': '001-3475622878151',
#   'file_date': '2022-05-02',
#   'file_year': 2022,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000156459022016871/0001564590-22-016871-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001564590-22-016871&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K',
#   'file_number': '001-3475622595227',
#   'file_date': '2022-02-07',
#   'file_year': 2022,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000095017022000796/0000950170-22-000796-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0000950170-22-000796&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K/A',
#   'file_number': '001-3475621879543',
#   'file_date': '2021-04-30',
#   'file_year': 2021,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000156459021022604/0001564590-21-022604-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001564590-21-022604&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K',
#   'file_number': '001-3475621598537',
#   'file_date': '2021-02-08',
#   'file_year': 2021,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/0001564590-21-004599-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001564590-21-004599&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K/A',
#   'file_number': '001-3475620822228',
#   'file_date': '2020-04-28',
#   'file_year': 2020,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000156459020018984/0001564590-20-018984-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001564590-20-018984&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K',
#   'file_number': '001-3475620606921',
#   'file_date': '2020-02-13',
#   'file_year': 2020,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000156459020004475/0001564590-20-004475-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001564590-20-004475&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K',
#   'file_number': '001-3475619613254',
#   'file_date': '2019-02-19',
#   'file_year': 2019,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000156459019003165/0001564590-19-003165-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001564590-19-003165&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K',
#   'file_number': '001-3475618634585',
#   'file_date': '2018-02-23',
#   'file_year': 2018,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000156459018002956/0001564590-18-002956-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001564590-18-002956&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K',
#   'file_number': '001-3475617655025',
#   'file_date': '2017-03-01',
#   'file_year': 2017,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000156459017003118/0001564590-17-003118-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001564590-17-003118&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K',
#   'file_number': '001-34756161452193',
#   'file_date': '2016-02-24',
#   'file_year': 2016,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000156459016013195/0001564590-16-013195-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001564590-16-013195&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K',
#   'file_number': '001-3475615653676',
#   'file_date': '2015-02-26',
#   'file_year': 2015,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000156459015001031/0001564590-15-001031-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001564590-15-001031&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K',
#   'file_number': '001-3475614644610',
#   'file_date': '2014-02-26',
#   'file_year': 2014,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000119312514069681/0001193125-14-069681-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001193125-14-069681&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K',
#   'file_number': '001-3475613674219',
#   'file_date': '2013-03-07',
#   'file_year': 2013,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000119312513096241/0001193125-13-096241-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001193125-13-096241&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K/A',
#   'file_number': '001-3475612721233',
#   'file_date': '2012-03-28',
#   'file_year': 2012,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000119312512137560/0001193125-12-137560-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001193125-12-137560&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K',
#   'file_number': '001-3475612643075',
#   'file_date': '2012-02-27',
#   'file_year': 2012,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000119312512081990/0001193125-12-081990-index.htm',
#    'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=1318605&accession_number=0001193125-12-081990&xbrl_type=v',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}},
#  {'file_type': '10-K',
#   'file_number': '001-3475611659731',
#   'file_date': '2011-03-03',
#   'file_year': 2011,
#   'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/1318605/000119312511054847/0001193125-11-054847-index.htm',
#    'interactive_data': 'no link',
#    'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-34756&owner=exclude&count=100'}}]

# %%
json_url = get_filing_json(master_list[1], user_agent)
xml_summary = get_xml_Filing_Summary(json_url, user_agent)
master_reports = parse_xml_summary_of_file(xml_summary, user_agent)
statements_data = grab_financial_statements(master_reports)
# Out:
# We encountered an error

# %%
statements_data
# Out:
# [{'headers': [['Consolidated Balance Sheets - USD ($) $ in Millions',
#     'Dec. 31, 2021',
#     'Dec. 31, 2020']],
#   'sections': ['CURRENT ASSETS',
#    'CURRENT LIABILITIES',
#    "STOCKHOLDERS' EQUITY",
#    'CURRENT ASSETS',
#    'CURRENT ASSETS'],
#   'data': [['CURRENT ASSETS', '', '', ''],
#    ['Cash and cash equivalents', '', '$ 17,576', '$ 19,384'],
#    ['Short-term marketable securities', '', '131', ''],
#    ['Accounts receivable, net', '', '1,913', '1,886'],
#    ['Inventory', '', '5,757', '4,101'],
#    ['Prepaid expenses and other current assets', '', '1,723', '1,346'],
#    ['Total current assets', '', '27,100', '26,717'],
#    ['Property, plant and equipment, net', '', '18,884', '12,747'],
#    ['Operating lease right-of-use assets', '', '2,016', '1,558'],
#    ['Digital assets, net', '', '1,260', ''],
#    ['Intangible assets, net', '', '257', '313'],
#    ['Goodwill', '', '200', '207'],
#    ['Other non-current assets', '', '2,138', '1,536'],
#    ['Total assets', '', '62,131', '52,148'],
#    ['CURRENT LIABILITIES', '', '', ''],
#    ['Accounts payable', '', '10,025', '6,051'],
#    ['Accrued liabilities and other', '', '5,719', '3,855'],
#    ['Deferred revenue', '', '1,447', '1,458'],
#    ['Customer deposits', '', '925', '752'],
#    ['Current portion of debt and finance leases', '', '1,589', '2,132'],
#    ['Total current liabilities', '', '19,705', '14,248'],
#    ['Debt and finance leases, net of current portion', '', '5,245', '9,556'],
#    ['Deferred revenue, net of current portion', '', '2,052', '1,284'],
#    ['Other long-term liabilities', '', '3,546', '3,330'],
#    ['Total liabilities', '', '30,548', '28,418'],
#    ['Commitments and contingencies (Note 15)', '', '', ''],
#    ['Redeemable noncontrolling interests in subsidiaries', '', '568', '604'],
#    ['Convertible senior notes (Note 11)', '', '', '51'],
#    ["STOCKHOLDERS' EQUITY", '', '', ''],
#    ['Preferred stock; $0.001 par value; 100 shares authorized; no shares issued and outstanding',
#     '',
#     '',
#     ''],
#    ['Common stock; $0.001 par value; 2,000 shares authorized; 1,033 and 960 shares issued and outstanding as of December 31, 2021 and December 31, 2020, respectively',
#     '',
#     '1',
#     '1'],
#    ['Additional paid-in capital', '', '29,803', '27,260'],
#    ['Accumulated other comprehensive income', '', '54', '363'],
#    ['Retained earnings (accumulated deficit)', '', '331', '(5,399)'],
#    ["Total stockholders' equity", '', '30,189', '22,225'],
#    ['Noncontrolling interests in subsidiaries', '', '826', '850'],
#    ['Total liabilities and equity', '', '62,131', '52,148'],
#    ['Operating Lease Vehicles [Member]', '', '', ''],
#    ['CURRENT ASSETS', '', '', ''],
#    ['Operating lease vehicles, net', '', '4,511', '3,091'],
#    ['Solar Energy Systems [Member]', '', '', ''],
#    ['CURRENT ASSETS', '', '', ''],
#    ['Solar energy systems, net', '[1],[2]', '$ 5,765', '$ 5,979'],
#    [''],
#    ['[1]',
#     'As of December 31, 2021 and 2020, solar energy systems, net, included $36 million of gross finance leased assets with accumulated depreciation and amortization of $9 million and $7 million, respectively.'],
#    ['[2]',
#     'As of December 31, 2021 and 2020, there were $1.02 billion and $1.05 billion, respectively, of gross solar energy systems under lease pass-through fund arrangements with accumulated depreciation of $165 million and $137 million, respectively.']]},
#  {'headers': [['Consolidated Statements of Operations - USD ($) shares in Millions, $ in Millions',
#     '12 Months Ended'],
#    ['Dec. 31, 2021', 'Dec. 31, 2020', 'Dec. 31, 2019']],
#   'sections': ['REVENUES',
#    'COST OF REVENUES',
#    'OPERATING EXPENSES',
#    'NET INCOME (LOSS) PER SHARE OF COMMON STOCK ATTRIBUTABLE TO COMMON STOCKHOLDERS',
#    'WEIGHTED AVERAGE SHARES USED IN COMPUTING NET INCOME (LOSS) PER SHARE OF COMMON STOCK',
#    'REVENUES',
#    'REVENUES',
#    'REVENUES',
#    'REVENUES',
#    'COST OF REVENUES',
#    'REVENUES',
#    'COST OF REVENUES',
#    'REVENUES',
#    'COST OF REVENUES'],
#   'data': [['REVENUES', '', '', ''],
#    ['Total revenues', '$ 53,823', '$ 31,536', '$ 24,578'],
#    ['COST OF REVENUES', '', '', ''],
#    ['Total cost of revenues', '40,217', '24,906', '20,509'],
#    ['Gross profit', '13,606', '6,630', '4,069'],
#    ['OPERATING EXPENSES', '', '', ''],
#    ['Research and development', '2,593', '1,491', '1,343'],
#    ['Selling, general and administrative', '4,517', '3,145', '2,646'],
#    ['Restructuring and other', '(27)', '0', '149'],
#    ['Total operating expenses', '7,083', '4,636', '4,138'],
#    ['Income (loss) from operations', '6,523', '1,994', '(69)'],
#    ['Interest income', '56', '30', '44'],
#    ['Interest expense', '(371)', '(748)', '(685)'],
#    ['Other income (expense), net', '135', '(122)', '45'],
#    ['Income (loss) before income taxes', '6,343', '1,154', '(665)'],
#    ['Provision for income taxes', '699', '292', '110'],
#    ['Net income (loss)', '5,644', '862', '(775)'],
#    ['Net income attributable to noncontrolling interests and redeemable noncontrolling interests in subsidiaries',
#     '125',
#     '141',
#     '87'],
#    ['Net income (loss) attributable to common stockholders',
#     '5,519',
#     '721',
#     '(862)'],
#    ['Less: Buy-out of noncontrolling interest', '(5)', '31', '8'],
#    ['Net income (loss) used in computing net income per share of common stock',
#     '$ 5,524',
#     '$ 690',
#     '$ (870)'],
#    ['NET INCOME (LOSS) PER SHARE OF COMMON STOCK ATTRIBUTABLE TO COMMON STOCKHOLDERS',
#     '',
#     '',
#     ''],
#    ['Basic', '$ 5.60', '$ 0.74', '$ (0.98)'],
#    ['Diluted', '$ 4.90', '$ 0.64', '$ (0.98)'],
#    ['WEIGHTED AVERAGE SHARES USED IN COMPUTING NET INCOME (LOSS) PER SHARE OF COMMON STOCK',
#     '',
#     '',
#     ''],
#    ['Basic', '986', '933', '887'],
#    ['Diluted', '1,129', '1,083', '887'],
#    ['Automotive Sales [Member]', '', '', ''],
#    ['REVENUES', '', '', ''],
#    ['Revenues', '$ 44,125', '$ 24,604', '$ 19,358'],
#    ['Automotive Regulatory Credits [Member]', '', '', ''],
#    ['REVENUES', '', '', ''],
#    ['Revenues', '1,465', '1,580', '594'],
#    ['Automotive Leasing [Member]', '', '', ''],
#    ['REVENUES', '', '', ''],
#    ['Revenues', '1,642', '1,052', '869'],
#    ['Automotive Revenues [Member]', '', '', ''],
#    ['REVENUES', '', '', ''],
#    ['Revenues', '47,232', '27,236', '20,821'],
#    ['COST OF REVENUES', '', '', ''],
#    ['Cost of revenues', '32,415', '19,696', '15,939'],
#    ['Automotive leasing', '978', '563', '459'],
#    ['Total cost of revenues', '33,393', '20,259', '16,398'],
#    ['Energy Generation and Storage [Member]', '', '', ''],
#    ['REVENUES', '', '', ''],
#    ['Revenues', '2,789', '1,994', '1,531'],
#    ['COST OF REVENUES', '', '', ''],
#    ['Cost of revenues', '2,918', '1,976', '1,341'],
#    ['Services And Other [Member]', '', '', ''],
#    ['REVENUES', '', '', ''],
#    ['Revenues', '3,802', '2,306', '2,226'],
#    ['COST OF REVENUES', '', '', ''],
#    ['Cost of revenues', '$ 3,906', '$ 2,671', '$ 2,770']]},
#  {'headers': [['Consolidated Statements of Comprehensive Income (Loss) - USD ($) $ in Millions',
#     '12 Months Ended'],
#    ['Dec. 31, 2021', 'Dec. 31, 2020', 'Dec. 31, 2019']],
#   'sections': ['STATEMENT OF COMPREHENSIVE INCOME [ABSTRACT]',
#    'OTHER COMPREHENSIVE INCOME (LOSS):'],
#   'data': [['STATEMENT OF COMPREHENSIVE INCOME [ABSTRACT]', '', '', ''],
#    ['Net income (loss)', '$ 5,644', '$ 862', '$ (775)'],
#    ['OTHER COMPREHENSIVE INCOME (LOSS):', '', '', ''],
#    ['Foreign currency translation adjustment', '(308)', '399', '(28)'],
#    ['Unrealized net loss on marketable securities', '(1)', '', ''],
#    ['Comprehensive income (loss)', '5,335', '1,261', '(803)'],
#    ['Less: Comprehensive income attributable to noncontrolling interests and redeemable noncontrolling interests in subsidiaries',
#     '125',
#     '141',
#     '87'],
#    ['Comprehensive income (loss) attributable to common stockholders',
#     '$ 5,210',
#     '$ 1,120',
#     '$ (890)']]},
#  {'headers': [['Consolidated Statements of Cash Flows (Unaudited) - USD ($) $ in Millions',
#     '12 Months Ended'],
#    ['Dec. 31, 2021', 'Dec. 31, 2020', 'Dec. 31, 2019']],
#   'sections': ['CASH FLOWS FROM OPERATING ACTIVITIES',
#    'ADJUSTMENTS TO RECONCILE NET INCOME (LOSS) TO NET CASH PROVIDED BY (USED IN) OPERATING ACTIVITIES:',
#    'CHANGES IN OPERATING ASSETS AND LIABILITIES:',
#    'CASH FLOWS FROM INVESTING ACTIVITIES',
#    'CASH FLOWS FROM FINANCING ACTIVITIES',
#    'SUPPLEMENTAL NON-CASH INVESTING AND FINANCING ACTIVITIES',
#    'SUPPLEMENTAL DISCLOSURES'],
#   'data': [['CASH FLOWS FROM OPERATING ACTIVITIES', '', '', ''],
#    ['Net income (loss)', '$ 5,644', '$ 862', '$ (775)'],
#    ['ADJUSTMENTS TO RECONCILE NET INCOME (LOSS) TO NET CASH PROVIDED BY (USED IN) OPERATING ACTIVITIES:',
#     '',
#     '',
#     ''],
#    ['Depreciation, amortization and impairment', '2,911', '2,322', '2,154'],
#    ['Stock-based compensation', '2,121', '1,734', '898'],
#    ['Inventory and purchase commitments write-downs', '140', '202', '193'],
#    ['Foreign currency transaction net unrealized (gain) loss',
#     '(55)',
#     '114',
#     '(48)'],
#    ['Non-cash interest and other operating activities', '245', '525', '520'],
#    ['Digital assets gain, net', '(27)', '0', '0'],
#    ['Operating cash flow related to repayment of discounted convertible senior notes',
#     '0',
#     '0',
#     '(188)'],
#    ['CHANGES IN OPERATING ASSETS AND LIABILITIES:', '', '', ''],
#    ['Accounts receivable', '130', '(652)', '(367)'],
#    ['Inventory', '1,709', '(422)', '(429)'],
#    ['Operating lease vehicles', '2,114', '(1,072)', '(764)'],
#    ['Prepaid expenses and other current assets', '271', '(251)', '(288)'],
#    ['Other non-current assets', '1,291', '(344)', '115'],
#    ['Accounts payable and accrued liabilities', '4,578', '2,102', '646'],
#    ['Deferred revenue', '793', '321', '801'],
#    ['Customer deposits', '186', '7', '(58)'],
#    ['Other long-term liabilities', '476', '495', '(5)'],
#    ['Net cash provided by operating activities', '11,497', '5,943', '2,405'],
#    ['CASH FLOWS FROM INVESTING ACTIVITIES', '', '', ''],
#    ['Purchases of property and equipment excluding finance leases, net of sales',
#     '(6,482)',
#     '(3,157)',
#     '(1,327)'],
#    ['Purchases of solar energy systems, net of sales', '32', '(75)', '(105)'],
#    ['Purchases of digital assets', '1,500', '0', '0'],
#    ['Proceeds from sales of digital assets', '272', '0', '0'],
#    ['Purchases of marketable securities', '(132)', '0', '0'],
#    ['Receipt of government grants', '6', '123', '46'],
#    ['Purchase of intangible assets', '(1,500)', '(10)', '(5)'],
#    ['Business combinations, net of cash acquired', '0', '(13)', '(45)'],
#    ['Net cash used in investing activities', '(7,868)', '(3,132)', '(1,436)'],
#    ['CASH FLOWS FROM FINANCING ACTIVITIES', '', '', ''],
#    ['Proceeds from issuances of common stock in public offerings, net of issuance costs',
#     '0',
#     '12,269',
#     '848'],
#    ['Proceeds from issuances of convertible and other debt',
#     '8,883',
#     '9,713',
#     '10,669'],
#    ['Repayments of convertible and other debt',
#     '14,167',
#     '(11,623)',
#     '(9,161)'],
#    ['Collateralized lease repayments', '(9)', '(240)', '(389)'],
#    ['Proceeds from exercises of stock options and other stock issuances',
#     '707',
#     '417',
#     '263'],
#    ['Principal payments on finance leases', '(439)', '(338)', '(321)'],
#    ['Debt issuance costs', '(9)', '(6)', '(37)'],
#    ['Purchase of convertible note hedges', '', '', '476'],
#    ['Proceeds from issuance of warrants', '', '', '174'],
#    ['Proceeds from investments by noncontrolling interests in subsidiaries',
#     '2',
#     '24',
#     '279'],
#    ['Distributions paid to noncontrolling interests in subsidiaries',
#     '(161)',
#     '(208)',
#     '(311)'],
#    ['Payments for buy-outs of noncontrolling interests in subsidiaries',
#     '10',
#     '(35)',
#     '(9)'],
#    ['Net cash (used in) provided by financing activities',
#     '(5,203)',
#     '9,973',
#     '1,529'],
#    ['Effect of exchange rate changes on cash and cash equivalents and restricted cash',
#     '(183)',
#     '334',
#     '8'],
#    ['Net (decrease) increase in cash and cash equivalents and restricted cash',
#     '(1,757)',
#     '13,118',
#     '2,506'],
#    ['Cash and cash equivalents and restricted cash, beginning of period',
#     '19,901',
#     '6,783',
#     '4,277'],
#    ['Cash and cash equivalents and restricted cash, end of period',
#     '18,144',
#     '19,901',
#     '6,783'],
#    ['SUPPLEMENTAL NON-CASH INVESTING AND FINANCING ACTIVITIES', '', '', ''],
#    ['Equity issued in connection with business combination', '0', '0', '207'],
#    ['Acquisitions of property and equipment included in liabilities',
#     '2,251',
#     '1,088',
#     '562'],
#    ['SUPPLEMENTAL DISCLOSURES', '', '', ''],
#    ['Cash paid during the period for interest, net of amounts capitalized',
#     '266',
#     '444',
#     '455'],
#    ['Cash paid during the period for taxes, net of refunds',
#     '$ 561',
#     '$ 115',
#     '$ 54']]}]

# %%
document_num = 1
print(statements_data[document_num]['data'])
# Out:
# [['STATEMENT OF COMPREHENSIVE INCOME [ABSTRACT]', '', '', ''], ['Net income', '$ 94,680', '$ 57,411', '$ 55,256'], ['OTHER COMPREHENSIVE INCOME/(LOSS):', '', '', ''], ['Change in foreign currency translation, net of tax', '501', '88', '(408)'], ['CHANGE IN UNREALIZED GAINS/LOSSES ON DERIVATIVE INSTRUMENTS, NET OF TAX:', '', '', ''], ['Change in fair value of derivative instruments', '32', '79', ''], ['Change in fair value of derivative instruments', '', '', '(661)'], ['Adjustment for net (gains)/losses realized and included in net income', '1,003', '(1,264)', ''], ['Adjustment for net (gains)/losses realized and included in net income', '', '', '23'], ['Total change in unrealized gains/losses on derivative instruments', '1,035', '(1,185)', ''], ['Total change in unrealized gains/losses on derivative instruments', '', '', '(638)'], ['CHANGE IN UNREALIZED GAINS/LOSSES ON MARKETABLE DEBT SECURITIES, NET OF TAX:', '', '', ''], ['Change in fair value of marketable debt securities', '(694)', '1,202', '3,802'], ['Adjustment for net (gains)/losses realized and included in net income', '(273)', '(63)', '25'], ['Total change in unrealized gains/losses on marketable debt securities', '(967)', '1,139', '3,827'], ['Total other comprehensive income/(loss)', '569', '42', '2,781'], ['Total comprehensive income', '$ 95,249', '$ 57,453', '$ 58,037']]

# %%
#define what document you want to convert (0 to n documents)
document_num = 3


#balance_header = statements_data[0]['headers'][-1]
balance_data = statements_data[document_num]['data']

df = pd.DataFrame(balance_data)


#Define the Index column, rename it, and we need to make sure to drop the old column once we reindex
df.index = df[0]
#df.index.name = 'Category'
df = df.drop(0, axis = 1)


# Get rid of the '$', '(', ')', and convert the '' to NaNs.
df = df.replace('[\$,)]','', regex=True )\
                     .replace( '[(]','-', regex=True)\
                     .replace( '', 'NaN', regex=True)


# Display
print('-'*100)
print('Before type conversion')
print('-'*100)
print(statements_data[document_num]['headers'])
display(df)
# Out:
# ----------------------------------------------------------------------------------------------------
# Before type conversion
# ----------------------------------------------------------------------------------------------------
# [['CONSOLIDATED STATEMENTS OF CASH FLOWS - USD ($) $ in Millions', '12 Months Ended'], ['Sep. 25, 2021', 'Sep. 26, 2020', 'Sep. 28, 2019']]
#                                                           1        2       3
# 0
# STATEMENT OF CASH FLOWS [ABSTRACT]                      NaN      NaN     NaN
# Cash, cash equivalents and restricted cash, beg...    39789    50224   25913
# OPERATING ACTIVITIES:                                   NaN      NaN     NaN
# Net income                                            94680    57411   55256
# ADJUSTMENTS TO RECONCILE NET INCOME TO CASH GEN...      NaN      NaN     NaN
# Depreciation and amortization                         11284    11056   12547
# Share-based compensation expense                       7906     6829    6068
# Deferred income tax benefit                           -4774     -215    -340
# Other                                                  -147      -97    -652
# CHANGES IN OPERATING ASSETS AND LIABILITIES:            NaN      NaN     NaN
# Accounts receivable, net                             -10125     6917     245
# Inventories                                           -2642     -127    -289
# Vendor non-trade receivables                          -3903     1553    2931
# Other current and non-current assets                  -8042    -9588     873
# Accounts payable                                      12326    -4062   -1923
# Deferred revenue                                       1676     2081    -625
# Other current and non-current liabilities              5799     8916   -4700
# Cash generated by operating activities               104038    80674   69391
# INVESTING ACTIVITIES:                                   NaN      NaN     NaN
# Purchases of marketable securities                  -109558  -114938  -39630
# Proceeds from maturities of marketable securities     59023    69918   40102
# Proceeds from sales of marketable securities          47460    50473   56988
# Payments for acquisition of property, plant and...   -11085    -7309  -10495
# Payments made in connection with business acqui...      -33    -1524    -624
# Purchases of non-marketable securities                 -131     -210   -1001
# Proceeds from non-marketable securities                 387       92    1634
# Other                                                  -608     -791   -1078
# Cash generated by/(used in) investing activities     -14545    -4289   45896
# FINANCING ACTIVITIES:                                   NaN      NaN     NaN
# Proceeds from issuance of common stock                 1105      880     781
# Payments for taxes related to net share settlem...    -6556    -3634   -2817
# Payments for dividends and dividend equivalents      -14467   -14081  -14119
# Repurchases of common stock                          -85971   -72358  -66897
# Proceeds from issuance of term debt, net              20393    16091    6963
# Repayments of term debt                               -8750   -12629   -8805
# Proceeds from/(Repayments of) commercial paper,...     1022     -963   -5977
# Other                                                  -129     -126    -105
# Cash used in financing activities                    -93353   -86820  -90976
# Increase/(Decrease) in cash, cash equivalents a...    -3860   -10435   24311
# Cash, cash equivalents and restricted cash, end...    35929    39789   50224
# SUPPLEMENTAL CASH FLOW DISCLOSURE:                      NaN      NaN     NaN
# Cash paid for income taxes, net                       25385     9501   15263
# Cash paid for interest                                 2687     3002    3423

# %%
    
for i in range(df.shape[1]):
    df[df.columns[i]] = df[df.columns[i]].apply(change_to_float)    
df = df.astype(float)
df = get_rid_of_null_columns(df)
display(df)
print(df.shape)
# Out:
#                                                            1         2  \
# 0
# STATEMENT OF CASH FLOWS [ABSTRACT]                       NaN       NaN
# Cash, cash equivalents and restricted cash, beg...   39789.0   50224.0
# OPERATING ACTIVITIES:                                    NaN       NaN
# Net income                                           94680.0   57411.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO CASH GEN...       NaN       NaN
# Depreciation and amortization                        11284.0   11056.0
# Share-based compensation expense                      7906.0    6829.0
# Deferred income tax benefit                          -4774.0    -215.0
# Other                                                 -147.0     -97.0
# CHANGES IN OPERATING ASSETS AND LIABILITIES:             NaN       NaN
# Accounts receivable, net                            -10125.0    6917.0
# Inventories                                          -2642.0    -127.0
# Vendor non-trade receivables                         -3903.0    1553.0
# Other current and non-current assets                 -8042.0   -9588.0
# Accounts payable                                     12326.0   -4062.0
# Deferred revenue                                      1676.0    2081.0
# Other current and non-current liabilities             5799.0    8916.0
# Cash generated by operating activities              104038.0   80674.0
# INVESTING ACTIVITIES:                                    NaN       NaN
# Purchases of marketable securities                 -109558.0 -114938.0
# Proceeds from maturities of marketable securities    59023.0   69918.0
# Proceeds from sales of marketable securities         47460.0   50473.0
# Payments for acquisition of property, plant and...  -11085.0   -7309.0
# Payments made in connection with business acqui...     -33.0   -1524.0
# Purchases of non-marketable securities                -131.0    -210.0
# Proceeds from non-marketable securities                387.0      92.0
# Other                                                 -608.0    -791.0
# Cash generated by/(used in) investing activities    -14545.0   -4289.0
# FINANCING ACTIVITIES:                                    NaN       NaN
# Proceeds from issuance of common stock                1105.0     880.0
# Payments for taxes related to net share settlem...   -6556.0   -3634.0
# Payments for dividends and dividend equivalents     -14467.0  -14081.0
# Repurchases of common stock                         -85971.0  -72358.0
# Proceeds from issuance of term debt, net             20393.0   16091.0
# Repayments of term debt                              -8750.0  -12629.0
# Proceeds from/(Repayments of) commercial paper,...    1022.0    -963.0
# Other                                                 -129.0    -126.0
# Cash used in financing activities                   -93353.0  -86820.0
# Increase/(Decrease) in cash, cash equivalents a...   -3860.0  -10435.0
# Cash, cash equivalents and restricted cash, end...   35929.0   39789.0
# SUPPLEMENTAL CASH FLOW DISCLOSURE:                       NaN       NaN
# Cash paid for income taxes, net                      25385.0    9501.0
# Cash paid for interest                                2687.0    3002.0
#
#                                                           3
# 0
# STATEMENT OF CASH FLOWS [ABSTRACT]                      NaN
# Cash, cash equivalents and restricted cash, beg...  25913.0
# OPERATING ACTIVITIES:                                   NaN
# Net income                                          55256.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO CASH GEN...      NaN
# Depreciation and amortization                       12547.0
# Share-based compensation expense                     6068.0
# Deferred income tax benefit                          -340.0
# Other                                                -652.0
# CHANGES IN OPERATING ASSETS AND LIABILITIES:            NaN
# Accounts receivable, net                              245.0
# Inventories                                          -289.0
# Vendor non-trade receivables                         2931.0
# Other current and non-current assets                  873.0
# Accounts payable                                    -1923.0
# Deferred revenue                                     -625.0
# Other current and non-current liabilities           -4700.0
# Cash generated by operating activities              69391.0
# INVESTING ACTIVITIES:                                   NaN
# Purchases of marketable securities                 -39630.0
# Proceeds from maturities of marketable securities   40102.0
# Proceeds from sales of marketable securities        56988.0
# Payments for acquisition of property, plant and... -10495.0
# Payments made in connection with business acqui...   -624.0
# Purchases of non-marketable securities              -1001.0
# Proceeds from non-marketable securities              1634.0
# Other                                               -1078.0
# Cash generated by/(used in) investing activities    45896.0
# FINANCING ACTIVITIES:                                   NaN
# Proceeds from issuance of common stock                781.0
# Payments for taxes related to net share settlem...  -2817.0
# Payments for dividends and dividend equivalents    -14119.0
# Repurchases of common stock                        -66897.0
# Proceeds from issuance of term debt, net             6963.0
# Repayments of term debt                             -8805.0
# Proceeds from/(Repayments of) commercial paper,...  -5977.0
# Other                                                -105.0
# Cash used in financing activities                  -90976.0
# Increase/(Decrease) in cash, cash equivalents a...  24311.0
# Cash, cash equivalents and restricted cash, end...  50224.0
# SUPPLEMENTAL CASH FLOW DISCLOSURE:                      NaN
# Cash paid for income taxes, net                     15263.0
# Cash paid for interest                               3423.0
# (43, 3)

# %%
#below is to account for the headers having multiple levels versus only one level
if len(statements_data[document_num]['headers']) == 1:
    header = statements_data[document_num]['headers'][0][1:]
    document = statements_data[document_num]['headers'][0][0]
    
elif len(statements_data[document_num]['headers']) == 2:
    header = statements_data[document_num]['headers'][-1]
    document = statements_data[document_num]['headers'][0][0] 
else:
    header = df.columns
    document = 'Category'
    
    
    
print(header)
print(document)
# Out:
# ['Sep. 25, 2021', 'Sep. 26, 2020', 'Sep. 28, 2019']
# CONSOLIDATED STATEMENTS OF CASH FLOWS - USD ($) $ in Millions

# %%
# everything is a string, so let's convert all the data to a float
df = df.astype(float)

#Change the column headers 
df.columns = header

#Change the name of the index
df.index.name = document

#Display
print('-'*100)
print('Final Product')
print('-'*100)

#show the df
df
# Out:
# ----------------------------------------------------------------------------------------------------
# Final Product
# ----------------------------------------------------------------------------------------------------
#                                                     Sep. 25, 2021  \
# CONSOLIDATED STATEMENTS OF CASH FLOWS - USD ($)...
# STATEMENT OF CASH FLOWS [ABSTRACT]                            NaN
# Cash, cash equivalents and restricted cash, beg...        39789.0
# OPERATING ACTIVITIES:                                         NaN
# Net income                                                94680.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO CASH GEN...            NaN
# Depreciation and amortization                             11284.0
# Share-based compensation expense                           7906.0
# Deferred income tax benefit                               -4774.0
# Other                                                      -147.0
# CHANGES IN OPERATING ASSETS AND LIABILITIES:                  NaN
# Accounts receivable, net                                 -10125.0
# Inventories                                               -2642.0
# Vendor non-trade receivables                              -3903.0
# Other current and non-current assets                      -8042.0
# Accounts payable                                          12326.0
# Deferred revenue                                           1676.0
# Other current and non-current liabilities                  5799.0
# Cash generated by operating activities                   104038.0
# INVESTING ACTIVITIES:                                         NaN
# Purchases of marketable securities                      -109558.0
# Proceeds from maturities of marketable securities         59023.0
# Proceeds from sales of marketable securities              47460.0
# Payments for acquisition of property, plant and...       -11085.0
# Payments made in connection with business acqui...          -33.0
# Purchases of non-marketable securities                     -131.0
# Proceeds from non-marketable securities                     387.0
# Other                                                      -608.0
# Cash generated by/(used in) investing activities         -14545.0
# FINANCING ACTIVITIES:                                         NaN
# Proceeds from issuance of common stock                     1105.0
# Payments for taxes related to net share settlem...        -6556.0
# Payments for dividends and dividend equivalents          -14467.0
# Repurchases of common stock                              -85971.0
# Proceeds from issuance of term debt, net                  20393.0
# Repayments of term debt                                   -8750.0
# Proceeds from/(Repayments of) commercial paper,...         1022.0
# Other                                                      -129.0
# Cash used in financing activities                        -93353.0
# Increase/(Decrease) in cash, cash equivalents a...        -3860.0
# Cash, cash equivalents and restricted cash, end...        35929.0
# SUPPLEMENTAL CASH FLOW DISCLOSURE:                            NaN
# Cash paid for income taxes, net                           25385.0
# Cash paid for interest                                     2687.0
#
#                                                     Sep. 26, 2020  \
# CONSOLIDATED STATEMENTS OF CASH FLOWS - USD ($)...
# STATEMENT OF CASH FLOWS [ABSTRACT]                            NaN
# Cash, cash equivalents and restricted cash, beg...        50224.0
# OPERATING ACTIVITIES:                                         NaN
# Net income                                                57411.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO CASH GEN...            NaN
# Depreciation and amortization                             11056.0
# Share-based compensation expense                           6829.0
# Deferred income tax benefit                                -215.0
# Other                                                       -97.0
# CHANGES IN OPERATING ASSETS AND LIABILITIES:                  NaN
# Accounts receivable, net                                   6917.0
# Inventories                                                -127.0
# Vendor non-trade receivables                               1553.0
# Other current and non-current assets                      -9588.0
# Accounts payable                                          -4062.0
# Deferred revenue                                           2081.0
# Other current and non-current liabilities                  8916.0
# Cash generated by operating activities                    80674.0
# INVESTING ACTIVITIES:                                         NaN
# Purchases of marketable securities                      -114938.0
# Proceeds from maturities of marketable securities         69918.0
# Proceeds from sales of marketable securities              50473.0
# Payments for acquisition of property, plant and...        -7309.0
# Payments made in connection with business acqui...        -1524.0
# Purchases of non-marketable securities                     -210.0
# Proceeds from non-marketable securities                      92.0
# Other                                                      -791.0
# Cash generated by/(used in) investing activities          -4289.0
# FINANCING ACTIVITIES:                                         NaN
# Proceeds from issuance of common stock                      880.0
# Payments for taxes related to net share settlem...        -3634.0
# Payments for dividends and dividend equivalents          -14081.0
# Repurchases of common stock                              -72358.0
# Proceeds from issuance of term debt, net                  16091.0
# Repayments of term debt                                  -12629.0
# Proceeds from/(Repayments of) commercial paper,...         -963.0
# Other                                                      -126.0
# Cash used in financing activities                        -86820.0
# Increase/(Decrease) in cash, cash equivalents a...       -10435.0
# Cash, cash equivalents and restricted cash, end...        39789.0
# SUPPLEMENTAL CASH FLOW DISCLOSURE:                            NaN
# Cash paid for income taxes, net                            9501.0
# Cash paid for interest                                     3002.0
#
#                                                     Sep. 28, 2019
# CONSOLIDATED STATEMENTS OF CASH FLOWS - USD ($)...
# STATEMENT OF CASH FLOWS [ABSTRACT]                            NaN
# Cash, cash equivalents and restricted cash, beg...        25913.0
# OPERATING ACTIVITIES:                                         NaN
# Net income                                                55256.0
# ADJUSTMENTS TO RECONCILE NET INCOME TO CASH GEN...            NaN
# Depreciation and amortization                             12547.0
# Share-based compensation expense                           6068.0
# Deferred income tax benefit                                -340.0
# Other                                                      -652.0
# CHANGES IN OPERATING ASSETS AND LIABILITIES:                  NaN
# Accounts receivable, net                                    245.0
# Inventories                                                -289.0
# Vendor non-trade receivables                               2931.0
# Other current and non-current assets                        873.0
# Accounts payable                                          -1923.0
# Deferred revenue                                           -625.0
# Other current and non-current liabilities                 -4700.0
# Cash generated by operating activities                    69391.0
# INVESTING ACTIVITIES:                                         NaN
# Purchases of marketable securities                       -39630.0
# Proceeds from maturities of marketable securities         40102.0
# Proceeds from sales of marketable securities              56988.0
# Payments for acquisition of property, plant and...       -10495.0
# Payments made in connection with business acqui...         -624.0
# Purchases of non-marketable securities                    -1001.0
# Proceeds from non-marketable securities                    1634.0
# Other                                                     -1078.0
# Cash generated by/(used in) investing activities          45896.0
# FINANCING ACTIVITIES:                                         NaN
# Proceeds from issuance of common stock                      781.0
# Payments for taxes related to net share settlem...        -2817.0
# Payments for dividends and dividend equivalents          -14119.0
# Repurchases of common stock                              -66897.0
# Proceeds from issuance of term debt, net                   6963.0
# Repayments of term debt                                   -8805.0
# Proceeds from/(Repayments of) commercial paper,...        -5977.0
# Other                                                      -105.0
# Cash used in financing activities                        -90976.0
# Increase/(Decrease) in cash, cash equivalents a...        24311.0
# Cash, cash equivalents and restricted cash, end...        50224.0
# SUPPLEMENTAL CASH FLOW DISCLOSURE:                            NaN
# Cash paid for income taxes, net                           15263.0
# Cash paid for interest                                     3423.0

# %%
get_statements_data_from_filing_to_dataframes(master_list[0], user_agent)
# Out:
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R1.htm
# 0001001 - Document - Cover Page
# Cover Page
# 1
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R2.htm
# 1001002 - Statement - CONSOLIDATED STATEMENTS OF OPERATIONS
# CONSOLIDATED STATEMENTS OF OPERATIONS
# 2
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R3.htm
# 1002003 - Statement - CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME
# CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME
# 3
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R4.htm
# 1003004 - Statement - CONSOLIDATED BALANCE SHEETS
# CONSOLIDATED BALANCE SHEETS
# 4
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R5.htm
# 1004005 - Statement - CONSOLIDATED BALANCE SHEETS (Parenthetical)
# CONSOLIDATED BALANCE SHEETS (Parenthetical)
# 5
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R6.htm
# 1005006 - Statement - CONSOLIDATED STATEMENTS OF SHAREHOLDERS' EQUITY
# CONSOLIDATED STATEMENTS OF SHAREHOLDERS' EQUITY
# 6
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R7.htm
# 1006007 - Statement - CONSOLIDATED STATEMENTS OF CASH FLOWS
# CONSOLIDATED STATEMENTS OF CASH FLOWS
# 7
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R8.htm
# 2101101 - Disclosure - Summary of Significant Accounting Policies
# Summary of Significant Accounting Policies
# 8
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R9.htm
# 2106102 - Disclosure - Revenue Recognition
# Revenue Recognition
# 9
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R10.htm
# 2111103 - Disclosure - Financial Instruments
# Financial Instruments
# 10
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R11.htm
# 2118104 - Disclosure - Consolidated Financial Statement Details
# Consolidated Financial Statement Details
# 11
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R12.htm
# 2123105 - Disclosure - Income Taxes
# Income Taxes
# 12
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R13.htm
# 2130106 - Disclosure - Leases
# Leases
# 13
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R14.htm
# 2135107 - Disclosure - Debt
# Debt
# 14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R15.htm
# 2141108 - Disclosure - Shareholders' Equity
# Shareholders' Equity
# 15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R16.htm
# 2145109 - Disclosure - Benefit Plans
# Benefit Plans
# 16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R17.htm
# 2150110 - Disclosure - Commitments and Contingencies
# Commitments and Contingencies
# 17
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R18.htm
# 2155111 - Disclosure - Segment Information and Geographic Data
# Segment Information and Geographic Data
# 18
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R19.htm
# 2202201 - Disclosure - Summary of Significant Accounting Policies (Policies)
# Summary of Significant Accounting Policies (Policies)
# 19
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R20.htm
# 2303301 - Disclosure - Summary of Significant Accounting Policies (Tables)
# Summary of Significant Accounting Policies (Tables)
# 20
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R21.htm
# 2307302 - Disclosure - Revenue Recognition (Tables)
# Revenue Recognition (Tables)
# 21
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R22.htm
# 2312303 - Disclosure - Financial Instruments (Tables)
# Financial Instruments (Tables)
# 22
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R23.htm
# 2319304 - Disclosure - Consolidated Financial Statement Details (Tables)
# Consolidated Financial Statement Details (Tables)
# 23
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R24.htm
# 2324305 - Disclosure - Income Taxes (Tables)
# Income Taxes (Tables)
# 24
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R25.htm
# 2331306 - Disclosure - Leases (Tables)
# Leases (Tables)
# 25
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R26.htm
# 2336307 - Disclosure - Debt (Tables)
# Debt (Tables)
# 26
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R27.htm
# 2342308 - Disclosure - Shareholders' Equity (Tables)
# Shareholders' Equity (Tables)
# 27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R28.htm
# 2346309 - Disclosure - Benefit Plans (Tables)
# Benefit Plans (Tables)
# 28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R29.htm
# 2351310 - Disclosure - Commitments and Contingencies (Tables)
# Commitments and Contingencies (Tables)
# 29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R30.htm
# 2356311 - Disclosure - Segment Information and Geographic Data (Tables)
# Segment Information and Geographic Data (Tables)
# 30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R31.htm
# 2404401 - Disclosure - Summary of Significant Accounting Policies - Additional Information (Details)
# Summary of Significant Accounting Policies - Additional Information (Details)
# 31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R32.htm
# 2405402 - Disclosure - Summary of Significant Accounting Policies - Computation of Basic and Diluted Earnings Per Share (Details)
# Summary of Significant Accounting Policies - Computation of Basic and Diluted Earnings Per Share (Details)
# 32
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R33.htm
# 2408403 - Disclosure - Revenue Recognition - Additional Information (Details)
# Revenue Recognition - Additional Information (Details)
# 33
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R34.htm
# 2409404 - Disclosure - Revenue Recognition - Deferred Revenue, Expected Timing of Realization (Details)
# Revenue Recognition - Deferred Revenue, Expected Timing of Realization (Details)
# 34
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R35.htm
# 2410405 - Disclosure - Revenue Recognition - Net Sales Disaggregated by Significant Products and Services (Details)
# Revenue Recognition - Net Sales Disaggregated by Significant Products and Services (Details)
# 35
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R36.htm
# 2413406 - Disclosure - Financial Instruments - Cash, Cash Equivalents and Marketable Securities (Details)
# Financial Instruments - Cash, Cash Equivalents and Marketable Securities (Details)
# 36
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R37.htm
# 2414407 - Disclosure - Financial Instruments - Non-Current Marketable Debt Securities by Contractual Maturity (Details)
# Financial Instruments - Non-Current Marketable Debt Securities by Contractual Maturity (Details)
# 37
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R38.htm
# 2415408 - Disclosure - Financial Instruments - Additional Information (Details)
# Financial Instruments - Additional Information (Details)
# 38
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R39.htm
# 2416409 - Disclosure - Financial Instruments - Notional Amounts of Derivative Instruments (Details)
# Financial Instruments - Notional Amounts of Derivative Instruments (Details)
# 39
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R40.htm
# 2417410 - Disclosure - Financial Instruments - Derivative Instruments Designated as Fair Value Hedges and Related Hedged Items (Details)
# Financial Instruments - Derivative Instruments Designated as Fair Value Hedges and Related Hedged Items (Details)
# 40
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R41.htm
# 2420411 - Disclosure - Consolidated Financial Statement Details - Property, Plant and Equipment, Net (Details)
# Consolidated Financial Statement Details - Property, Plant and Equipment, Net (Details)
# 41
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R42.htm
# 2421412 - Disclosure - Consolidated Financial Statement Details - Other Non-Current Liabilities (Details)
# Consolidated Financial Statement Details - Other Non-Current Liabilities (Details)
# 42
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R43.htm
# 2422413 - Disclosure - Consolidated Financial Statement Details - Other Income/(Expense), Net (Details)
# Consolidated Financial Statement Details - Other Income/(Expense), Net (Details)
# 43
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R44.htm
# 2425414 - Disclosure - Income Taxes - Provision for Income Taxes (Details)
# Income Taxes - Provision for Income Taxes (Details)
# 44
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R45.htm
# 2426415 - Disclosure - Income Taxes - Additional Information (Details)
# Income Taxes - Additional Information (Details)
# 45
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R46.htm
# 2427416 - Disclosure - Income Taxes - Reconciliation of the Provision for Income Taxes (Details)
# Income Taxes - Reconciliation of the Provision for Income Taxes (Details)
# 46
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R47.htm
# 2428417 - Disclosure - Income Taxes - Significant Components of Deferred Tax Assets and Liabilities (Details)
# Income Taxes - Significant Components of Deferred Tax Assets and Liabilities (Details)
# 47
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R48.htm
# 2429418 - Disclosure - Income Taxes - Aggregate Changes in Gross Unrecognized Tax Benefits (Details)
# Income Taxes - Aggregate Changes in Gross Unrecognized Tax Benefits (Details)
# 48
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R49.htm
# 2432419 - Disclosure - Leases - Additional Information (Details)
# Leases - Additional Information (Details)
# 49
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R50.htm
# 2433420 - Disclosure - Leases - ROU Assets and Lease Liabilities (Details)
# Leases - ROU Assets and Lease Liabilities (Details)
# 50
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R51.htm
# 2434421 - Disclosure - Leases - Lease Liability Maturities (Details)
# Leases - Lease Liability Maturities (Details)
# 51
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R52.htm
# 2437422 - Disclosure - Debt - Additional Information (Details)
# Debt - Additional Information (Details)
# 52
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R53.htm
# 2438423 - Disclosure - Debt - Summary of Cash Flows Associated with Commercial Paper (Details)
# Debt - Summary of Cash Flows Associated with Commercial Paper (Details)
# 53
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R54.htm
# 2439424 - Disclosure - Debt - Summary of Term Debt (Details)
# Debt - Summary of Term Debt (Details)
# 54
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R55.htm
# 2440425 - Disclosure - Debt - Future Principal Payments for Term Debt (Details)
# Debt - Future Principal Payments for Term Debt (Details)
# 55
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R56.htm
# 2443426 - Disclosure - Shareholders' Equity - Additional Information (Details)
# Shareholders' Equity - Additional Information (Details)
# 56
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R57.htm
# 2444427 - Disclosure - Shareholders' Equity - Shares of Common Stock (Details)
# Shareholders' Equity - Shares of Common Stock (Details)
# 57
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R58.htm
# 2447428 - Disclosure - Benefit Plans - Additional Information (Details)
# Benefit Plans - Additional Information (Details)
# 58
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R59.htm
# 2448429 - Disclosure - Benefit Plans - Restricted Stock Units Activity and Related Information (Details)
# Benefit Plans - Restricted Stock Units Activity and Related Information (Details)
# 59
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R60.htm
# 2449430 - Disclosure - Benefit Plans - Summary of Share-Based Compensation Expense and the Related Income Tax Benefit (Details)
# Benefit Plans - Summary of Share-Based Compensation Expense and the Related Income Tax Benefit (Details)
# 60
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R61.htm
# 2452431 - Disclosure - Commitments and Contingencies - Changes in Accrued Warranties and Related Costs (Details)
# Commitments and Contingencies - Changes in Accrued Warranties and Related Costs (Details)
# 61
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R62.htm
# 2453432 - Disclosure - Commitments and Contingencies - Future Payments Under Unconditional Purchase Obligations (Details)
# Commitments and Contingencies - Future Payments Under Unconditional Purchase Obligations (Details)
# 62
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R63.htm
# 2454433 - Disclosure - Commitments and Contingencies - Additional Information (Details)
# Commitments and Contingencies - Additional Information (Details)
# 63
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R64.htm
# 2457434 - Disclosure - Segment Information and Geographic Data - Information by Reportable Segment (Details)
# Segment Information and Geographic Data - Information by Reportable Segment (Details)
# 64
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R65.htm
# 2458435 - Disclosure - Segment Information and Geographic Data - Reconciliation of Segment Operating Income to the Consolidated Statements of Operations (Details)
# Segment Information and Geographic Data - Reconciliation of Segment Operating Income to the Consolidated Statements of Operations (Details)
# 65
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R66.htm
# 2459436 - Disclosure - Segment Information and Geographic Data - Net Sales (Details)
# Segment Information and Geographic Data - Net Sales (Details)
# 66
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R67.htm
# 2460437 - Disclosure - Segment Information and Geographic Data - Long-Lived Assets (Details)
# Segment Information and Geographic Data - Long-Lived Assets (Details)
# 67
# We encountered an error
# 1
# 1
# 0
# 1
# 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-9028960df86f> in <module>
# ----> 1 get_statements_data_from_filing_to_dataframes(master_list[0], user_agent)
#
# <ipython-input-38-2fac265234ac> in get_statements_data_from_filing_to_dataframes(filing, user_agent)
#       9     dataframes = []
#      10     for i in range(len(statements_data)):
# ---> 11         df = convert_statements_data_to_pandas(statements_data, i)
#      12         df = add_tags_for_sections(statements_data[i]['sections'], df)
#      13         df = add_tags_to_repeating_indices(df, '@')
#
# <ipython-input-64-5c1d1cf0d97b> in convert_statements_data_to_pandas(statements_data, statements_num)
#      73
#      74
# ---> 75     df.columns = header
#      76     df.index.name = document
#      77
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     668     def _set_axis(self, axis: int, labels: Index) -> None:
#     669         labels = ensure_index(labels)
# --> 670         self._mgr.set_axis(axis, labels)
#     671         self._clear_item_cache()
#     672
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     218
#     219         if new_len != old_len:
# --> 220             raise ValueError(
#     221                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     222                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 8 elements, new values have 1 elements

# %%
statements_dataframes = scrape_company_financial_statements(CIK_num, filing_type, start_year, num_years, user_agent)
statements_dataframes
# Out:
# We encountered an error
# 0
# title error
# We encountered an error
# 0
# title error
# We encountered an error
# 0
# title error
# 0
# We encountered an error
# 0
# title error
# We encountered an error
# 0
# title error
# We encountered an error
# 0
# title error
# We encountered an error
# 0
# title error
# We encountered an error
# 0
# title error
# [[                                                    Sep. 25, 2021
#   CONSOLIDATED STATEMENTS OF OPERATIONS - USD ($)...
#   Net sales-0                                              365817.0
#   Cost of sales-0                                          212981.0
#   Gross margin-0                                           152836.0
#   OPERATING EXPENSES:-1                                         NaN
#   Research and development-1                                21914.0
#   Selling, general and administrative-1                     21973.0
#   Total operating expenses-1                                43887.0
#   Operating income-1                                       108949.0
#   Other income/(expense), net-1                               258.0
#   Income before provision for income taxes-1               109207.0
#   Provision for income taxes-1                              14527.0
#   Net income-1                                              94680.0
#   EARNINGS PER SHARE:-2                                         NaN
#   Basic (in dollars per share)-2                              567.0
#   Diluted (in dollars per share)-2                            561.0
#   SHARES USED IN COMPUTING EARNINGS PER SHARE:-3                NaN
#   Basic (in shares)-3                                    16701272.0
#   Diluted (in shares)-3                                  16864919.0
#   Products-3                                                    NaN
#   Net sales-3                                              297392.0
#   Cost of sales-3                                          192266.0
#   Services-3                                                    NaN
#   Net sales-3@                                              68425.0
#   Cost of sales-3@                                          20715.0,
#                                                       Sep. 25, 2021
#   CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME...
#   STATEMENT OF COMPREHENSIVE INCOME [ABSTRACT]-1                NaN
#   Net income-1                                              94680.0
#   OTHER COMPREHENSIVE INCOME/(LOSS):-2                          NaN
#   Change in foreign currency translation, net of ...          501.0
#   CHANGE IN UNREALIZED GAINS/LOSSES ON DERIVATIVE...            NaN
#   Change in fair value of derivative instruments-3             32.0
#   Change in fair value of derivative instruments-3@             NaN
#   Adjustment for net (gains)/losses realized and ...         1003.0
#   Adjustment for net (gains)/losses realized and ...            NaN
#   Total change in unrealized gains/losses on deri...         1035.0
#   Total change in unrealized gains/losses on deri...            NaN
#   CHANGE IN UNREALIZED GAINS/LOSSES ON MARKETABLE...            NaN
#   Change in fair value of marketable debt securit...         -694.0
#   Adjustment for net (gains)/losses realized and ...         -273.0
#   Total change in unrealized gains/losses on mark...         -967.0
#   Total other comprehensive income/(loss)-4                   569.0
#   Total comprehensive income-4                              95249.0,
#                                                       Sep. 25, 2021
#   CONSOLIDATED BALANCE SHEETS - USD ($) $ in Mill...
#   CURRENT ASSETS:-1                                             NaN
#   Cash and cash equivalents-1                               34940.0
#   Marketable securities-1                                   27699.0
#   Accounts receivable, net-1                                26278.0
#   Inventories-1                                              6580.0
#   Vendor non-trade receivables-1                            25228.0
#   Other current assets-1                                    14111.0
#   Total current assets-1                                   134836.0
#   NON-CURRENT ASSETS:-2                                         NaN
#   Marketable securities-2                                  127877.0
#   Property, plant and equipment, net-2                      39440.0
#   Other non-current assets-2                                48849.0
#   Total non-current assets-2                               216166.0
#   Total assets-2                                           351002.0
#   CURRENT LIABILITIES:-3                                        NaN
#   Accounts payable-3                                        54763.0
#   Other current liabilities-3                               47493.0
#   Deferred revenue-3                                         7612.0
#   Commercial paper-3                                         6000.0
#   Term debt-3                                                9613.0
#   Total current liabilities-3                              125481.0
#   NON-CURRENT LIABILITIES:-4                                    NaN
#   Term debt-4                                              109106.0
#   Other non-current liabilities-4                           53325.0
#   Total non-current liabilities-4                          162431.0
#   Total liabilities-4                                      287912.0
#   Commitments and contingencies-4                               NaN
#   SHAREHOLDERS’ EQUITY:-5                                       NaN
#   Common stock and additional paid-in capital, $0...        57365.0
#   Retained earnings-5                                        5562.0
#   Accumulated other comprehensive income/(loss)-5             163.0
#   Total shareholders’ equity-5                              63090.0
#   Total liabilities and shareholders’ equity-5             351002.0,
#                                                       Sep. 25, 2021
#   CONSOLIDATED STATEMENTS OF CASH FLOWS - USD ($)...
#   STATEMENT OF CASH FLOWS [ABSTRACT]-1                          NaN
#   Cash, cash equivalents and restricted cash, beg...        39789.0
#   OPERATING ACTIVITIES:-2                                       NaN
#   Net income-2                                              94680.0
#   ADJUSTMENTS TO RECONCILE NET INCOME TO CASH GEN...            NaN
#   Depreciation and amortization-3                           11284.0
#   Share-based compensation expense-3                         7906.0
#   Deferred income tax benefit-3                             -4774.0
#   Other-3                                                    -147.0
#   CHANGES IN OPERATING ASSETS AND LIABILITIES:-4                NaN
#   Accounts receivable, net-4                               -10125.0
#   Inventories-4                                             -2642.0
#   Vendor non-trade receivables-4                            -3903.0
#   Other current and non-current assets-4                    -8042.0
#   Accounts payable-4                                        12326.0
#   Deferred revenue-4                                         1676.0
#   Other current and non-current liabilities-4                5799.0
#   Cash generated by operating activities-4                 104038.0
#   INVESTING ACTIVITIES:-5                                       NaN
#   Purchases of marketable securities-5                    -109558.0
#   Proceeds from maturities of marketable securiti...        59023.0
#   Proceeds from sales of marketable securities-5            47460.0
#   Payments for acquisition of property, plant and...       -11085.0
#   Payments made in connection with business acqui...          -33.0
#   Purchases of non-marketable securities-5                   -131.0
#   Proceeds from non-marketable securities-5                   387.0
#   Other-5                                                    -608.0
#   Cash generated by/(used in) investing activities-5       -14545.0
#   FINANCING ACTIVITIES:-6                                       NaN
#   Proceeds from issuance of common stock-6                   1105.0
#   Payments for taxes related to net share settlem...        -6556.0
#   Payments for dividends and dividend equivalents-6        -14467.0
#   Repurchases of common stock-6                            -85971.0
#   Proceeds from issuance of term debt, net-6                20393.0
#   Repayments of term debt-6                                 -8750.0
#   Proceeds from/(Repayments of) commercial paper,...         1022.0
#   Other-6                                                    -129.0
#   Cash used in financing activities-6                      -93353.0
#   Increase/(Decrease) in cash, cash equivalents a...        -3860.0
#   Cash, cash equivalents and restricted cash, end...        35929.0
#   SUPPLEMENTAL CASH FLOW DISCLOSURE:-7                          NaN
#   Cash paid for income taxes, net-7                         25385.0
#   Cash paid for interest-7                                   2687.0,
#   Empty DataFrame
#   Columns: []
#   Index: []],
#  [                                                    Sep. 26, 2020
#   CONSOLIDATED STATEMENTS OF OPERATIONS - USD ($)...
#   Net sales-0                                              274515.0
#   Cost of sales-0                                          169559.0
#   Gross margin-0                                           104956.0
#   OPERATING EXPENSES:-1                                         NaN
#   Research and development-1                                18752.0
#   Selling, general and administrative-1                     19916.0
#   Total operating expenses-1                                38668.0
#   Operating income-1                                        66288.0
#   Other income/(expense), net-1                               803.0
#   Income before provision for income taxes-1                67091.0
#   Provision for income taxes-1                               9680.0
#   Net income-1                                              57411.0
#   EARNINGS PER SHARE:-2                                         NaN
#   Basic (in dollars per share)-2                              331.0
#   Diluted (in dollars per share)-2                            328.0
#   SHARES USED IN COMPUTING EARNINGS PER SHARE:-3                NaN
#   Basic (in shares)-3                                    17352119.0
#   Diluted (in shares)-3                                  17528214.0
#   Products-3                                                    NaN
#   Net sales-3                                              220747.0
#   Cost of sales-3                                          151286.0
#   Services-3                                                    NaN
#   Net sales-3@                                              53768.0
#   Cost of sales-3@                                          18273.0,
#                                                       Sep. 26, 2020
#   CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME...
#   STATEMENT OF COMPREHENSIVE INCOME [ABSTRACT]-1                NaN
#   Net income-1                                              57411.0
#   OTHER COMPREHENSIVE INCOME/(LOSS):-2                          NaN
#   Change in foreign currency translation, net of ...           88.0
#   CHANGE IN UNREALIZED GAINS/LOSSES ON DERIVATIVE...            NaN
#   Change in fair value of derivatives-3                        79.0
#   Change in fair value of derivatives-3@                        NaN
#   Adjustment for net (gains)/losses realized and ...        -1264.0
#   Adjustment for net (gains)/losses realized and ...            NaN
#   Total change in unrealized gains/losses on deri...        -1185.0
#   Total change in unrealized gains/losses on deri...            NaN
#   CHANGE IN UNREALIZED GAINS/LOSSES ON MARKETABLE...            NaN
#   Change in fair value of marketable debt securit...         1202.0
#   Adjustment for net (gains)/losses realized and ...          -63.0
#   Total change in unrealized gains/losses on mark...         1139.0
#   Total other comprehensive income/(loss)-4                    42.0
#   Total comprehensive income-4                              57453.0,
#                                                       Sep. 26, 2020
#   CONSOLIDATED BALANCE SHEETS - USD ($) $ in Mill...
#   CURRENT ASSETS:-1                                             NaN
#   Cash and cash equivalents-1                               38016.0
#   Marketable securities-1                                   52927.0
#   Accounts receivable, net-1                                16120.0
#   Inventories-1                                              4061.0
#   Vendor non-trade receivables-1                            21325.0
#   Other current assets-1                                    11264.0
#   Total current assets-1                                   143713.0
#   NON-CURRENT ASSETS:-2                                         NaN
#   Marketable securities-2                                  100887.0
#   Property, plant and equipment, net-2                      36766.0
#   Other non-current assets-2                                42522.0
#   Total non-current assets-2                               180175.0
#   Total assets-2                                           323888.0
#   CURRENT LIABILITIES:-3                                        NaN
#   Accounts payable-3                                        42296.0
#   Other current liabilities-3                               42684.0
#   Deferred revenue-3                                         6643.0
#   Commercial paper-3                                         4996.0
#   Term debt-3                                                8773.0
#   Total current liabilities-3                              105392.0
#   NON-CURRENT LIABILITIES:-4                                    NaN
#   Term debt-4                                               98667.0
#   Other non-current liabilities-4                           54490.0
#   Total non-current liabilities-4                          153157.0
#   Total liabilities-4                                      258549.0
#   Commitments and contingencies-4                               NaN
#   SHAREHOLDERS’ EQUITY:-5                                       NaN
#   Common stock and additional paid-in capital, $0...        50779.0
#   Retained earnings-5                                       14966.0
#   Accumulated other comprehensive income/(loss)-5            -406.0
#   Total shareholders’ equity-5                              65339.0
#   Total liabilities and shareholders’ equity-5             323888.0,
#                                                       Sep. 26, 2020
#   CONSOLIDATED STATEMENTS OF CASH FLOWS - USD ($)...
#   STATEMENT OF CASH FLOWS [ABSTRACT]-1                          NaN
#   Cash, cash equivalents and restricted cash, beg...        50224.0
#   OPERATING ACTIVITIES:-2                                       NaN
#   Net income-2                                              57411.0
#   ADJUSTMENTS TO RECONCILE NET INCOME TO CASH GEN...            NaN
#   Depreciation and amortization-3                           11056.0
#   Share-based compensation expense-3                         6829.0
#   Deferred income tax benefit-3                              -215.0
#   Other-3                                                     -97.0
#   CHANGES IN OPERATING ASSETS AND LIABILITIES:-4                NaN
#   Accounts receivable, net-4                                 6917.0
#   Inventories-4                                              -127.0
#   Vendor non-trade receivables-4                             1553.0
#   Other current and non-current assets-4                    -9588.0
#   Accounts payable-4                                        -4062.0
#   Deferred revenue-4                                         2081.0
#   Other current and non-current liabilities-4                8916.0
#   Cash generated by operating activities-4                  80674.0
#   INVESTING ACTIVITIES:-5                                       NaN
#   Purchases of marketable securities-5                    -114938.0
#   Proceeds from maturities of marketable securiti...        69918.0
#   Proceeds from sales of marketable securities-5            50473.0
#   Payments for acquisition of property, plant and...        -7309.0
#   Payments made in connection with business acqui...        -1524.0
#   Purchases of non-marketable securities-5                   -210.0
#   Proceeds from non-marketable securities-5                    92.0
#   Other-5                                                    -791.0
#   Cash generated by/(used in) investing activities-5        -4289.0
#   FINANCING ACTIVITIES:-6                                       NaN
#   Proceeds from issuance of common stock-6                    880.0
#   Payments for taxes related to net share settlem...        -3634.0
#   Payments for dividends and dividend equivalents-6        -14081.0
#   Repurchases of common stock-6                            -72358.0
#   Proceeds from issuance of term debt, net-6                16091.0
#   Repayments of term debt-6                                -12629.0
#   Repayments of commercial paper, net-6                      -963.0
#   Other-6                                                    -126.0
#   Cash used in financing activities-6                      -86820.0
#   Increase/(Decrease) in cash, cash equivalents a...       -10435.0
#   Cash, cash equivalents and restricted cash, end...        39789.0
#   SUPPLEMENTAL CASH FLOW DISCLOSURE:-7                          NaN
#   Cash paid for income taxes, net-7                          9501.0
#   Cash paid for interest-7                                   3002.0,
#   Empty DataFrame
#   Columns: []
#   Index: []],
#  [                                                    Sep. 28, 2019
#   CONSOLIDATED STATEMENTS OF OPERATIONS - USD ($)...
#   Net sales-0                                              260174.0
#   Cost of sales-0                                          161782.0
#   Gross margin-0                                            98392.0
#   OPERATING EXPENSES:-1                                         NaN
#   Research and development-1                                16217.0
#   Selling, general and administrative-1                     18245.0
#   Total operating expenses-1                                34462.0
#   Operating income-1                                        63930.0
#   Other income/(expense), net-1                              1807.0
#   Income before provision for income taxes-1                65737.0
#   Provision for income taxes-1                              10481.0
#   Net income-1                                              55256.0
#   EARNINGS PER SHARE:-2                                         NaN
#   Basic (in dollars per share)-2                             1197.0
#   Diluted (in dollars per share)-2                           1189.0
#   SHARES USED IN COMPUTING EARNINGS PER SHARE:-3                NaN
#   Basic (in shares)-3                                     4617834.0
#   Diluted (in shares)-3                                   4648913.0
#   Products-3                                                    NaN
#   Net sales-3                                              213883.0
#   Cost of sales-3                                          144996.0
#   Services-3                                                    NaN
#   Net sales-3@                                              46291.0
#   Cost of sales-3@                                          16786.0,
#                                                       Sep. 28, 2019
#   CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME...
#   STATEMENT OF COMPREHENSIVE INCOME [ABSTRACT]-1                NaN
#   Net income-1                                              55256.0
#   OTHER COMPREHENSIVE INCOME/(LOSS):-2                          NaN
#   Change in foreign currency translation, net of ...         -408.0
#   CHANGE IN UNREALIZED GAINS/LOSSES ON DERIVATIVE...            NaN
#   Change in fair value of derivatives-3                      -661.0
#   Adjustment for net (gains)/losses realized and ...           23.0
#   Total change in unrealized gains/losses on deri...         -638.0
#   CHANGE IN UNREALIZED GAINS/LOSSES ON MARKETABLE...            NaN
#   Change in fair value of marketable securities-4            3802.0
#   Adjustment for net (gains)/losses realized and ...           25.0
#   Total change in unrealized gains/losses on mark...         3827.0
#   Total other comprehensive income/(loss)-4                  2781.0
#   Total comprehensive income-4                              58037.0,
#                                                       Sep. 28, 2019
#   CONSOLIDATED BALANCE SHEETS - USD ($) $ in Mill...
#   CURRENT ASSETS:-1                                             NaN
#   Cash and cash equivalents-1                               48844.0
#   Marketable securities-1                                   51713.0
#   Accounts receivable, net-1                                22926.0
#   Inventories-1                                              4106.0
#   Vendor non-trade receivables-1                            22878.0
#   Other current assets-1                                    12352.0
#   Total current assets-1                                   162819.0
#   NON-CURRENT ASSETS:-2                                         NaN
#   Marketable securities-2                                  105341.0
#   Property, plant and equipment, net-2                      37378.0
#   Other non-current assets-2                                32978.0
#   Total non-current assets-2                               175697.0
#   Total assets-2                                           338516.0
#   CURRENT LIABILITIES:-3                                        NaN
#   Accounts payable-3                                        46236.0
#   Other current liabilities-3                               37720.0
#   Deferred revenue-3                                         5522.0
#   Commercial paper-3                                         5980.0
#   Term debt-3                                               10260.0
#   Total current liabilities-3                              105718.0
#   NON-CURRENT LIABILITIES:-4                                    NaN
#   Term debt-4                                               91807.0
#   Other non-current liabilities-4                           50503.0
#   Total non-current liabilities-4                          142310.0
#   Total liabilities-4                                      248028.0
#   Commitments and contingencies-4                               NaN
#   SHAREHOLDERS’ EQUITY:-5                                       NaN
#   Common stock and additional paid-in capital, $0...        45174.0
#   Retained earnings-5                                       45898.0
#   Accumulated other comprehensive income/(loss)-5            -584.0
#   Total shareholders’ equity-5                              90488.0
#   Total liabilities and shareholders’ equity-5             338516.0,
#                                                       Sep. 28, 2019
#   CONSOLIDATED STATEMENTS OF CASH FLOWS - USD ($)...
#   STATEMENT OF CASH FLOWS [ABSTRACT]-1                          NaN
#   Cash, cash equivalents and restricted cash, beg...        25913.0
#   OPERATING ACTIVITIES:-2                                       NaN
#   Net income-2                                              55256.0
#   ADJUSTMENTS TO RECONCILE NET INCOME TO CASH GEN...            NaN
#   Depreciation and amortization-3                           12547.0
#   Share-based compensation expense-3                         6068.0
#   Deferred income tax expense/(benefit)-3                    -340.0
#   Other-3                                                    -652.0
#   CHANGES IN OPERATING ASSETS AND LIABILITIES:-4                NaN
#   Accounts receivable, net-4                                  245.0
#   Inventories-4                                              -289.0
#   Vendor non-trade receivables-4                             2931.0
#   Other current and non-current assets-4                      873.0
#   Accounts payable-4                                        -1923.0
#   Deferred revenue-4                                         -625.0
#   Other current and non-current liabilities-4               -4700.0
#   Cash generated by operating activities-4                  69391.0
#   INVESTING ACTIVITIES:-5                                       NaN
#   Purchases of marketable securities-5                     -39630.0
#   Proceeds from maturities of marketable securiti...        40102.0
#   Proceeds from sales of marketable securities-5            56988.0
#   Payments for acquisition of property, plant and...       -10495.0
#   Payments made in connection with business acqui...         -624.0
#   Purchases of non-marketable securities-5                  -1001.0
#   Proceeds from non-marketable securities-5                  1634.0
#   Other-5                                                   -1078.0
#   Cash generated by/(used in) investing activities-5        45896.0
#   FINANCING ACTIVITIES:-6                                       NaN
#   Proceeds from issuance of common stock-6                    781.0
#   Payments for taxes related to net share settlem...        -2817.0
#   Payments for dividends and dividend equivalents-6         14119.0
#   Repurchases of common stock-6                            -66897.0
#   Proceeds from issuance of term debt, net-6                 6963.0
#   Repayments of term debt-6                                 -8805.0
#   Proceeds from/(Repayments of) commercial paper,...        -5977.0
#   Other-6                                                    -105.0
#   Cash used in financing activities-6                      -90976.0
#   Increase/(Decrease) in cash, cash equivalents a...        24311.0
#   Cash, cash equivalents and restricted cash, end...        50224.0
#   SUPPLEMENTAL CASH FLOW DISCLOSURE:-7                          NaN
#   Cash paid for income taxes, net-7                         15263.0
#   Cash paid for interest-7                                   3423.0,
#   Empty DataFrame
#   Columns: []
#   Index: []],
#  [                                                    Sep. 29, 2018
#   CONSOLIDATED STATEMENTS OF OPERATIONS - USD ($)...
#   INCOME STATEMENT [ABSTRACT]-1                                 NaN
#   Net sales-1                                              265595.0
#   Cost of sales-1                                          163756.0
#   Gross margin-1                                           101839.0
#   OPERATING EXPENSES:-2                                         NaN
#   Research and development-2                                14236.0
#   Selling, general and administrative-2                     16705.0
#   Total operating expenses-2                                30941.0
#   Operating income-2                                        70898.0
#   Other income/(expense), net-2                              2005.0
#   Income before provision for income taxes-2                72903.0
#   Provision for income taxes-2                              13372.0
#   Net income-2                                              59531.0
#   EARNINGS PER SHARE:-3                                         NaN
#   Basic (in dollars per share)-3                             1201.0
#   Diluted (in dollars per share)-3                           1191.0
#   SHARES USED IN COMPUTING EARNINGS PER SHARE:-4                NaN
#   Basic (in shares)-4                                     4955377.0
#   Diluted (in shares)-4                                   5000109.0,
#                                                       Sep. 29, 2018
#   CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME...
#   STATEMENT OF COMPREHENSIVE INCOME [ABSTRACT]-1                NaN
#   Net income-1                                              59531.0
#   OTHER COMPREHENSIVE INCOME/(LOSS):-2                          NaN
#   Change in foreign currency translation, net of ...         -525.0
#   CHANGE IN UNREALIZED GAINS/LOSSES ON DERIVATIVE...            NaN
#   Change in fair value of derivatives, net of tax...          523.0
#   Adjustment for net (gains)/losses realized and ...          382.0
#   Total change in unrealized gains/losses on deri...          905.0
#   CHANGE IN UNREALIZED GAINS/LOSSES ON MARKETABLE...            NaN
#   Change in fair value of marketable securities, ...        -3407.0
#   Adjustment for net (gains)/losses realized and ...            1.0
#   Total change in unrealized gains/losses on mark...        -3406.0
#   Total other comprehensive income/(loss)-4                 -3026.0
#   Total comprehensive income-4                              56505.0,
#                                                       Sep. 29, 2018
#   CONSOLIDATED BALANCE SHEETS - USD ($) $ in Mill...
#   CURRENT ASSETS:-1                                             NaN
#   Cash and cash equivalents-1                               25913.0
#   Marketable securities-1                                   40388.0
#   Accounts receivable, net-1                                23186.0
#   Inventories-1                                              3956.0
#   Vendor non-trade receivables-1                            25809.0
#   Other current assets-1                                    12087.0
#   Total current assets-1                                   131339.0
#   NON-CURRENT ASSETS:-2                                         NaN
#   Marketable securities-2                                  170799.0
#   Property, plant and equipment, net-2                      41304.0
#   Other non-current assets-2                                22283.0
#   Total non-current assets-2                               234386.0
#   Total assets-2                                           365725.0
#   CURRENT LIABILITIES:-3                                        NaN
#   Accounts payable-3                                        55888.0
#   Other current liabilities-3                               32687.0
#   Deferred revenue-3                                         7543.0
#   Commercial paper-3                                        11964.0
#   Term debt-3                                                8784.0
#   Total current liabilities-3                              116866.0
#   NON-CURRENT LIABILITIES:-4                                    NaN
#   Deferred revenue-4                                         2797.0
#   Term debt-4                                               93735.0
#   Other non-current liabilities-4                           45180.0
#   Total non-current liabilities-4                          141712.0
#   Total liabilities-4                                      258578.0
#   Commitments and contingencies-4                               NaN
#   SHAREHOLDERS’ EQUITY:-5                                       NaN
#   Common stock and additional paid-in capital, $0...        40201.0
#   Retained earnings-5                                       70400.0
#   Accumulated other comprehensive income/(loss)-5           -3454.0
#   Total shareholders’ equity-5                             107147.0
#   Total liabilities and shareholders’ equity-5             365725.0,
#                                                       Sep. 29, 2018
#   CONSOLIDATED STATEMENTS OF CASH FLOWS - USD ($)...
#   STATEMENT OF CASH FLOWS [ABSTRACT]-1                          NaN
#   Cash and cash equivalents, beginning of the year-1        20289.0
#   OPERATING ACTIVITIES:-2                                       NaN
#   Net income-2                                              59531.0
#   ADJUSTMENTS TO RECONCILE NET INCOME TO CASH GEN...            NaN
#   Depreciation and amortization-3                           10903.0
#   Share-based compensation expense-3                         5340.0
#   Deferred income tax expense/(benefit)-3                  -32590.0
#   Other-3                                                    -444.0
#   CHANGES IN OPERATING ASSETS AND LIABILITIES:-4                NaN
#   Accounts receivable, net-4                                -5322.0
#   Inventories-4                                               828.0
#   Vendor non-trade receivables-4                            -8010.0
#   Other current and non-current assets-4                     -423.0
#   Accounts payable-4                                         9175.0
#   Deferred revenue-4                                          -44.0
#   Other current and non-current liabilities-4               38490.0
#   Cash generated by operating activities-4                  77434.0
#   INVESTING ACTIVITIES:-5                                       NaN
#   Purchases of marketable securities-5                     -71356.0
#   Proceeds from maturities of marketable securiti...        55881.0
#   Proceeds from sales of marketable securities-5            47838.0
#   Payments for acquisition of property, plant and...       -13313.0
#   Payments made in connection with business acqui...         -721.0
#   Purchases of non-marketable securities-5                  -1871.0
#   Proceeds from non-marketable securities-5                   353.0
#   Other-5                                                    -745.0
#   Cash generated by/(used in) investing activities-5        16066.0
#   FINANCING ACTIVITIES:-6                                       NaN
#   Proceeds from issuance of common stock-6                    669.0
#   Payments for taxes related to net share settlem...        -2527.0
#   Payments for dividends and dividend equivalents-6         13712.0
#   Repurchases of common stock-6                            -72738.0
#   Proceeds from issuance of term debt, net-6                 6969.0
#   Repayments of term debt-6                                 -6500.0
#   Change in commercial paper, net-6                           -37.0
#   Cash used in financing activities-6                      -87876.0
#   Increase/(Decrease) in cash and cash equivalents-6         5624.0
#   Cash and cash equivalents, end of the year-6              25913.0
#   SUPPLEMENTAL CASH FLOW DISCLOSURE:-7                          NaN
#   Cash paid for income taxes, net-7                         10417.0
#   Cash paid for interest-7                                   3022.0],
#  [                                                    Sep. 30, 2017
#   CONSOLIDATED STATEMENTS OF OPERATIONS - USD ($)...
#   INCOME STATEMENT [ABSTRACT]-1                                 NaN
#   Net sales-1                                              229234.0
#   Cost of sales-1                                          141048.0
#   Gross margin-1                                            88186.0
#   OPERATING EXPENSES:-2                                         NaN
#   Research and development-2                                11581.0
#   Selling, general and administrative-2                     15261.0
#   Total operating expenses-2                                26842.0
#   Operating income-2                                        61344.0
#   Other income/(expense), net-2                              2745.0
#   Income before provision for income taxes-2                64089.0
#   Provision for income taxes-2                              15738.0
#   Net income-2                                              48351.0
#   EARNINGS PER SHARE:-3                                         NaN
#   Basic (in dollars per share)-3                              927.0
#   Diluted (in dollars per share)-3                            921.0
#   SHARES USED IN COMPUTING EARNINGS PER SHARE:-4                NaN
#   Basic (in shares)-4                                     5217242.0
#   Diluted (in shares)-4                                   5251692.0
#   Cash dividends declared per share (in dollars p...           24.0,
#                                                       Sep. 30, 2017
#   CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME...
#   STATEMENT OF COMPREHENSIVE INCOME [ABSTRACT]-1                NaN
#   Net income-1                                              48351.0
#   OTHER COMPREHENSIVE INCOME/(LOSS):-2                          NaN
#   Change in foreign currency translation, net of ...          224.0
#   CHANGE IN UNREALIZED GAINS/LOSSES ON DERIVATIVE...            NaN
#   Change in fair value of derivatives, net of tax...         1315.0
#   Adjustment for net (gains)/losses realized and ...        -1477.0
#   Total change in unrealized gains/losses on deri...         -162.0
#   CHANGE IN UNREALIZED GAINS/LOSSES ON MARKETABLE...            NaN
#   Change in fair value of marketable securities, ...         -782.0
#   Adjustment for net (gains)/losses realized and ...          -64.0
#   Total change in unrealized gains/losses on mark...         -846.0
#   Total other comprehensive income/(loss)-4                  -784.0
#   Total comprehensive income-4                              47567.0,
#                                                       Sep. 30, 2017
#   CONSOLIDATED BALANCE SHEETS - USD ($) $ in Mill...
#   CURRENT ASSETS:-1                                             NaN
#   Cash and cash equivalents-1                               20289.0
#   Short-term marketable securities-1                        53892.0
#   Accounts receivable, less allowances of $58 and...        17874.0
#   Inventories-1                                              4855.0
#   Vendor non-trade receivables-1                            17799.0
#   Other current assets-1                                    13936.0
#   Total current assets-1                                   128645.0
#   Long-term marketable securities-1                        194714.0
#   Property, plant and equipment, net-1                      33783.0
#   Goodwill-1                                                 5717.0
#   Acquired intangible assets, net-1                          2298.0
#   Other non-current assets-1                                10162.0
#   Total assets-1                                           375319.0
#   CURRENT LIABILITIES:-2                                        NaN
#   Accounts payable-2                                        49049.0
#   Accrued expenses-2                                        25744.0
#   Deferred revenue-2                                         7548.0
#   Commercial paper-2                                        11977.0
#   Current portion of long-term debt-2                        6496.0
#   Total current liabilities-2                              100814.0
#   Deferred revenue, non-current-2                            2836.0
#   Long-term debt-2                                          97207.0
#   Other non-current liabilities-2                           40415.0
#   Total liabilities-2                                      241272.0
#   Commitments and contingencies-2                               NaN
#   SHAREHOLDERS’ EQUITY:-3                                       NaN
#   Common stock and additional paid-in capital, $0...        35867.0
#   Retained earnings-3                                       98330.0
#   Accumulated other comprehensive income/(loss)-3            -150.0
#   Total shareholders’ equity-3                             134047.0
#   Total liabilities and shareholders’ equity-3             375319.0,
#                                                       Sep. 30, 2017
#   CONSOLIDATED STATEMENTS OF CASH FLOWS - USD ($)...
#   STATEMENT OF CASH FLOWS [ABSTRACT]-1                          NaN
#   Cash and cash equivalents, beginning of the year-1        20484.0
#   OPERATING ACTIVITIES:-2                                       NaN
#   Net income-2                                              48351.0
#   ADJUSTMENTS TO RECONCILE NET INCOME TO CASH GEN...            NaN
#   Depreciation and amortization-3                           10157.0
#   Share-based compensation expense-3                         4840.0
#   Deferred income tax expense-3                              5966.0
#   Other-3                                                    -166.0
#   CHANGES IN OPERATING ASSETS AND LIABILITIES:-4                NaN
#   Accounts receivable, net-4                                -2093.0
#   Inventories-4                                             -2723.0
#   Vendor non-trade receivables-4                            -4254.0
#   Other current and non-current assets-4                    -5318.0
#   Accounts payable-4                                         9618.0
#   Deferred revenue-4                                         -626.0
#   Other current and non-current liabilities-4                -154.0
#   Cash generated by operating activities-4                  63598.0
#   INVESTING ACTIVITIES:-5                                       NaN
#   Purchases of marketable securities-5                    -159486.0
#   Proceeds from maturities of marketable securiti...        31775.0
#   Proceeds from sales of marketable securities-5            94564.0
#   Payments made in connection with business acqui...         -329.0
#   Payments for acquisition of property, plant and...       -12451.0
#   Payments for acquisition of intangible assets-5            -344.0
#   Payments for strategic investments, net-5                  -395.0
#   Other-5                                                     220.0
#   Cash used in investing activities-5                      -46446.0
#   FINANCING ACTIVITIES:-6                                       NaN
#   Proceeds from issuance of common stock-6                    555.0
#   Excess tax benefits from equity awards-6                    627.0
#   Payments for taxes related to net share settlem...        -1874.0
#   Payments for dividends and dividend equivalents-6         12769.0
#   Repurchases of common stock-6                            -32900.0
#   Proceeds from issuance of term debt, net-6                28662.0
#   Repayments of term debt-6                                 -3500.0
#   Change in commercial paper, net-6                          3852.0
#   Cash used in financing activities-6                      -17347.0
#   Increase/(Decrease) in cash and cash equivalents-6         -195.0
#   Cash and cash equivalents, end of the year-6              20289.0
#   SUPPLEMENTAL CASH FLOW DISCLOSURE:-7                          NaN
#   Cash paid for income taxes, net-7                         11591.0
#   Cash paid for interest-7                                   2092.0,
#   Empty DataFrame
#   Columns: []
#   Index: []],
#  [                                                    Sep. 24, 2016
#   CONSOLIDATED STATEMENTS OF OPERATIONS - USD ($)...
#   INCOME STATEMENT [ABSTRACT]-1                                 NaN
#   Net sales-1                                              215639.0
#   Cost of sales-1                                          131376.0
#   Gross margin-1                                            84263.0
#   OPERATING EXPENSES:-2                                         NaN
#   Research and development-2                                10045.0
#   Selling, general and administrative-2                     14194.0
#   Total operating expenses-2                                24239.0
#   Operating income-2                                        60024.0
#   Other income/(expense), net-2                              1348.0
#   Income before provision for income taxes-2                61372.0
#   Provision for income taxes-2                              15685.0
#   Net income-2                                              45687.0
#   EARNINGS PER SHARE:-3                                         NaN
#   Basic (in dollars per share)-3                              835.0
#   Diluted (in dollars per share)-3                            831.0
#   SHARES USED IN COMPUTING EARNINGS PER SHARE:-4                NaN
#   Basic (in shares)-4                                     5470820.0
#   Diluted (in shares)-4                                   5500281.0
#   Cash dividends declared per share (in dollars p...          218.0,
#                                                       Sep. 24, 2016
#   CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME...
#   STATEMENT OF COMPREHENSIVE INCOME [ABSTRACT]-1                NaN
#   Net income-1                                              45687.0
#   OTHER COMPREHENSIVE INCOME/(LOSS):-2                          NaN
#   Change in foreign currency translation, net of ...           75.0
#   CHANGE IN UNREALIZED GAINS/LOSSES ON DERIVATIVE...            NaN
#   Change in fair value of derivatives, net of tax...            7.0
#   Adjustment for net (gains)/losses realized and ...         -741.0
#   Total change in unrealized gains/losses on deri...         -734.0
#   CHANGE IN UNREALIZED GAINS/LOSSES ON MARKETABLE...            NaN
#   Change in fair value of marketable securities, ...         1582.0
#   Adjustment for net (gains)/losses realized and ...           56.0
#   Total change in unrealized gains/losses on mark...         1638.0
#   Total other comprehensive income/(loss)-4                   979.0
#   Total comprehensive income-4                              46666.0,
#                                                       Sep. 24, 2016
#   CONSOLIDATED BALANCE SHEETS - USD ($) $ in Mill...
#   CURRENT ASSETS:-1                                             NaN
#   Cash and cash equivalents-1                               20484.0
#   Short-term marketable securities-1                        46671.0
#   Accounts receivable, less allowances of $53 and...        15754.0
#   Inventories-1                                              2132.0
#   Vendor non-trade receivables-1                            13545.0
#   Other current assets-1                                     8283.0
#   Total current assets-1                                   106869.0
#   Long-term marketable securities-1                        170430.0
#   Property, plant and equipment, net-1                      27010.0
#   Goodwill-1                                                 5414.0
#   Acquired intangible assets, net-1                          3206.0
#   Other non-current assets-1                                 8757.0
#   Total assets-1                                           321686.0
#   CURRENT LIABILITIES:-2                                        NaN
#   Accounts payable-2                                        37294.0
#   Accrued expenses-2                                        22027.0
#   Deferred revenue-2                                         8080.0
#   Commercial paper-2                                         8105.0
#   Current portion of long-term debt-2                        3500.0
#   Total current liabilities-2                               79006.0
#   Deferred revenue, non-current-2                            2930.0
#   Long-term debt-2                                          75427.0
#   Other non-current liabilities-2                           36074.0
#   Total liabilities-2                                      193437.0
#   Commitments and contingencies-2                               NaN
#   SHAREHOLDERS’ EQUITY:-3                                       NaN
#   Common stock and additional paid-in capital, $0...        31251.0
#   Retained earnings-3                                       96364.0
#   Accumulated other comprehensive income/(loss)-3             634.0
#   Total shareholders’ equity-3                             128249.0
#   Total liabilities and shareholders’ equity-3             321686.0,
#                                                       Sep. 24, 2016
#   CONSOLIDATED STATEMENTS OF CASH FLOWS - USD ($)...
#   STATEMENT OF CASH FLOWS [ABSTRACT]-1                          NaN
#   Cash and cash equivalents, beginning of the year-1        21120.0
#   OPERATING ACTIVITIES:-2                                       NaN
#   Net income-2                                              45687.0
#   ADJUSTMENTS TO RECONCILE NET INCOME TO CASH GEN...            NaN
#   Depreciation and amortization-3                           10505.0
#   Share-based compensation expense-3                         4210.0
#   Deferred income tax expense-3                              4938.0
#   CHANGES IN OPERATING ASSETS AND LIABILITIES:-4                NaN
#   Accounts receivable, net-4                                 1095.0
#   Inventories-4                                               217.0
#   Vendor non-trade receivables-4                              -51.0
#   Other current and non-current assets-4                     1090.0
#   Accounts payable-4                                         1791.0
#   Deferred revenue-4                                        -1554.0
#   Other current and non-current liabilities-4               -2104.0
#   Cash generated by operating activities-4                  65824.0
#   INVESTING ACTIVITIES:-5                                       NaN
# ...
#   FINANCING ACTIVITIES:-5                                       NaN
#   Proceeds from issuance of common stock-5                    543.0
#   Excess tax benefits from equity awards-5                    749.0
#   Taxes paid related to net share settlement of e...        -1499.0
#   Dividends and dividend equivalents paid-5                -11561.0
#   Repurchase of common stock-5                             -35253.0
#   Proceeds from issuance of term debt, net-5                27114.0
#   Change in commercial paper, net-5                          2191.0
#   Cash used in financing activities-5                      -17716.0
#   Increase/(decrease) in cash and cash equivalents-5         7276.0
#   Cash and cash equivalents, end of the year-5              21120.0
#   SUPPLEMENTAL CASH FLOW DISCLOSURE:-6                          NaN
#   Cash paid for income taxes, net-6                         13252.0
#   Cash paid for interest-6                                    514.0,
#   Empty DataFrame
#   Columns: []
#   Index: []],
#  [                                                    Sep. 27, 2014
#   CONSOLIDATED STATEMENTS OF OPERATIONS (USD $)In...
#   Net sales-0                                              182795.0
#   Cost of sales-0                                          112258.0
#   Gross margin-0                                            70537.0
#   OPERATING EXPENSES:-1                                         NaN
#   Research and development-1                                 6041.0
#   Selling, general and administrative-1                     11993.0
#   Total operating expenses-1                                18034.0
#   Operating income-1                                        52503.0
#   Other income/(expense), net-1                               980.0
#   Income before provision for income taxes-1                53483.0
#   Provision for income taxes-1                              13973.0
#   Net income-1                                              39510.0
#   EARNINGS PER SHARE:-2                                         NaN
#   Basic-2                                                     649.0
#   Diluted-2                                                   645.0
#   SHARES USED IN COMPUTING EARNINGS PER SHARE:-3                NaN
#   Basic-3                                                 6085572.0
#   Diluted-3                                               6122663.0
#   Cash dividends declared per common share-3                  182.0,
#                                                       Sep. 27, 2014
#   CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME...
#   Net income-0                                              39510.0
#   OTHER COMPREHENSIVE INCOME/(LOSS):-1                          NaN
#   Change in foreign currency translation, net of ...         -137.0
#   CHANGE IN UNRECOGNIZED GAINS/LOSSES ON DERIVATI...            NaN
#   Change in fair value of derivatives, net of tax...         1390.0
#   Adjustment for net losses/(gains) realized and ...          149.0
#   Total change in unrecognized gains/losses on de...         1539.0
#   CHANGE IN UNREALIZED GAINS/LOSSES ON MARKETABLE...            NaN
#   Change in fair value of marketable securities, ...          285.0
#   Adjustment for net losses/(gains) realized and ...         -134.0
#   Total change in unrealized gains/losses on mark...          151.0
#   Total other comprehensive income/(loss)-3                  1553.0
#   Total comprehensive income-3                              41063.0,
#                                                       Sep. 27, 2014
#   CONSOLIDATED BALANCE SHEETS (USD $)In Millions,...
#   CURRENT ASSETS:-1                                             NaN
#   Cash and cash equivalents-1                               13844.0
#   Short-term marketable securities-1                        11233.0
#   Accounts receivable, less allowances of $86 and...        17460.0
#   Inventories-1                                              2111.0
#   Deferred tax assets-1                                      4318.0
#   Vendor non-trade receivables-1                             9759.0
#   Other current assets-1                                     9806.0
#   Total current assets-1                                    68531.0
#   Long-term marketable securities-1                        130162.0
#   Property, plant and equipment, net-1                      20624.0
#   Goodwill-1                                                 4616.0
#   Acquired intangible assets, net-1                          4142.0
#   Other assets-1                                             3764.0
#   Total assets-1                                           231839.0
#   CURRENT LIABILITIES:-2                                        NaN
#   Accounts payable-2                                        30196.0
#   Accrued expenses-2                                        18453.0
#   Deferred revenue-2                                         8491.0
#   Commercial paper-2                                         6308.0
#   Total current liabilities-2                               63448.0
#   Deferred revenue - non-current-2                           3031.0
#   Long-term debt-2                                          28987.0
#   Other non-current liabilities-2                           24826.0
#   Total liabilities-2                                      120292.0
#   Commitments and contingencies-2                               NaN
#   SHAREHOLDERS' EQUITY:-3                                       NaN
#   Common stock and additional paid-in capital, $0...        23313.0
#   Retained earnings-3                                       87152.0
#   Accumulated other comprehensive income/(loss)-3            1082.0
#   Total shareholders' equity-3                             111547.0
#   Total liabilities and shareholders' equity-3             231839.0,
#                                                       Sep. 27, 2014
#   CONSOLIDATED STATEMENTS OF CASH FLOWS (USD $)In...
#   Cash and cash equivalents, beginning of the year-0        14259.0
#   OPERATING ACTIVITIES:-1                                       NaN
#   Net income-1                                              39510.0
#   ADJUSTMENTS TO RECONCILE NET INCOME TO CASH GEN...            NaN
#   Depreciation and amortization-2                            7946.0
#   Share-based compensation expense-2                         2863.0
#   Deferred income tax expense-2                              2347.0
#   CHANGES IN OPERATING ASSETS AND LIABILITIES:-3                NaN
#   Accounts receivable, net-3                                -4232.0
#   Inventories-3                                               -76.0
#   Vendor non-trade receivables-3                            -2220.0
#   Other current and non-current assets-3                      167.0
#   Accounts payable-3                                         5938.0
#   Deferred revenue-3                                         1460.0
#   Other current and non-current liabilities-3                6010.0
#   Cash generated by operating activities-3                  59713.0
#   INVESTING ACTIVITIES:-4                                       NaN
#   Purchases of marketable securities-4                    -217128.0
#   Proceeds from maturities of marketable securiti...        18810.0
#   Proceeds from sales of marketable securities-4           189301.0
#   Payments made in connection with business acqui...        -3765.0
#   Payments for acquisition of property, plant and...        -9571.0
#   Payments for acquisition of intangible assets-4            -242.0
#   Other-4                                                      16.0
#   Cash used in investing activities-4                      -22579.0
#   FINANCING ACTIVITIES:-5                                       NaN
#   Proceeds from issuance of common stock-5                    730.0
#   Excess tax benefits from equity awards-5                    739.0
#   Taxes paid related to net share settlement of e...        -1158.0
#   Dividends and dividend equivalents paid-5                -11126.0
#   Repurchase of common stock-5                             -45000.0
#   Proceeds from issuance of long-term debt, net-5           11960.0
#   Proceeds from issuance of commercial paper, net-5          6306.0
#   Cash used in financing activities-5                      -37549.0
#   Increase/(decrease) in cash and cash equivalents-5         -415.0
#   Cash and cash equivalents, end of the year-5              13844.0
#   SUPPLEMENTAL CASH FLOW DISCLOSURE:-6                          NaN
#   Cash paid for income taxes, net-6                         10026.0
#   Cash paid for interest-6                                    339.0,
#   Empty DataFrame
#   Columns: []
#   Index: []],
#  [                                                    Sep. 28, 2013
#   Consolidated Statements of Operations (USD $)In...
#   Net sales-0                                              170910.0
#   Cost of sales-0                                          106606.0
#   Gross margin-0                                            64304.0
#   OPERATING EXPENSES:-1                                         NaN
#   Research and development-1                                 4475.0
#   Selling, general and administrative-1                     10830.0
#   Total operating expenses-1                                15305.0
#   Operating income-1                                        48999.0
#   Other income/(expense), net-1                              1156.0
#   Income before provision for income taxes-1                50155.0
#   Provision for income taxes-1                              13118.0
#   Net income-1                                              37037.0
#   EARNINGS PER SHARE:-2                                         NaN
#   Basic-2                                                    4003.0
#   Diluted-2                                                  3975.0
#   SHARES USED IN COMPUTING EARNINGS PER SHARE:-3                NaN
#   Basic-3                                                  925331.0
#   Diluted-3                                                931662.0
#   Cash dividends declared per common share-3                 1140.0,
#                                                       Sep. 28, 2013
#   Consolidated Statements of Comprehensive Income...
#   Net income-0                                              37037.0
#   OTHER COMPREHENSIVE INCOME/(LOSS):-1                          NaN
#   Change in foreign currency translation, net of ...         -112.0
#   CHANGE IN UNRECOGNIZED GAINS/LOSSES ON DERIVATI...            NaN
#   Change in fair value of derivatives, net of tax...          522.0
#   Adjustment for net losses/(gains) realized and ...         -458.0
#   Total change in unrecognized gains/losses on de...           64.0
#   CHANGE IN UNREALIZED GAINS/LOSSES ON MARKETABLE...            NaN
#   Change in fair value of marketable securities, ...         -791.0
#   Adjustment for net losses/(gains) realized and ...         -131.0
#   Total change in unrealized gains/losses on mark...         -922.0
#   Total other comprehensive income/(loss)-3                  -970.0
#   Total comprehensive income-3                              36067.0,
#                                                       Sep. 28, 2013
#   Consolidated Balance Sheets (USD $)In Millions,...
#   CURRENT ASSETS:-1                                             NaN
#   Cash and Cash Equivalents-1                               14259.0
#   Short-term marketable securities-1                        26287.0
#   Accounts receivable, less allowances of $99 and...        13102.0
#   Inventories-1                                              1764.0
#   Deferred tax assets-1                                      3453.0
#   Vendor non-trade receivables-1                             7539.0
#   Other current assets-1                                     6882.0
#   Total current assets-1                                    73286.0
#   Long-term marketable securities-1                        106215.0
#   Property, plant and equipment, net-1                      16597.0
#   Goodwill-1                                                 1577.0
#   Acquired intangible assets, net-1                          4179.0
#   Other assets-1                                             5146.0
#   Total assets-1                                           207000.0
#   CURRENT LIABILITIES:-2                                        NaN
#   Accounts payable-2                                        22367.0
#   Accrued expenses-2                                        13856.0
#   Deferred revenue-2                                         7435.0
#   Total current liabilities-2                               43658.0
#   Deferred revenue - non-current-2                           2625.0
#   Long-term debt-2                                          16960.0
#   Other non-current liabilities-2                           20208.0
#   Total liabilities-2                                       83451.0
#   Commitments and contingencies-2                               NaN
#   SHAREHOLDERS' EQUITY:-3                                       NaN
#   Common stock, no par value; 1,800,000 shares au...        19764.0
#   Retained earnings-3                                      104256.0
#   Accumulated other comprehensive income/(loss)-3            -471.0
#   Total shareholders' equity-3                             123549.0
#   Total liabilities and shareholders' equity-3             207000.0,
#                                                       Sep. 28, 2013
#   Consolidated Statements of Cash Flows (USD $)In...
#   Cash and cash equivalents, beginning of the year-0        10746.0
#   OPERATING ACTIVITIES:-1                                       NaN
#   Net income-1                                              37037.0
#   ADJUSTMENTS TO RECONCILE NET INCOME TO CASH GEN...            NaN
#   Depreciation and amortization-2                            6757.0
#   Share-based compensation expense-2                         2253.0
#   Deferred income tax expense-2                              1141.0
#   CHANGES IN OPERATING ASSETS AND LIABILITIES:-3                NaN
#   Accounts receivable, net-3                                -2172.0
#   Inventories-3                                              -973.0
#   Vendor non-trade receivables-3                              223.0
#   Other current and non-current assets-3                     1080.0
#   Accounts payable-3                                         2340.0
#   Deferred revenue-3                                         1459.0
#   Other current and non-current liabilities-3                4521.0
#   Cash generated by operating activities-3                  53666.0
#   INVESTING ACTIVITIES:-4                                       NaN
#   Purchases of marketable securities-4                    -148489.0
#   Proceeds from maturities of marketable securiti...        20317.0
#   Proceeds from sales of marketable securities-4           104130.0
#   Payments made in connection with business acqui...         -496.0
#   Payments for acquisition of property, plant and...        -8165.0
#   Payments for acquisition of intangible assets-4            -911.0
#   Other-4                                                    -160.0
#   Cash used in investing activities-4                      -33774.0
#   FINANCING ACTIVITIES:-5                                       NaN
#   Proceeds from issuance of common stock-5                    530.0
#   Excess tax benefits from equity awards-5                    701.0
#   Taxes paid related to net share settlement of e...        -1082.0
#   Dividends and dividend equivalent rights paid-5          -10564.0
#   Repurchase of common stock-5                             -22860.0
#   Proceeds from issuance of long-term debt, net-5           16896.0
#   Cash generated by/(used in) financing activities-5       -16379.0
#   Increase/(decrease) in cash and cash equivalents-5         3513.0
#   Cash and cash equivalents, end of the year-5              14259.0
#   SUPPLEMENTAL CASH FLOW DISCLOSURE:-6                          NaN
#   Cash paid for income taxes, net-6                          9128.0,
#   Empty DataFrame
#   Columns: []
#   Index: []]]

# %%
#perform a request for the document using hte link from the master list
response = requests.get(master_list[0]['links']['documents'], headers=user_agent)

#create a beautiful soup object to parse the html
soup = BeautifulSoup(response.content, 'html.parser')


# filing is split into a table, so we want to get that table
doc_table = soup.find_all('table')

# the last item on the table is the complete submission text file (ignoring xbrl stuff)
text_row = doc_table[0].find_all('tr')[-1]

base_url = r"https://www.sec.gov"

#grab the portion of the row that gives the end of the .txt url
end = text_row.find('a', {'href':True}).text.strip()

'''
#for grabbing the newer filing format (hard to convert to Filing.xml)
print(text_row.find('a', {'href':True})['href'])
'''

txt_url = base_url + "/Archives/edgar/data/" + str(CIK_num) + "/" + end
json_url = base_url + "/Archives/edgar/data/" + str(CIK_num) + "/" + end.replace('-', '').replace('.txt', '/index.json')
print(txt_url)
print(json_url)
# Out:
# https://www.sec.gov/Archives/edgar/data/21344/0000021344-18-000008.txt
# https://www.sec.gov/Archives/edgar/data/21344/000002134418000008/index.json
